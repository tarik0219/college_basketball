# %%
from datetime import datetime
from datetime import timedelta
from sportsreference.ncaab.boxscore import Boxscores
from sportsreference.ncaab.teams import Teams
import pandas as pd
import csv
import os
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from csv import reader
from csv import writer
import time
path = os.getcwd()
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
def get_yesterday():
    today = datetime.today()
    yesterday = today - timedelta(days = 1)
    year = yesterday.year
    month = yesterday.month
    day = yesterday.day
    return year,month,day

# %%
def get_today():
    today = datetime.today()
    year = today.year
    month = today.month
    day = today.day
    return year,month,day

# %%
pd.set_option('display.max_columns', None)

# %%
options = webdriver.ChromeOptions() 
#options.add_argument(r'''user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data''')
#"user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data" home
# "user-data-dir=C:\Users\koric1\AppData\Local\Google\Chrome\User Data" work
#options.add_argument("--start-maximized")
#self.options.add_argument("--headless")
#self.options.add_argument("--no-sandbox")
#self.options.add_argument("--disable-gpu")
options.add_argument('--headless')
options.add_argument('--disable-gpu')  # Last I checked this was necessa
driver = webdriver.Chrome(chrome_options= options)



#writer.writerow(["SN", "Name", "Contribution"])
driver.get('https://kenpom.com/')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="login"]/input[1]').send_keys('tarik0219@yahoo.com')
driver.find_element_by_xpath('//*[@id="login"]/input[2]').send_keys('kenporn123')
driver.find_element_by_xpath('//*[@id="login"]/input[3]').click()


teams = []
confs = []
adj_off = []
adj_def = []
adj_tempo = []
poss_off = []
poss_def = []
fg_off = []
fg_def = []
turnover_off = []
turnover_def = []
reb_off = []
reb_def = []
three_off = []
three_def = []
experience = []
height = []
wins_five = []
wins_last = []
for x in range(1,10):
    try:
        for z in range(1,41):
            team_name = str(driver.find_element_by_xpath('//*[@id="ratings-table"]/tbody['+str(x)+']/tr['+str(z)+']/td[2]/a').text)
            conf = str(driver.find_element_by_xpath('//*[@id="ratings-table"]/tbody['+str(x)+']/tr['+str(z)+']/td[3]/a').text)
            teams.append(team_name)
            confs.append(conf)
    except:
        break

for team in teams:
    print(team)
    team_list = team.split()
    new_team = ''
    for x in team_list:
        if x == '&':
            x = '%26'
        if x == 'A&M':
            x = 'A%26M'
        if x == 'A&T':
            x = 'A%26T'
        new_team = new_team + '+' + x
    
    new_team = new_team[1:]
    driver.get('https://kenpom.com/team.php?team='+new_team)
    #time.sleep(1)
    adj_off.append(float(driver.find_element_by_xpath('//*[@id="OE"]/a').text))
    adj_def.append(float(driver.find_element_by_xpath('//*[@id="DE"]/a').text))
    adj_tempo.append(float(driver.find_element_by_xpath('//*[@id="Tempo"]/span/a').text))
    poss_off.append(float(driver.find_element_by_xpath('//*[@id="APLO"]/a').text))
    poss_def.append(float(driver.find_element_by_xpath('//*[@id="APLD"]/a').text))           
    fg_off.append(float(driver.find_element_by_xpath('//*[@id="eFG"]/a').text))
    fg_def.append(float(driver.find_element_by_xpath('//*[@id="DeFG"]/a').text))
    turnover_off.append(float(driver.find_element_by_xpath('//*[@id="TOPct"]/a').text))
    turnover_def.append(float(driver.find_element_by_xpath('//*[@id="DTOPct"]/a').text))
    reb_off.append(float(driver.find_element_by_xpath('//*[@id="ORPct"]/a').text))
    reb_def.append(float(driver.find_element_by_xpath('//*[@id="DORPct"]/a').text))
    three_off.append(float(driver.find_element_by_xpath('//*[@id="3Pct"]/a').text))
    three_def.append(float(driver.find_element_by_xpath('//*[@id="D3Pct"]/a').text))
    experience.append(str(driver.find_element_by_xpath('//*[@id="report-table"]/tbody[2]/tr[29]/td[2]/a').text))
    height.append(str(driver.find_element_by_xpath('//*[@id="report-table"]/tbody[2]/tr[31]/td[2]/a').text))
    
    try:
        z = 1
        none = driver.find_element_by_xpath('//*[@id="schedule-table"]/tbody[2]/tr['+str(z)+']/td[7]').text
        wins_team = []
        while(none == ' ' or none == 'OT' or none == '2OT' or none =='3OT' or none == '4OT' or none == '5OT'):
            wins_team.append(str(driver.find_element_by_xpath('//*[@id="schedule-table"]/tbody[2]/tr['+str(z)+']/td[5]').text).split(',')[0])
            z += 1
            none = driver.find_element_by_xpath('//*[@id="schedule-table"]/tbody[2]/tr['+str(z)+']/td[7]').text
        wins_five.append(wins_team[-5:].count('W'))
        wins_last.append(wins_team[-1].count('W'))
    except:
        wins_five.append(0)
        wins_last.append(0)
driver.close()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()
# Gonzaga
# Baylor
# Michigan
# Iowa
# Villanova
# Houston
# Illinois
# Texas
# Virginia
# Alabama
# Wisconsin
# Ohio St.
# Texas Tech
# Creighton
# Florida St.
# West Virginia
# Kansas
# Tennessee
# Colorado
# USC
# Loyola Chicago
# Oklahoma
# Florida
# Indiana
# UCLA
# Connecticut
# Arizona
# Oregon
# Minnesota
# Purdue
# San Diego St.
# Missouri
# Duke
# Saint Louis
# North Carolina
# Syracuse
# Louisville
# Oklahoma St.
# Arkansas
# LSU
# Rutgers
# Maryland
# Seton Hall
# Michigan St.
# Virginia Tech
# Penn St.
# BYU
# Stanford
# Utah St.
# Xavier
# SMU
# Clemson
# Kentucky
# St. Bonaventure
# Mississippi
# Boise St.
# Memphis
# Auburn
# Georgia Tech
# VCU
# Richmond
# Providence
# Davidson
# Drake
# Pittsburgh
# Marquette
# Rhode Island
# N.C. State
# Toledo
# Wright St.
# Northwestern
# Arizona St.
# Utah
# Colorado St.
# Marshall
# Saint Mary's
# Wichita St.
# Notre Dame
# San Francisco
# South Carolina
# Mississippi St.
# Western Kentucky
# St. John's
# Cincinnati
# Dayton
# Tulsa
# Butler
# Furman
# Georgia
# Belmont
# UC Santa Barbara
# UAB
# North Texas
# DePaul
# Boston College
# Iowa St.
# TCU
# South Dakota St.
# Miami FL
# UCF
# Vermont
# South Florida
# Yale
# Louisiana Tech
# Colgate
# Liberty
# Massachusetts
# Winthrop
# Kent St.
# Buffalo
# Georgetown
# UC Irvine
# Abilene Christian
# Duquesne
# Texas A&M
# UNC Greensboro
# Bradley
# Wake Forest
# New Mexico St.
# Wofford
# Missouri St.
# Nevada
# Nebraska
# Oregon St.
# Akron
# Ohio
# UNLV
# Georgia St.
# Loyola Marymount
# Pacific
# Pepperdine
# UC Riverside
# Washington
# Grand Canyon
# Bowling Green
# Washington St.
# Eastern Washington
# Cal St. Bakersfield
# East Tennessee St.
# California
# Temple
# Siena
# George Mason
# Princeton
# Indiana St.
# East Carolina
# Santa Clara
# Ball St.
# Vanderbilt
# Texas St.
# Old Dominion
# Northern Iowa
# North Dakota St.
# Stephen F. Austin
# Mercer
# Northeastern
# Drexel
# Murray St.
# Harvard
# Coastal Carolina
# Eastern Kentucky
# Little Rock
# Miami OH
# Saint Peter's
# Monmouth
# Charlotte
# La Salle
# Montana
# Louisiana
# Kansas St.
# Navy
# Cleveland St.
# Hofstra
# UTEP
# South Dakota
# Appalachian St.
# Bryant
# Army
# Oral Roberts
# UMBC
# Wyoming
# Fresno St.
# Florida Atlantic
# Gardner Webb
# Montana St.
# San Diego
# Chattanooga
# Sam Houston St.
# Jacksonville St.
# Morehead St.
# Nicholls St.
# Saint Joseph's
# Weber St.
# Rice
# Southern Illinois
# Penn
# UT Arlington
# Cornell
# Detroit
# UNC Wilmington
# Southern Utah
# Tulane
# UC Davis
# UTSA
# Valparaiso
# Austin Peay
# Western Carolina
# George Washington
# Lafayette
# James Madison
# VMI
# Bellarmine
# Hawaii
# South Alabama
# Iona
# Northern Colorado
# FIU
# Charleston
# UC San Diego
# UT Rio Grande Valley
# Albany
# Milwaukee
# Lipscomb
# UNC Asheville
# Hartford
# Radford
# Sacramento St.
# Elon
# Brown
# Illinois Chicago
# Northern Kentucky
# UMKC
# UMass Lowell
# Purdue Fort Wayne
# Delaware
# Mount St. Mary's
# Niagara
# Stetson
# Canisius
# Texas Southern
# Oakland
# Towson
# LIU
# New Hampshire
# Green Bay
# NJIT
# North Alabama
# Youngstown St.
# Utah Valley
# Illinois St.
# American
# Eastern Illinois
# Stony Brook
# Loyola MD
# Eastern Michigan
# Central Michigan
# Southern Miss
# Fordham
# Norfolk St.
# Samford
# St. Francis PA
# Georgia Southern
# Boston University
# Robert Morris
# North Carolina Central
# Longwood
# Bucknell
# Dartmouth
# Nebraska Omaha
# Morgan St.
# Middle Tennessee
# Campbell
# Florida Gulf Coast
# Quinnipiac
# Southern
# Prairie View A&M
# Marist
# Evansville
# Cal Baptist
# Columbia
# Wagner
# Western Michigan
# New Mexico
# St. Francis NY
# Central Arkansas
# High Point
# Seattle
# Long Beach St.
# Portland St.
# Arkansas St.
# Troy
# Florida A&M
# William & Mary
# Idaho St.
# North Florida
# IUPUI
# Jackson St.
# Portland
# The Citadel
# North Dakota
# Tennessee St.
# New Orleans
# Cal St. Northridge
# Cal St. Fullerton
# Rider
# Fairleigh Dickinson
# Manhattan
# Merrimack
# Louisiana Monroe
# Jacksonville
# Howard
# Lehigh
# Air Force
# USC Upstate
# North Carolina A&T
# Hampton
# Southeast Missouri St.
# Tennessee Tech
# Northern Illinois
# Sacred Heart
# Northwestern St.
# Coppin St.
# Grambling St.
# SIU Edwardsville
# San Jose St.
# Northern Arizona
# Lamar
# Tarleton St.
# Incarnate Word
# Alabama A&M
# Fairfield
# Western Illinois
# Dixie St.
# Texas A&M Corpus Chris
# Central Connecticut
# Southeastern Louisiana
# Holy Cross
# Alcorn St.
# Maine
# Charleston Southern
# Denver
# Houston Baptist
# Cal Poly
# McNeese St.
# Binghamton
# Presbyterian
# Kennesaw St.
# Bethune Cookman
# Idaho
# Tennessee Martin
# Delaware St.
# Arkansas Pine Bluff
# Alabama St.
# Maryland Eastern Shore
# South Carolina St.
# Chicago St.
# Mississippi Valley St.

# %%
new_experience = []
new_height = []
for i,team in enumerate(experience):
    new_experience.append(float(experience[i][:-4]))
    new_height.append(float(height[i][:-1]))

# %%
kp = pd.DataFrame(list(zip(teams,confs,adj_off,adj_def,adj_tempo,poss_off,poss_def,fg_off,fg_def,turnover_off,turnover_def,reb_off,reb_def,three_off,three_def,new_experience,new_height,wins_five,wins_last)), columns =['teams','conf','adj_off','adj_def','adj_tempo','poss_off','poss_def','fg_off','fg_def','turnover_off','turnover_def','reb_off','reb_def','three_off','three_def','experience','height','wins_five','wins_last'])
kp
# Out:
#                       teams  conf  adj_off  adj_def  adj_tempo  poss_off  \
# 0                   Gonzaga   WCC    124.4     90.4       75.2      14.2
# 1                    Baylor   B12    120.7     87.0       69.1      16.1
# 2                  Michigan   B10    116.9     88.8       68.6      16.8
# 3                      Iowa   B10    124.6     97.5       71.3      15.7
# 4                 Villanova    BE    119.3     93.0       65.0      18.2
# ..                      ...   ...      ...      ...        ...       ...
# 352             Alabama St.  SWAC     84.0    108.7       68.0      16.1
# 353  Maryland Eastern Shore  MEAC     84.3    110.2       68.7       0.0
# 354      South Carolina St.  MEAC     85.4    112.7       73.1      16.4
# 355             Chicago St.   WAC     88.0    116.9       68.6      17.8
# 356  Mississippi Valley St.  SWAC     81.0    121.5       70.4      16.9
#
#      poss_def  fg_off  fg_def  turnover_off  turnover_def  reb_off  reb_def  \
# 0        17.5    60.4    46.9          15.4          20.0     34.0     24.3
# 1        17.5    58.4    46.4          17.7          26.5     38.3     30.0
# 2        17.7    57.6    43.0          18.4          15.5     30.4     25.1
# 3        17.1    56.4    48.6          13.7          17.8     34.3     30.1
# 4        17.4    54.8    52.9          11.9          19.9     27.2     21.2
# ..        ...     ...     ...           ...           ...      ...      ...
# 352      18.1    40.7    47.1          24.2          21.5     33.6     27.0
# 353       0.0     0.0   100.0         100.0           0.0      0.0    100.0
# 354      16.3    43.7    56.6          24.4          21.9     25.3     34.6
# 355      16.0    41.3    60.1          21.7          16.2     16.6     37.9
# 356      15.9    41.9    59.8          23.7          15.4     16.7     39.6
#
#      three_off  three_def  experience  height  wins_five  wins_last
# 0         35.3       33.9        1.48    78.3          5          1
# 1         42.6       32.0        1.96    76.6          5          1
# 2         37.7       32.2        2.08    77.9          4          1
# 3         38.4       34.8        1.68    77.8          4          0
# 4         36.9       36.2        1.88    77.9          5          1
# ..         ...        ...         ...     ...        ...        ...
# 352       26.9       31.5        1.87    75.0          1          0
# 353        0.0      100.0        0.00     0.0          0          0
# 354       32.6       34.3        1.09    76.5          0          0
# 355       25.1       39.5        1.88    75.6          0          0
# 356       31.2       37.4        1.32    76.1          0          0
#
# [357 rows x 19 columns]

# %%
year,month,day = get_today()
name = path+"\\kenpom\\"+str(year)+"_"+str(month)+"_"+str(day)+"_kenpom.csv"
kp.to_csv(name, index = False)

# %%
options = webdriver.ChromeOptions() 
#options.add_argument(r'''user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data''')
#"user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data" home
# "user-data-dir=C:\Users\koric1\AppData\Local\Google\Chrome\User Data" work
#options.add_argument("--start-maximized")
#self.options.add_argument("--headless")
#self.options.add_argument("--no-sandbox")
#self.options.add_argument("--disable-gpu")
options.add_argument('--headless')
options.add_argument('--disable-gpu')  # Last I checked this was necessa
driver = webdriver.Chrome(chrome_options= options)



#writer.writerow(["SN", "Name", "Contribution"])
driver.get('https://kenpom.com/')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="login"]/input[1]').send_keys('tarik0219@yahoo.com')
driver.find_element_by_xpath('//*[@id="login"]/input[2]').send_keys('kenporn123')
driver.find_element_by_xpath('//*[@id="login"]/input[3]').click()
driver.get('https://kenpom.com/fanmatch.php')
x = 1
home = []
away = []
predict = []
while(True):
    try:
        away.append(str(driver.find_element_by_xpath('//*[@id="fanmatch-table"]/tbody/tr['+str(x)+']/td[1]/a[1]').text))
        home.append((driver.find_element_by_xpath('//*[@id="fanmatch-table"]/tbody/tr['+str(x)+']/td[1]/a[2]').text))
        predict.append((driver.find_element_by_xpath('//*[@id="fanmatch-table"]/tbody/tr['+str(x)+']/td[2]').text))
        x+=1
    except:
        break
driver.close()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()

# %%
score = []
for i,x in enumerate(predict):
    team = home[i]
    list_1 = x.split()
    team_compare = ''
    num = len(list_1) - 2
    
    for i in range(0,num):
        team_compare = team_compare + ' '+ list_1[i]
    team_compare = team_compare[1:]
    if team_compare == team:
        list_2 = list_1[-2].split('-')
        score.append(int(list_2[0]) - int(list_2[1]))
    else:
        list_2 = list_1[-2].split('-')
        score.append(int(list_2[1]) - int(list_2[0]))

# %%
games = pd.DataFrame(list(zip(home,away,score)), columns =['home','away','predict_kp'])
year,month,day = get_today()
name = path+"\\games\\"+str(year)+"_"+str(month)+"_"+str(day)+"_games.csv"
games.to_csv(name, index = False)
games['date'] = str(year)+'-'+str("{0:0=2d}".format(month))+'-'+str("{0:0=2d}".format(day))
games
# Out:
#                    home                 away  predict_kp        date
# 0         West Virginia           Texas Tech           2  2021-01-25
# 1              Virginia             Syracuse           7  2021-01-25
# 2              Iowa St.         Oklahoma St.          -4  2021-01-25
# 3               Arizona          Arizona St.           7  2021-01-25
# 4                  UNLV             Utah St.          -6  2021-01-25
# 5               Bradley       Loyola Chicago          -7  2021-01-25
# 6                Furman       UNC Greensboro           5  2021-01-25
# 7           Indiana St.    Southern Illinois           5  2021-01-25
# 8         UNC Asheville              Radford           2  2021-01-25
# 9           Alabama A&M           Alcorn St.           4  2021-01-25
# 10             Portland     Loyola Marymount          -9  2021-01-25
# 11  Arkansas Pine Bluff     Prairie View A&M          -8  2021-01-25
# 12          Alabama St.             Southern          -8  2021-01-25
# 13           High Point         Presbyterian           9  2021-01-25
# 14         Gardner Webb  Charleston Southern          13  2021-01-25

# %%
predict = pd.merge(games, kp, how='left', left_on='home', right_on='teams')
predict.drop(['teams'], axis = 1, inplace = True)
predict = pd.merge(predict, kp, how='left', left_on='away', right_on='teams')
predict.drop(['teams'], axis = 1, inplace = True)
year,month,day = get_today()
name = path+"\\predict\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict.csv"
predict.to_csv(name, index = False)
predict
# Out:
#                    home                 away  predict_kp        date conf_x  \
# 0         West Virginia           Texas Tech           2  2021-01-25    B12
# 1              Virginia             Syracuse           7  2021-01-25    ACC
# 2              Iowa St.         Oklahoma St.          -4  2021-01-25    B12
# 3               Arizona          Arizona St.           7  2021-01-25    P12
# 4                  UNLV             Utah St.          -6  2021-01-25    MWC
# 5               Bradley       Loyola Chicago          -7  2021-01-25    MVC
# 6                Furman       UNC Greensboro           5  2021-01-25     SC
# 7           Indiana St.    Southern Illinois           5  2021-01-25    MVC
# 8         UNC Asheville              Radford           2  2021-01-25   BSth
# 9           Alabama A&M           Alcorn St.           4  2021-01-25   SWAC
# 10             Portland     Loyola Marymount          -9  2021-01-25    WCC
# 11  Arkansas Pine Bluff     Prairie View A&M          -8  2021-01-25   SWAC
# 12          Alabama St.             Southern          -8  2021-01-25   SWAC
# 13           High Point         Presbyterian           9  2021-01-25   BSth
# 14         Gardner Webb  Charleston Southern          13  2021-01-25   BSth
#
#     adj_off_x  adj_def_x  adj_tempo_x  poss_off_x  poss_def_x  fg_off_x  \
# 0       112.9       90.8         68.8        17.4        16.6      47.1
# 1       115.4       90.8         59.6        19.9        19.2      58.3
# 2       106.4       98.9         69.4        16.8        17.1      52.9
# 3       114.1       95.6         69.9        16.3        17.8      51.5
# 4       105.4      101.3         68.2        17.5        17.0      51.1
# 5       102.2       97.1         67.2        16.7        18.9      49.9
# 6       110.1      101.6         69.0        15.9        17.1      57.3
# 7       101.9      100.1         69.5        17.0        17.1      47.6
# 8       101.4      107.1         69.8        16.8        17.0      54.4
# 9        90.4      106.0         70.6        18.2        14.4      50.8
# 10       95.1      106.5         73.8        16.4        15.7      44.6
# 11       88.7      113.2         69.8        18.3        15.3      42.0
# 12       84.0      108.7         68.0        16.1        18.1      40.7
# 13       96.1      106.1         67.9        18.0        17.3      50.5
# 14      102.2      104.8         68.8        16.5        16.9      51.1
#
#     fg_def_x  turnover_off_x  turnover_def_x  reb_off_x  reb_def_x  \
# 0       47.9            16.8            21.4       37.1       31.2
# 1       48.1            13.5            15.9       23.7       21.2
# 2       49.5            22.5            19.2       23.8       33.3
# 3       47.8            16.6            19.5       36.5       23.7
# 4       52.4            19.3            19.6       26.4       26.1
# 5       48.1            19.6            18.3       29.9       26.6
# 6       52.0            18.1            22.3       28.5       31.6
# 7       52.9            20.1            22.3       24.2       29.0
# 8       50.3            20.0            20.0       27.0       29.1
# 9       41.1            22.0            17.6       27.7       29.6
# 10      56.1            19.7            18.4       20.8       28.6
# 11      57.2            22.8            16.2       25.4       31.0
# 12      47.1            24.2            21.5       33.6       27.0
# 13      52.4            20.0            19.9       27.1       26.8
# 14      50.1            17.7            18.1       25.3       25.9
#
#     three_off_x  three_def_x  experience_x  height_x  wins_five_x  \
# 0          34.7         28.7          1.83      77.4            3
# 1          38.9         34.6          1.85      77.8            5
# 2          33.0         28.3          1.93      76.6            1
# 3          37.7         32.7          1.33      78.6            3
# 4          33.9         37.8          1.59      77.3            4
# 5          32.1         37.2          1.61      77.4            3
# 6          35.5         35.2          1.94      76.5            3
# 7          34.1         33.3          1.86      76.6            3
# 8          35.3         32.8          1.78      76.9            4
# 9          27.2         17.3          0.79      76.3            4
# 10         30.8         33.5          2.00      75.7            0
# 11         31.7         43.6          2.26      75.8            2
# 12         26.9         31.5          1.87      75.0            1
# 13         33.3         33.8          1.16      76.2            2
# 14         35.9         34.1          1.16      75.9            2
#
#     wins_last_x conf_y  adj_off_y  adj_def_y  adj_tempo_y  poss_off_y  \
# 0             1    B12      111.5       88.7         67.1        17.8
# 1             1    ACC      112.7       95.3         69.3        15.5
# 2             0    B12      110.4       93.2         71.1        15.9
# 3             1    P12      109.6       97.9         73.8        15.8
# 4             1    MWC      105.8       90.3         69.9        16.8
# 5             0    MVC      110.5       90.6         65.8        18.0
# 6             0     SC      102.6       97.4         68.8        16.7
# 7             1    MVC      101.2      104.6         68.6        17.3
# 8             1   BSth       97.5      103.2         64.7        19.6
# 9             1   SWAC       92.5      110.0         69.7        17.7
# 10            0    WCC      100.9       97.3         69.2        17.5
# 11            0   SWAC       93.1      102.5         68.7        17.5
# 12            0   SWAC       94.8      104.1         70.3        16.2
# 13            1   BSth       90.5      110.7         65.7        19.1
# 14            1   BSth       89.6      107.5         69.6        16.8
#
#     poss_def_y  fg_off_y  fg_def_y  turnover_off_y  turnover_def_y  reb_off_y  \
# 0         17.6      49.1      45.4            16.7            26.1       35.1
# 1         17.4      51.7      45.7            16.1            20.9       29.7
# 2         17.6      51.1      47.6            19.5            19.3       32.3
# 3         17.0      50.4      52.3            14.8            22.0       20.3
# 4         17.2      51.0      45.4            20.1            21.3       35.5
# 5         18.0      57.7      46.9            17.7            22.1       25.1
# 6         16.7      47.3      46.7            17.7            21.2       35.7
# 7         18.1      53.3      54.0            17.7            20.3       16.0
# 8         17.3      50.9      48.7            24.4            17.9       34.3
# 9         16.4      45.2      56.5            21.3            19.8       30.2
# 10        16.9      48.4      47.9            24.1            18.8       32.2
# 11        17.2      48.5      48.9            21.6            26.4       31.5
# 12        16.8      46.8      49.7            21.6            17.9       30.3
# 13        16.4      45.5      56.8            23.9            22.4       30.4
# 14        16.5      45.1      52.8            25.4            18.8       26.1
#
#     reb_def_y  three_off_y  three_def_y  experience_y  height_y  wins_five_y  \
# 0        28.9         32.6         32.1          1.41      76.9            3
# 1        32.0         32.1         28.6          1.53      77.9            3
# 2        30.5         32.8         33.2          1.14      77.6            3
# 3        30.2         33.2         36.3          1.79      76.7            0
# 4        19.8         34.4         32.8          1.45      78.1            4
# 5        21.2         36.2         33.0          2.21      76.3            5
# 6        26.4         27.8         30.6          1.74      77.3            4
# 7        27.1         39.8         40.0          0.98      76.3            2
# 8        23.0         29.6         36.8          1.18      75.4            4
# 9        36.3         29.6         37.6          2.09      75.1            3
# 10       21.3         29.8         34.5          1.79      78.2            2
# 11       34.8         28.8         31.1          2.05      76.8            3
# 12       22.8         33.6         33.7          2.16      76.0            3
# 13       29.5         31.2         41.1          0.83      77.1            0
# 14       30.3         30.8         35.3          1.12      76.5            0
#
#     wins_last_y
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0
# 5             1
# 6             1
# 7             0
# 8             0
# 9             1
# 10            0
# 11            1
# 12            0
# 13            0
# 14            0

# %%
year,month,day = get_yesterday()

# %%
options = webdriver.ChromeOptions() 
#options.add_argument(r'''user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data''')
#"user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data" home
# "user-data-dir=C:\Users\koric1\AppData\Local\Google\Chrome\User Data" work
#options.add_argument("--start-maximized")
#self.options.add_argument("--headless")
#self.options.add_argument("--no-sandbox")
#self.options.add_argument("--disable-gpu")
#options.add_argument('--headless')
#options.add_argument('--disable-gpu')  # Last I checked this was necessa
driver = webdriver.Chrome(chrome_options= options)



#writer.writerow(["SN", "Name", "Contribution"])
driver.get('https://kenpom.com/')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="login"]/input[1]').send_keys('tarik0219@yahoo.com')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="login"]/input[2]').send_keys('kenporn123')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="login"]/input[3]').click()
time.sleep(1)
driver.get('https://kenpom.com/fanmatch.php?d='+str(year)+'-'+str("{0:0=2d}".format(month))+'-'+str("{0:0=2d}".format(day)))

x = 1
away = []
home = []
home_score = []
away_score = []
while(True):

    
    try:
        
        driver.find_element_by_xpath('//*[@id="fanmatch-table"]/tbody/tr['+str(x)+']/td[3]/a').click()
        away.append(str(driver.find_element_by_xpath('//*[@id="linescore-table2"]/tbody/tr[1]/td[1]').text))
        home.append(str(driver.find_element_by_xpath('//*[@id="linescore-table2"]/tbody/tr[2]/td[1]').text))
        

        y = 15
        while(True):
            try:
                w_s = driver.find_element_by_xpath('//*[@id="linescore-table2"]/tbody/tr[1]/td['+str(y)+']/b').text
                l_s = driver.find_element_by_xpath('//*[@id="linescore-table2"]/tbody/tr[2]/td['+str(y)+']/b').text
                away_score.append(int(w_s))
                home_score.append(int(l_s))
                break
            except:
                y -= 1
        driver.get('https://kenpom.com/fanmatch.php?d='+str(year)+'-'+str("{0:0=2d}".format(month))+'-'+str("{0:0=2d}".format(day)))
        
        x+=1
    except:
        break
driver.close()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()

# %%
scores = pd.DataFrame(list(zip(home,away,home_score, away_score)), columns =['home','away','home_score','away_score'])
scores['score'] = scores['home_score'] - scores['away_score']
scores['date'] = str(year)+'-'+str("{0:0=2d}".format(month))+'-'+str("{0:0=2d}".format(day))
scores
# Out:
#                 home                 away  home_score  away_score  score  \
# 0            Indiana              Rutgers          70          74     -4
# 1      Massachusetts             Davidson          60          69     -9
# 2           Miami FL           Notre Dame          59          73    -14
# 3            Bradley       Loyola Chicago          56          69    -13
# 4         Washington                 Utah          83          79      4
# 5      East Carolina              Memphis          53          80    -27
# 6            Wyoming               Nevada          93          88      5
# 7               Navy                 Army          78          87     -9
# 8       Illinois St.           Valparaiso          66          70     -4
# 9      UNC Asheville              Radford          76          68      8
# 10         Loyola MD             American          79          81     -2
# 11     New Hampshire               Albany          64          83    -19
# 12        Coppin St.          Norfolk St.          81          77      4
# 13        Holy Cross               Lehigh          74          82     -8
# 14    UNC Wilmington             Delaware          62          67     -5
# 15              NJIT          Stony Brook          44          56    -12
# 16           Hofstra               Towson          74          69      5
# 17         Lafayette    Boston University          61          64     -3
# 18      Oral Roberts                 UMKC          76          81     -5
# 19      Northeastern        James Madison          72          79     -7
# 20  Middle Tennessee     Western Kentucky          52          68    -16
# 21        High Point         Presbyterian          81          57     24
# 22         Air Force        San Diego St.          59          91    -32
# 23        Morgan St.         Delaware St.          99          83     16
# 24      Gardner Webb  Charleston Southern          74          62     12
# 25      Rhode Island              Fordham          52          42     10
#
#           date
# 0   2021-01-24
# 1   2021-01-24
# 2   2021-01-24
# 3   2021-01-24
# 4   2021-01-24
# 5   2021-01-24
# 6   2021-01-24
# 7   2021-01-24
# 8   2021-01-24
# 9   2021-01-24
# 10  2021-01-24
# 11  2021-01-24
# 12  2021-01-24
# 13  2021-01-24
# 14  2021-01-24
# 15  2021-01-24
# 16  2021-01-24
# 17  2021-01-24
# 18  2021-01-24
# 19  2021-01-24
# 20  2021-01-24
# 21  2021-01-24
# 22  2021-01-24
# 23  2021-01-24
# 24  2021-01-24
# 25  2021-01-24

# %%
year,month,day = get_yesterday()
name = path+"\\kenpom\\"+str(year)+"_"+str(month)+"_"+str(day)+"_kenpom.csv"
kp_yesterday = pd.read_csv(name)

# %%
kp_scores = pd.merge(scores, kp_yesterday, how='left', left_on='home', right_on='teams')
kp_scores.drop(['teams'], axis = 1, inplace = True)
kp_scores = pd.merge(kp_scores, kp_yesterday, how='left', left_on='away', right_on='teams')
kp_scores.drop(['teams'], axis = 1, inplace = True)
year,month,day = get_yesterday()
name = path+"\\scores_kenpom\\"+str(year)+"_"+str(month)+"_"+str(day)+"_scores_kenpom.csv"
kp_scores.to_csv(name, index = False)
kp_scores
# Out:
#                 home                 away  home_score  away_score  score  \
# 0            Indiana              Rutgers          70          74     -4
# 1      Massachusetts             Davidson          60          69     -9
# 2           Miami FL           Notre Dame          59          73    -14
# 3            Bradley       Loyola Chicago          56          69    -13
# 4         Washington                 Utah          83          79      4
# 5      East Carolina              Memphis          53          80    -27
# 6            Wyoming               Nevada          93          88      5
# 7               Navy                 Army          78          87     -9
# 8       Illinois St.           Valparaiso          66          70     -4
# 9      UNC Asheville              Radford          76          68      8
# 10         Loyola MD             American          79          81     -2
# 11     New Hampshire               Albany          64          83    -19
# 12        Coppin St.          Norfolk St.          81          77      4
# 13        Holy Cross               Lehigh          74          82     -8
# 14    UNC Wilmington             Delaware          62          67     -5
# 15              NJIT          Stony Brook          44          56    -12
# 16           Hofstra               Towson          74          69      5
# 17         Lafayette    Boston University          61          64     -3
# 18      Oral Roberts                 UMKC          76          81     -5
# 19      Northeastern        James Madison          72          79     -7
# 20  Middle Tennessee     Western Kentucky          52          68    -16
# 21        High Point         Presbyterian          81          57     24
# 22         Air Force        San Diego St.          59          91    -32
# 23        Morgan St.         Delaware St.          99          83     16
# 24      Gardner Webb  Charleston Southern          74          62     12
# 25      Rhode Island              Fordham          52          42     10
#
#           date conf_x  adj_off_x  adj_def_x  adj_tempo_x  poss_off_x  \
# 0   2021-01-24    B10      110.9       91.1         66.9        17.7
# 1   2021-01-24    A10      107.2      100.2         73.4        16.2
# 2   2021-01-24    ACC      104.2       95.6         69.0        17.8
# 3   2021-01-24    MVC      102.8       97.2         67.0        16.7
# 4   2021-01-24    P12      103.7      100.8         70.8        16.6
# 5   2021-01-24   Amer      100.5       97.2         68.1        17.5
# 6   2021-01-24    MWC      104.8      107.6         70.2        16.8
# 7   2021-01-24    Pat      102.9      103.2         66.0        18.6
# 8   2021-01-24    MVC       97.5      104.7         70.7        16.1
# 9   2021-01-24   BSth      101.4      107.5         70.0        16.8
# 10  2021-01-24    Pat       99.4      106.8         69.6        18.7
# 11  2021-01-24     AE       97.5      102.9         67.8        18.8
# 12  2021-01-24   MEAC       89.0      103.4         78.5        14.1
# 13  2021-01-24    Pat       93.7      110.8         71.7        16.8
# 14  2021-01-24    CAA      101.9      104.8         70.3        16.3
# 15  2021-01-24     AE       97.4      103.4         69.7        17.5
# 16  2021-01-24    CAA      102.1      103.1         68.7        16.7
# 17  2021-01-24    Pat      104.3      108.4         69.2        17.2
# 18  2021-01-24    Sum      106.9      107.7         71.5        16.2
# 19  2021-01-24    CAA       99.6       97.5         68.5        18.2
# 20  2021-01-24   CUSA       90.8       99.2         72.3        17.0
# 21  2021-01-24   BSth       95.4      106.6         67.6        18.1
# 22  2021-01-24    MWC       96.9      108.8         63.2        19.5
# 23  2021-01-24   MEAC       97.2      106.7         72.0        16.0
# 24  2021-01-24   BSth      102.2      104.9         68.7        16.5
# 25  2021-01-24    A10      106.6       93.8         70.7        16.6
#
#     poss_def_x  fg_off_x  fg_def_x  turnover_off_x  turnover_def_x  reb_off_x  \
# 0         17.4      51.6      47.7            16.8            18.5       23.3
# 1         15.8      49.3      52.0            16.0            21.6       25.6
# 2         16.4      47.9      49.4            20.4            18.5       29.3
# 3         18.9      50.1      47.3            19.2            18.0       30.7
# 4         17.7      46.7      49.3            19.1            16.4       25.5
# 5         17.4      47.9      45.6            19.8            20.9       27.0
# 6         17.4      53.8      51.1            15.2            18.4       23.5
# 7         17.0      50.2      53.5            17.2            21.4       31.2
# 8         18.3      51.1      52.4            19.0            17.1       22.2
# 9         16.8      54.9      50.2            20.4            19.3       27.2
# 10        16.2      50.6      54.4            21.5            17.1       36.2
# 11        16.4      45.4      48.5            17.5            18.0       29.1
# 12        15.8      46.2      50.6            19.8            22.4       18.0
# 13        16.4      51.7      53.3            20.4            16.8       26.3
# 14        17.6      49.0      49.6            17.1            20.0       26.7
# 15        17.5      46.6      50.9            16.2            20.0       25.1
# 16        17.8      48.4      50.0            18.2            18.0       27.8
# 17        16.9      53.6      52.5            15.4            18.4       28.2
# 18        16.6      52.1      50.1            17.4            17.7       26.9
# 19        16.4      52.3      47.5            20.3            17.2       18.8
# 20        15.9      43.9      49.6            23.8            22.7       23.7
# 21        17.2      50.0      52.7            19.7            18.7       24.7
# 22        17.4      53.7      56.2            24.7            20.2       14.6
# 23        16.5      50.0      48.2            20.4            21.3       33.1
# 24        16.9      50.8      50.5            17.7            17.8       25.1
# 25        16.7      50.9      46.5            20.6            18.1       29.0
#
#     reb_def_x  three_off_x  three_def_x  experience_x  height_x  wins_five_x  \
# 0        26.4         33.3         33.1          1.36      77.2            3
# 1        23.8         32.6         37.0          1.01      76.8            3
# 2        24.9         26.9         36.1          1.45      78.4            2
# 3        26.9         32.7         37.9          1.62      77.4            3
# 4        38.4         30.9         33.0          1.93      78.0            1
# 5        25.9         34.5         28.8          1.99      77.8            2
# 6        29.1         37.4         30.9          1.08      77.9            2
# 7        24.4         33.3         33.6          1.66      75.9            5
# 8        26.1         37.9         33.1          1.07      77.2            2
# 9        29.1         34.3         33.0          1.77      76.9            4
# 10       24.0         30.6         43.2          1.66      77.3            0
# 11       19.2         32.2         32.9          1.56      77.0            3
# 12       32.2         29.5         32.8          1.60      77.2            4
# 13       32.7         35.1         37.9          1.37      76.7            1
# 14       31.7         35.1         29.9          1.84      76.7            3
# 15       29.7         33.7         32.1          2.24      76.1            2
# 16       27.4         29.2         32.5          1.73      76.8            2
# 17       28.5         40.1         35.3          1.94      77.6            4
# 18       33.5         37.7         33.9          1.61      76.6            4
# 19       24.8         36.3         29.1          1.12      77.6            5
# 20       24.7         29.1         28.2          1.95      76.6            1
# 21       26.6         33.2         33.9          1.16      76.2            1
# 22       35.1         34.0         36.9          1.96      76.8            1
# 23       31.6         35.9         31.1          2.16      77.0            3
# 24       26.7         35.4         34.9          1.17      75.9            2
# 25       26.5         32.7         32.1          1.94      76.4            2
#
#     wins_last_x conf_y  adj_off_y  adj_def_y  adj_tempo_y  poss_off_y  \
# 0             1    B10      109.3       93.0         69.3        16.8
# 1             1    A10      113.0      100.3         64.3        19.1
# 2             0    ACC      112.6      103.3         67.4        18.1
# 3             0    MVC      110.5       91.3         65.6        17.9
# 4             1    P12      107.8       95.9         67.5        17.7
# 5             0   Amer      102.4       89.2         71.9        15.8
# 6             1    MWC      103.6       98.3         70.7        16.9
# 7             1    Pat       97.8      100.5         68.6        16.9
# 8             0    MVC       97.1      101.6         68.3        17.1
# 9             0   BSth       98.1      103.4         64.9        19.6
# 10            0    Pat       97.2      105.0         70.3        16.7
# 11            1     AE       96.3      103.5         69.9        17.4
# 12            1   MEAC       97.5      105.3         68.9        17.1
# 13            0    Pat       96.4      109.6         68.8        17.6
# 14            1    CAA       97.1      104.5         67.3        18.2
# 15            1     AE       95.6      104.3         68.8        17.1
# 16            1    CAA      100.6      107.5         66.9        18.7
# 17            0    Pat       99.3      108.3         67.9        17.4
# 18            1    Sum       95.1      102.2         63.6        19.2
# 19            1    CAA      100.5      106.5         72.2        15.6
# 20            0   CUSA      108.4       98.9         68.8        17.6
# 21            0   BSth       91.1      110.0         65.3        19.2
# 22            0    MWC      109.0       91.5         66.2        17.0
# 23            1   MEAC       90.8      113.5         74.1        15.3
# 24            1   BSth       90.1      107.6         69.5        16.8
# 25            0    A10       89.9       98.1         64.5        19.1
#
#     poss_def_y  fg_off_y  fg_def_y  turnover_off_y  turnover_def_y  reb_off_y  \
# 0         17.4      51.2      49.0            15.0            18.3       28.9
# 1         18.2      55.8      49.9            17.6            15.3       30.1
# 2         18.2      53.2      52.4            15.7            12.6       20.6
# 3         18.0      57.6      46.9            17.3            21.9       25.3
# 4         17.7      50.0      48.1            17.3            21.5       25.7
# 5         17.1      47.5      43.9            21.3            22.1       33.9
# 6         17.4      49.5      46.8            19.7            18.2       26.2
# 7         16.7      53.3      51.8            18.9            20.8       23.1
# 8         17.3      45.5      51.0            18.4            18.7       20.0
# 9         17.3      50.7      48.8            23.9            18.2       34.6
# 10        17.5      55.0      47.5            23.9            20.3       26.8
# 11        17.6      50.5      52.0            18.4            21.9       20.4
# 12        16.8      49.0      46.7            17.2            19.0       25.4
# 13        17.2      50.6      53.6            16.9            17.3       22.5
# 14        17.2      48.2      49.5            21.3            18.3       27.8
# 15        17.2      49.6      51.3            20.4            19.3       26.3
# 16        16.1      46.5      50.5            20.4            14.2       34.6
# 17        16.9      47.6      56.2            20.9            14.7       34.8
# 18        18.0      50.1      51.1            22.0            21.6       24.3
# 19        17.2      49.8      50.1            18.8            21.9       26.7
# 20        16.0      50.0      51.0            20.4            19.2       32.8
# 21        16.4      45.3      56.8            22.9            22.3       30.5
# 22        18.6      51.9      49.0            19.1            24.0       29.0
# 23        15.8      45.2      54.2            21.6            18.1       25.0
# 24        16.4      45.1      52.6            25.7            18.8       26.9
# 25        18.6      40.5      52.8            21.0            19.4       22.9
#
#     reb_def_y  three_off_y  three_def_y  experience_y  height_y  wins_five_y  \
# 0        28.2         35.3         31.8          1.91      77.9            0
# 1        18.7         36.2         32.2          1.76      78.4            4
# 2        28.8         37.4         38.0          2.16      78.7            1
# 3        21.3         37.0         33.8          2.19      76.2            4
# 4        29.8         31.1         33.1          1.39      77.4            2
# 5        23.3         32.4         28.0          1.10      77.8            3
# 6        23.9         33.3         32.6          1.03      78.2            2
# 7        24.0         33.5         34.1          1.98      75.2            3
# 8        26.6         27.1         34.0          1.43      76.8            1
# 9        22.8         29.6         35.9          1.19      75.5            5
# 10       35.4         38.8         33.3          1.62      77.9            1
# 11       29.0         32.4         36.6          2.30      77.0            2
# 12       30.5         37.5         31.3          2.33      76.8            4
# 13       27.0         32.9         38.8          1.40      77.5            1
# 14       26.5         28.7         36.2          1.72      78.0            1
# 15       26.7         31.2         36.8          2.16      77.1            2
# 16       30.3         27.1         37.5          1.71      77.2            3
# 17       27.4         28.9         36.8          1.98      77.6            1
# 18       24.1         33.1         38.3          1.94      76.5            1
# 19       31.5         32.8         31.4          1.35      76.4            3
# 20       22.0         33.8         37.3          2.16      76.3            4
# 21       26.6         31.3         41.7          0.86      77.2            1
# 22       25.9         37.0         34.6          2.46      76.6            3
# 23       33.0         32.9         35.2          1.63      75.6            0
# 24       30.4         31.3         34.6          1.12      76.5            0
# 25       29.9         25.9         34.1          1.63      75.8            1
#
#     wins_last_y
# 0             0
# 1             1
# 2             1
# 3             1
# 4             1
# 5             1
# 6             0
# 7             0
# 8             1
# 9             1
# 10            1
# 11            0
# 12            0
# 13            1
# 14            0
# 15            0
# 16            0
# 17            1
# 18            0
# 19            0
# 20            1
# 21            0
# 22            1
# 23            0
# 24            0
# 25            0

# %%
df = pd.read_csv('all.csv')
df.to_csv('all_copy.csv', index = False)
frames = [df,kp_scores]
df = pd.concat(frames, ignore_index = True)

# %%
df.to_csv('all.csv', index = False)

# %%
df = pd.read_csv('all.csv')

# %%
df
# Out:
#                home                 away  home_score  away_score  score  \
# 0          Michigan            Wisconsin          77          54     23
# 1      Oklahoma St.               Kansas          75          70      5
# 2     Virginia Tech                 Duke          74          67      7
# 3          Kentucky              Alabama          65          85    -20
# 4    North Carolina             Syracuse          81          75      6
# ..              ...                  ...         ...         ...    ...
# 496      High Point         Presbyterian          81          57     24
# 497       Air Force        San Diego St.          59          91    -32
# 498      Morgan St.         Delaware St.          99          83     16
# 499    Gardner Webb  Charleston Southern          74          62     12
# 500    Rhode Island              Fordham          52          42     10
#
#            date conf_x  adj_off_x  adj_def_x  adj_tempo_x  poss_off_x  \
# 0    2021-01-12    B10      116.4       91.4         68.0        16.6
# 1    2021-01-12    B12      109.8       92.3         71.7        15.7
# 2    2021-01-12    ACC      111.7       93.9         67.2        17.7
# 3    2021-01-12    SEC      107.7       91.1         68.0        17.0
# 4    2021-01-12    ACC      108.6       90.3         71.1        15.8
# ..          ...    ...        ...        ...          ...         ...
# 496  2021-01-24   BSth       95.4      106.6         67.6        18.1
# 497  2021-01-24    MWC       96.9      108.8         63.2        19.5
# 498  2021-01-24   MEAC       97.2      106.7         72.0        16.0
# 499  2021-01-24   BSth      102.2      104.9         68.7        16.5
# 500  2021-01-24    A10      106.6       93.8         70.7        16.6
#
#      poss_def_x  fg_off_x  fg_def_x  turnover_off_x  turnover_def_x  \
# 0          17.6      59.0      43.8            18.2            15.2
# 1          17.6      51.3      46.8            19.2            19.5
# 2          18.0      53.0      48.8            17.9            18.6
# 3          18.0      47.2      45.9            20.8            18.3
# 4          17.7      46.1      48.7            22.0            18.8
# ..          ...       ...       ...             ...             ...
# 496        17.2      50.0      52.7            19.7            18.7
# 497        17.4      53.7      56.2            24.7            20.2
# 498        16.5      50.0      48.2            20.4            21.3
# 499        16.9      50.8      50.5            17.7            17.8
# 500        16.7      50.9      46.5            20.6            18.1
#
#      reb_off_x  reb_def_x  three_off_x  three_def_x  experience_x  height_x  \
# 0         31.1       24.1         35.8         34.8          2.10      77.9
# 1         32.2       29.6         31.6         33.2          1.12      77.6
# 2         31.8       23.0         35.3         33.8          1.63      76.3
# 3         33.8       30.4         31.1         30.8          0.90      79.0
# 4         40.7       23.7         30.4         34.7          1.08      78.8
# ..         ...        ...          ...          ...           ...       ...
# 496       24.7       26.6         33.2         33.9          1.16      76.2
# 497       14.6       35.1         34.0         36.9          1.96      76.8
# 498       33.1       31.6         35.9         31.1          2.16      77.0
# 499       25.1       26.7         35.4         34.9          1.17      75.9
# 500       29.0       26.5         32.7         32.1          1.94      76.4
#
#      wins_five_x  wins_last_x conf_y  adj_off_y  adj_def_y  adj_tempo_y  \
# 0              5            1    B10      114.9       89.2         64.9
# 1              2            1    B12      112.7       89.5         68.7
# 2              4            1    ACC      112.8       92.9         69.0
# 3              3            1    SEC      111.6       93.0         74.6
# 4              3            1    ACC      109.6       92.7         70.6
# ..           ...          ...    ...        ...        ...          ...
# 496            1            0   BSth       91.1      110.0         65.3
# 497            1            0    MWC      109.0       91.5         66.2
# 498            3            1   MEAC       90.8      113.5         74.1
# 499            2            1   BSth       90.1      107.6         69.5
# 500            2            0    A10       89.9       98.1         64.5
#
#      poss_off_y  poss_def_y  fg_off_y  fg_def_y  turnover_off_y  \
# 0          18.1        18.0      53.8      44.4            12.1
# 1          16.3        17.5      49.9      47.2            18.0
# 2          16.4        16.8      52.7      52.2            20.0
# 3          14.2        17.5      49.4      47.4            18.0
# 4          15.3        17.0      51.3      46.3            17.5
# ..          ...         ...       ...       ...             ...
# 496        19.2        16.4      45.3      56.8            22.9
# 497        17.0        18.6      51.9      49.0            19.1
# 498        15.3        15.8      45.2      54.2            21.6
# 499        16.8        16.4      45.1      52.6            25.7
# 500        19.1        18.6      40.5      52.8            21.0
#
#      turnover_def_y  reb_off_y  reb_def_y  three_off_y  three_def_y  \
# 0              18.2       23.7       21.9         41.4         33.0
# 1              18.1       35.0       25.9         35.5         32.1
# 2              21.8       35.3       24.9         35.2         37.1
# 3              21.0       32.8       29.2         32.2         31.6
# 4              22.8       29.6       28.0         32.6         29.8
# ..              ...        ...        ...          ...          ...
# 496            22.3       30.5       26.6         31.3         41.7
# 497            24.0       29.0       25.9         37.0         34.6
# 498            18.1       25.0       33.0         32.9         35.2
# 499            18.8       26.9       30.4         31.3         34.6
# 500            19.4       22.9       29.9         25.9         34.1
#
#      experience_y  height_y  wins_five_y  wins_last_y
# 0            2.33      78.2          4.0          1.0
# 1            1.42      78.2          4.0          1.0
# 2            0.90      76.9          4.0          1.0
# 3            1.93      77.9          5.0          1.0
# 4            1.49      77.9          4.0          1.0
# ..            ...       ...          ...          ...
# 496          0.86      77.2          1.0          0.0
# 497          2.46      76.6          3.0          1.0
# 498          1.63      75.6          0.0          0.0
# 499          1.12      76.5          0.0          0.0
# 500          1.63      75.8          1.0          0.0
#
# [501 rows x 42 columns]

# %%
x = df[['adj_off_x', 'adj_def_x', 'adj_tempo_x', 'poss_off_x', 'poss_def_x',
       'fg_off_x', 'fg_def_x', 'turnover_off_x', 'turnover_def_x', 'reb_off_x',
       'reb_def_x', 'three_off_x', 'three_def_x', 'experience_x', 'height_x','wins_five_x','wins_last_x',
       'adj_off_y', 'adj_def_y', 'adj_tempo_y', 'poss_off_y',
       'poss_def_y', 'fg_off_y', 'fg_def_y', 'turnover_off_y',
       'turnover_def_y', 'reb_off_y', 'reb_def_y', 'three_off_y',
       'three_def_y', 'experience_y', 'height_y','wins_five_y','wins_last_y']].values
y = df[['score']].values
predict_x = predict[['adj_off_x', 'adj_def_x', 'adj_tempo_x', 'poss_off_x', 'poss_def_x',
       'fg_off_x', 'fg_def_x', 'turnover_off_x', 'turnover_def_x', 'reb_off_x',
       'reb_def_x', 'three_off_x', 'three_def_x', 'experience_x', 'height_x','wins_five_x','wins_last_x',
       'adj_off_y', 'adj_def_y', 'adj_tempo_y', 'poss_off_y',
       'poss_def_y', 'fg_off_y', 'fg_def_y', 'turnover_off_y',
       'turnover_def_y', 'reb_off_y', 'reb_def_y', 'three_off_y',
       'three_def_y', 'experience_y', 'height_y','wins_five_y','wins_last_y']].values

# %%
lasso = Lasso()
lasso.fit(x, y)
lasso.coef_
# Out:
# array([ 0.77118463, -0.87066219,  0.        , -0.        ,  0.        ,
#         0.        , -0.        ,  0.        ,  0.19248712,  0.08953666,
#        -0.        , -0.        ,  0.07970516,  0.        , -0.        ,
#        -0.        , -0.        , -0.81682135,  0.94566866,  0.        ,
#         0.        , -0.        , -0.        ,  0.        , -0.16225034,
#         0.16205559, -0.        ,  0.21851947,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.82703142,  0.        ])

# %%
lin = LinearRegression()
lin.fit(x, y)
lin.coef_
# Out:
# array([[ 0.94549994, -0.73081072, -0.12766016, -0.32157506, -0.18491013,
#          0.10511841, -0.43128327,  0.08901593,  0.35468074,  0.10694798,
#         -0.14487415, -0.13665923,  0.33719631, -0.02093596, -0.99046547,
#         -0.39633739, -0.43181987, -0.79887283,  0.9839219 ,  0.4960484 ,
#          0.97205322, -0.18415794, -0.37002126, -0.0614429 , -0.24062763,
#          0.31497561, -0.09446422,  0.34774366,  0.22307357,  0.22709505,
#         -0.50620498,  0.19050007,  2.09077102, -0.25832405]])

# %%
rf = RandomForestRegressor()
rf.fit(x, y)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
games['lasso'] = lasso.predict(predict_x)
games['lasso'] = round(games['lasso'])
games['linear'] = lin.predict(predict_x)
games['linear'] = round(games['linear'])
games['rf'] = rf.predict(predict_x)
games['rf'] = round(games['rf'])
games
# Out:
#                    home                 away  predict_kp        date  lasso  \
# 0         West Virginia           Texas Tech           2  2021-01-25    3.0
# 1              Virginia             Syracuse           7  2021-01-25    9.0
# 2              Iowa St.         Oklahoma St.          -4  2021-01-25   -6.0
# 3               Arizona          Arizona St.           7  2021-01-25    8.0
# 4                  UNLV             Utah St.          -6  2021-01-25   -8.0
# 5               Bradley       Loyola Chicago          -7  2021-01-25   -9.0
# 6                Furman       UNC Greensboro           5  2021-01-25    7.0
# 7           Indiana St.    Southern Illinois           5  2021-01-25    7.0
# 8         UNC Asheville              Radford           2  2021-01-25    2.0
# 9           Alabama A&M           Alcorn St.           4  2021-01-25    6.0
# 10             Portland     Loyola Marymount          -9  2021-01-25  -14.0
# 11  Arkansas Pine Bluff     Prairie View A&M          -8  2021-01-25   -7.0
# 12          Alabama St.             Southern          -8  2021-01-25  -10.0
# 13           High Point         Presbyterian           9  2021-01-25   10.0
# 14         Gardner Webb  Charleston Southern          13  2021-01-25   13.0
#
#     linear    rf
# 0      3.0  12.0
# 1      7.0   3.0
# 2     -6.0   0.0
# 3      8.0   5.0
# 4     -8.0  -5.0
# 5     -9.0  -1.0
# 6      9.0  -8.0
# 7      8.0   6.0
# 8      1.0   5.0
# 9      8.0  12.0
# 10   -17.0  -8.0
# 11    -7.0 -16.0
# 12    -7.0 -14.0
# 13    10.0  10.0
# 14    13.0  11.0

# %%
map_team_name = {'Ole Miss':'Mississippi',
                 'Miami (FL)' : 'Miami FL',
                 'Miami Ohio' : 'Miami OH',
                 "St. Joseph's" : "Saint Joseph's",
                 'NC State' : 'N.C. State',
                 'Texas A&M-CC' : 'Texas A&M Corpus Chris',
                 'LIU Sharks' : "LIU",
                 'Central Connecticut State' : 'Central Connecticut',
                 'LA-Lafayette' : 'Louisiana',
                 'Cal State Bakersfield' : 'Cal St. Bakersfield',
                 'CSU Northridge' : 'Cal St. Northridge',
                 'Louisiana-Monroe' : 'Louisiana Monroe',
                 'Tarleton State Texans':'Tarleton St.',
                 'Florida Intl' : "FIU",
                 'Citadel':'The Citadel',
                 'UC San Diego Tritons':'UC San Diego',
                 'Grambling St' : 'Grambling St.',
                 'Arkansas-Pine Bluff': 'Arkansas Pine Bluff',
                 'UMass' : 'Massachusetts',
                 'North Carolina Asheville' : 'UNC Asheville',
                 'St. Francis (PA)' : 'St. Francis PA',
                 'San José State' : 'San Jose St.',
                 "Mt. St. Mary's" : "Mount St. Mary's",
                 "Tennessee-Martin" : "Tennessee Martin",
                 'Arkansas Little Rock' : 'Little Rock',
                 'Southern Mississippi' : 'Southern Miss',
                 'Kansas City' : 'UMKC',
                 'Charleston Southern' : "Charleston Southern",
                 'Southern University' : 'Southern'
                 
                 
                 
                }

# %%
options = webdriver.ChromeOptions() 
#options.add_argument(r'''user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data''')
#"user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data" home
# "user-data-dir=C:\Users\koric1\AppData\Local\Google\Chrome\User Data" work
#options.add_argument("--start-maximized")
#self.options.add_argument("--headless")
#self.options.add_argument("--no-sandbox")
#self.options.add_argument("--disable-gpu")
options.add_argument('--headless')
options.add_argument('--disable-gpu')  # Last I checked this was necessa
driver = webdriver.Chrome(chrome_options= options)
driver.get('https://sportsbook.draftkings.com/leagues/basketball/3230960?category=game-lines&subcategory=game')

x = True
i = 1
teams = {}
while(x):
    try:
        team_name = str(driver.find_element_by_xpath('//*[@id="root"]/section/section[2]/section/div[3]/div/div[3]/div/div/div[2]/div/div[2]/div[2]/section/div[2]/div[1]/div['+str(i)+']/a/div/div[2]/span').text)
        team_score = float(driver.find_element_by_xpath('//*[@id="root"]/section/section[2]/section/div[3]/div/div[3]/div/div/div[2]/div/div[2]/div[2]/section/div[2]/div[2]/div['+str(i)+']/div/div/div/div[1]/span').text)
        teams[team_name] = team_score 
        i += 1
    except:
        x = False

        
for key in list(teams):
    name_list = key.split()
    
    if key in map_team_name.keys():
        teams[map_team_name[key]] =   teams[key]
        del teams[key]
    elif name_list[-1] == "State":
        name_list[-1] = "St."
        new_name = " ".join(str(x) for x in name_list)
        home_team = new_name
        teams[home_team] = teams[key] 
        del teams[key]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()

# %%
games['draft_kings'] = games['away'].apply(lambda x: teams[x] if x in teams else -99)
games[games['draft_kings'] == -99]
# Out:
#             home                 away  predict_kp        date  lasso  linear  \
# 14  Gardner Webb  Charleston Southern          13  2021-01-25   13.0    13.0
#
#       rf  draft_kings
# 14  11.0        -99.0

# %%
games
# Out:
#                    home                 away  predict_kp        date  lasso  \
# 0         West Virginia           Texas Tech           2  2021-01-25    3.0
# 1              Virginia             Syracuse           7  2021-01-25    9.0
# 2              Iowa St.         Oklahoma St.          -4  2021-01-25   -6.0
# 3               Arizona          Arizona St.           7  2021-01-25    8.0
# 4                  UNLV             Utah St.          -6  2021-01-25   -8.0
# 5               Bradley       Loyola Chicago          -7  2021-01-25   -9.0
# 6                Furman       UNC Greensboro           5  2021-01-25    7.0
# 7           Indiana St.    Southern Illinois           5  2021-01-25    7.0
# 8         UNC Asheville              Radford           2  2021-01-25    2.0
# 9           Alabama A&M           Alcorn St.           4  2021-01-25    6.0
# 10             Portland     Loyola Marymount          -9  2021-01-25  -14.0
# 11  Arkansas Pine Bluff     Prairie View A&M          -8  2021-01-25   -7.0
# 12          Alabama St.             Southern          -8  2021-01-25  -10.0
# 13           High Point         Presbyterian           9  2021-01-25   10.0
# 14         Gardner Webb  Charleston Southern          13  2021-01-25   13.0
#
#     linear    rf  draft_kings
# 0      3.0  12.0          2.0
# 1      7.0   3.0          7.5
# 2     -6.0   0.0         -2.5
# 3      8.0   5.0          5.0
# 4     -8.0  -5.0         -6.0
# 5     -9.0  -1.0         -7.0
# 6      9.0  -8.0          4.5
# 7      8.0   6.0          7.0
# 8      1.0   5.0          3.0
# 9      8.0  12.0          4.5
# 10   -17.0  -8.0        -10.0
# 11    -7.0 -16.0         -9.0
# 12    -7.0 -14.0         -8.5
# 13    10.0  10.0          8.0
# 14    13.0  11.0        -99.0

# %%
games = games[games['draft_kings']!=-99]
year,month,day = get_today()
name = path+"\\predict_scores\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict_scores.csv"
games.to_csv(name, index = False)

# %%
games['diff_kp'] = abs(games['predict_kp'] - games['draft_kings'])
games = games.sort_values(by=['diff_kp'], ascending = False)
games['bet'] = 'none'
for index, row in games.iterrows():
    line = row['predict_kp']
    dk = row['draft_kings']
    home = row['home']
    away = row['away']
    if line < dk:
        games.loc[index,'bet'] = away
    elif line > dk:
        games.loc[index,'bet'] = home
    else:
        pass
games
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                    home               away  predict_kp        date  lasso  \
# 3               Arizona        Arizona St.           7  2021-01-25    8.0
# 7           Indiana St.  Southern Illinois           5  2021-01-25    7.0
# 2              Iowa St.       Oklahoma St.          -4  2021-01-25   -6.0
# 8         UNC Asheville            Radford           2  2021-01-25    2.0
# 10             Portland   Loyola Marymount          -9  2021-01-25  -14.0
# 11  Arkansas Pine Bluff   Prairie View A&M          -8  2021-01-25   -7.0
# 13           High Point       Presbyterian           9  2021-01-25   10.0
# 1              Virginia           Syracuse           7  2021-01-25    9.0
# 6                Furman     UNC Greensboro           5  2021-01-25    7.0
# 9           Alabama A&M         Alcorn St.           4  2021-01-25    6.0
# 12          Alabama St.           Southern          -8  2021-01-25  -10.0
# 0         West Virginia         Texas Tech           2  2021-01-25    3.0
# 4                  UNLV           Utah St.          -6  2021-01-25   -8.0
# 5               Bradley     Loyola Chicago          -7  2021-01-25   -9.0
#
#     linear    rf  draft_kings  diff_kp                  bet
# 3      8.0   5.0          5.0      2.0              Arizona
# 7      8.0   6.0          7.0      2.0    Southern Illinois
# 2     -6.0   0.0         -2.5      1.5         Oklahoma St.
# 8      1.0   5.0          3.0      1.0              Radford
# 10   -17.0  -8.0        -10.0      1.0             Portland
# 11    -7.0 -16.0         -9.0      1.0  Arkansas Pine Bluff
# 13    10.0  10.0          8.0      1.0           High Point
# 1      7.0   3.0          7.5      0.5             Syracuse
# 6      9.0  -8.0          4.5      0.5               Furman
# 9      8.0  12.0          4.5      0.5           Alcorn St.
# 12    -7.0 -14.0         -8.5      0.5          Alabama St.
# 0      3.0  12.0          2.0      0.0                 none
# 4     -8.0  -5.0         -6.0      0.0                 none
# 5     -9.0  -1.0         -7.0      0.0                 none

# %%
games.drop(columns=['lasso','linear','rf'])
# Out:
#                    home               away  predict_kp        date  \
# 3               Arizona        Arizona St.           7  2021-01-25
# 7           Indiana St.  Southern Illinois           5  2021-01-25
# 2              Iowa St.       Oklahoma St.          -4  2021-01-25
# 8         UNC Asheville            Radford           2  2021-01-25
# 10             Portland   Loyola Marymount          -9  2021-01-25
# 11  Arkansas Pine Bluff   Prairie View A&M          -8  2021-01-25
# 13           High Point       Presbyterian           9  2021-01-25
# 1              Virginia           Syracuse           7  2021-01-25
# 6                Furman     UNC Greensboro           5  2021-01-25
# 9           Alabama A&M         Alcorn St.           4  2021-01-25
# 12          Alabama St.           Southern          -8  2021-01-25
# 0         West Virginia         Texas Tech           2  2021-01-25
# 4                  UNLV           Utah St.          -6  2021-01-25
# 5               Bradley     Loyola Chicago          -7  2021-01-25
#
#     draft_kings  diff_kp                  bet
# 3           5.0      2.0              Arizona
# 7           7.0      2.0    Southern Illinois
# 2          -2.5      1.5         Oklahoma St.
# 8           3.0      1.0              Radford
# 10        -10.0      1.0             Portland
# 11         -9.0      1.0  Arkansas Pine Bluff
# 13          8.0      1.0           High Point
# 1           7.5      0.5             Syracuse
# 6           4.5      0.5               Furman
# 9           4.5      0.5           Alcorn St.
# 12         -8.5      0.5          Alabama St.
# 0           2.0      0.0                 none
# 4          -6.0      0.0                 none
# 5          -7.0      0.0                 none

# %%
year,month,day = get_yesterday()
name = path+"\\predict_scores\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict_scores.csv"
predict_yesterday = pd.read_csv(name)
predict_yesterday
# Out:
#                 home               away  predict_kp        date  lasso  \
# 0      Massachusetts           Davidson          -1  2021-01-24   -3.0
# 1           Miami FL         Notre Dame           2  2021-01-24    2.0
# 2            Bradley     Loyola Chicago          -7  2021-01-24   -8.0
# 3         Washington               Utah          -4  2021-01-24   -6.0
# 4      East Carolina            Memphis          -5  2021-01-24   -7.0
# 5            Wyoming             Nevada          -4  2021-01-24   -7.0
# 6               Navy               Army           4  2021-01-24    5.0
# 7       Illinois St.         Valparaiso           1  2021-01-24   -1.0
# 8      UNC Asheville            Radford           1  2021-01-24    2.0
# 9          Loyola MD           American           2  2021-01-24    4.0
# 10     New Hampshire             Albany           3  2021-01-24    6.0
# 11        Holy Cross             Lehigh          -1  2021-01-24   -1.0
# 12    UNC Wilmington           Delaware           5  2021-01-24    4.0
# 13         Lafayette  Boston University           6  2021-01-24    5.0
# 14      Oral Roberts               UMKC           6  2021-01-24    5.0
# 15      Northeastern      James Madison           8  2021-01-24   11.0
# 16  Middle Tennessee   Western Kentucky         -11  2021-01-24  -12.0
# 17        High Point       Presbyterian           7  2021-01-24    8.0
# 18         Air Force      San Diego St.         -15  2021-01-24  -22.0
# 19        Morgan St.       Delaware St.          12  2021-01-24   14.0
# 20      Rhode Island            Fordham          17  2021-01-24   19.0
#
#     linear    rf  draft_kings
# 0     -3.0   2.0         -2.5
# 1      2.0   2.0          3.5
# 2     -9.0  -0.0         -7.5
# 3     -9.0   5.0         -5.0
# 4     -8.0  -2.0         -6.0
# 5     -9.0   2.0         -4.0
# 6      5.0  12.0          2.5
# 7     -6.0  -9.0          1.0
# 8      3.0  -1.0          3.0
# 9      6.0  14.0          4.5
# 10     8.0   2.0          2.0
# 11    -2.0  -2.0          1.0
# 12     1.0   8.0          4.5
# 13     0.0   4.0          5.5
# 14     3.0  10.0          6.0
# 15    10.0   8.0          5.5
# 16   -11.0 -11.0        -10.0
# 17     9.0  15.0          5.0
# 18   -24.0 -10.0        -16.0
# 19    13.0  16.0         13.5
# 20    22.0  21.0         17.0

# %%
scores = scores.drop(columns=['date','away'])
scores
# Out:
#                 home  home_score  away_score  score
# 0            Indiana          70          74     -4
# 1      Massachusetts          60          69     -9
# 2           Miami FL          59          73    -14
# 3            Bradley          56          69    -13
# 4         Washington          83          79      4
# 5      East Carolina          53          80    -27
# 6            Wyoming          93          88      5
# 7               Navy          78          87     -9
# 8       Illinois St.          66          70     -4
# 9      UNC Asheville          76          68      8
# 10         Loyola MD          79          81     -2
# 11     New Hampshire          64          83    -19
# 12        Coppin St.          81          77      4
# 13        Holy Cross          74          82     -8
# 14    UNC Wilmington          62          67     -5
# 15              NJIT          44          56    -12
# 16           Hofstra          74          69      5
# 17         Lafayette          61          64     -3
# 18      Oral Roberts          76          81     -5
# 19      Northeastern          72          79     -7
# 20  Middle Tennessee          52          68    -16
# 21        High Point          81          57     24
# 22         Air Force          59          91    -32
# 23        Morgan St.          99          83     16
# 24      Gardner Webb          74          62     12
# 25      Rhode Island          52          42     10

# %%
import math
error = pd.merge(predict_yesterday, scores, how='left', left_on='home', right_on='home')
error = error[error['home'] !='Georgetown']
error
# Out:
#                 home               away  predict_kp        date  lasso  \
# 0      Massachusetts           Davidson          -1  2021-01-24   -3.0
# 1           Miami FL         Notre Dame           2  2021-01-24    2.0
# 2            Bradley     Loyola Chicago          -7  2021-01-24   -8.0
# 3         Washington               Utah          -4  2021-01-24   -6.0
# 4      East Carolina            Memphis          -5  2021-01-24   -7.0
# 5            Wyoming             Nevada          -4  2021-01-24   -7.0
# 6               Navy               Army           4  2021-01-24    5.0
# 7       Illinois St.         Valparaiso           1  2021-01-24   -1.0
# 8      UNC Asheville            Radford           1  2021-01-24    2.0
# 9          Loyola MD           American           2  2021-01-24    4.0
# 10     New Hampshire             Albany           3  2021-01-24    6.0
# 11        Holy Cross             Lehigh          -1  2021-01-24   -1.0
# 12    UNC Wilmington           Delaware           5  2021-01-24    4.0
# 13         Lafayette  Boston University           6  2021-01-24    5.0
# 14      Oral Roberts               UMKC           6  2021-01-24    5.0
# 15      Northeastern      James Madison           8  2021-01-24   11.0
# 16  Middle Tennessee   Western Kentucky         -11  2021-01-24  -12.0
# 17        High Point       Presbyterian           7  2021-01-24    8.0
# 18         Air Force      San Diego St.         -15  2021-01-24  -22.0
# 19        Morgan St.       Delaware St.          12  2021-01-24   14.0
# 20      Rhode Island            Fordham          17  2021-01-24   19.0
#
#     linear    rf  draft_kings  home_score  away_score  score
# 0     -3.0   2.0         -2.5          60          69     -9
# 1      2.0   2.0          3.5          59          73    -14
# 2     -9.0  -0.0         -7.5          56          69    -13
# 3     -9.0   5.0         -5.0          83          79      4
# 4     -8.0  -2.0         -6.0          53          80    -27
# 5     -9.0   2.0         -4.0          93          88      5
# 6      5.0  12.0          2.5          78          87     -9
# 7     -6.0  -9.0          1.0          66          70     -4
# 8      3.0  -1.0          3.0          76          68      8
# 9      6.0  14.0          4.5          79          81     -2
# 10     8.0   2.0          2.0          64          83    -19
# 11    -2.0  -2.0          1.0          74          82     -8
# 12     1.0   8.0          4.5          62          67     -5
# 13     0.0   4.0          5.5          61          64     -3
# 14     3.0  10.0          6.0          76          81     -5
# 15    10.0   8.0          5.5          72          79     -7
# 16   -11.0 -11.0        -10.0          52          68    -16
# 17     9.0  15.0          5.0          81          57     24
# 18   -24.0 -10.0        -16.0          59          91    -32
# 19    13.0  16.0         13.5          99          83     16
# 20    22.0  21.0         17.0          52          42     10

# %%
dfe = pd.read_csv('all_e.csv')
dfe.to_csv('all_e_copy.csv', index = False)
frames = [dfe,error]
dfe = pd.concat(frames, ignore_index = True)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %%
dfe.to_csv('all_e.csv', index = False)

# %%
dfe
# Out:
#                  away  away_score        date  draft_kings              home  \
# 0           Wisconsin        54.0  2021-01-12          3.5          Michigan
# 1              Kansas        70.0  2021-01-12         -3.5      Oklahoma St.
# 2                Duke        67.0  2021-01-12         -1.0     Virginia Tech
# 3             Alabama        85.0  2021-01-12          3.0          Kentucky
# 4            Syracuse        75.0  2021-01-12          4.5    North Carolina
# ..                ...         ...         ...          ...               ...
# 468  Western Kentucky        68.0  2021-01-24        -10.0  Middle Tennessee
# 469      Presbyterian        57.0  2021-01-24          5.0        High Point
# 470     San Diego St.        91.0  2021-01-24        -16.0         Air Force
# 471      Delaware St.        83.0  2021-01-24         13.5        Morgan St.
# 472           Fordham        42.0  2021-01-24         17.0      Rhode Island
#
#      home_score  lasso  linear  predict_kp    rf  score
# 0          77.0   -7.0    -8.0           1 -16.0   23.0
# 1          75.0   -3.0    -2.0          -1  -4.0    5.0
# 2          74.0   -6.0    -2.0           1  -6.0    7.0
# 3          65.0    1.0     2.0           1  -4.0  -20.0
# 4          81.0    6.0     4.0           3  -4.0    6.0
# ..          ...    ...     ...         ...   ...    ...
# 468        52.0  -12.0   -11.0         -11 -11.0  -16.0
# 469        81.0    8.0     9.0           7  15.0   24.0
# 470        59.0  -22.0   -24.0         -15 -10.0  -32.0
# 471        99.0   14.0    13.0          12  16.0   16.0
# 472        52.0   19.0    22.0          17  21.0   10.0
#
# [473 rows x 11 columns]

# %%
for index, row in dfe.iterrows():
    line = row['predict_kp']
    dk = row['draft_kings']
    score = row['score']
    win = -99
    if line > dk:
        if score > dk:
            win = 1
        elif score < dk:
            win = 0
        else:
            win = 2
    elif line < dk:
        if score < dk:
            win = 1
        elif score > dk:
            win = 0
        else:
            win = 2
    else:
        win = 2
    
    
    dfe.loc[index,'win_kp'] = win

# %%
for index, row in dfe.iterrows():
    line = row['lasso']
    dk = row['draft_kings']
    score = row['score']
    win = -99
    if line > dk:
        if score > dk:
            win = 1
        elif score < dk:
            win = 0
        else:
            win = 2
    elif line < dk:
        if score < dk:
            win = 1
        elif score > dk:
            win = 0
        else:
            win = 2
    else:
        win = 2
    
    
    dfe.loc[index,'win_lasso'] = win

# %%
for index, row in dfe.iterrows():
    line = row['linear']
    dk = row['draft_kings']
    score = row['score']
    win = -99
    if line > dk:
        if score > dk:
            win = 1
        elif score < dk:
            win = 0
        else:
            win = 2
    elif line < dk:
        if score < dk:
            win = 1
        elif score > dk:
            win = 0
        else:
            win = 2
    else:
        win = 2
    
    
    dfe.loc[index,'win_lin'] = win

# %%
for index, row in dfe.iterrows():
    line = row['rf']
    dk = row['draft_kings']
    score = row['score']
    win = -99
    if line > dk:
        if score > dk:
            win = 1
        elif score < dk:
            win = 0
        else:
            win = 2
    elif line < dk:
        if score < dk:
            win = 1
        elif score > dk:
            win = 0
        else:
            win = 2
    else:
        win = 2
    
    
    dfe.loc[index,'win_rf'] = win

# %%
dfe['diff_kp'] = abs(dfe['predict_kp'] - dfe['draft_kings'])
dfe = dfe.sort_values(by=['diff_kp'], ascending = False)

# %%
dfe
# Out:
#                     away  away_score        date  draft_kings  \
# 421           Oregon St.        75.0  2021-01-23          8.5
# 310           High Point        54.0  2021-01-20         -2.0
# 430         San Jose St.        83.0  2021-01-23         10.0
# 15           Alabama St.        64.0  2021-01-12         -9.0
# 78   Cal St. Bakersfield        60.0  2021-01-15          2.0
# ..                   ...         ...         ...          ...
# 418     Western Carolina        78.0  2021-01-23          8.0
# 415     Northwestern St.        73.0  2021-01-23          1.0
# 279             Ball St.        71.0  2021-01-19         -3.0
# 181               Lehigh        70.0  2021-01-16          4.0
# 472              Fordham        42.0  2021-01-24         17.0
#
#                        home  home_score  lasso  linear  predict_kp    rf  \
# 421                  Oregon        64.0    NaN     NaN          15   NaN
# 310                Longwood        67.0    2.0     0.0           3   9.0
# 430              New Mexico        71.0    NaN     NaN           5   NaN
# 15   Mississippi Valley St.        51.0    4.0    -0.0          -5   2.0
# 78                   Hawaii        55.0  -12.0    12.0          -2  -6.0
# ..                      ...         ...    ...     ...         ...   ...
# 418                 Wofford        91.0    NaN     NaN           8   NaN
# 415  Southeastern Louisiana        68.0    NaN     NaN           1   NaN
# 279                Miami OH        81.0   -2.0    -2.0          -3  -3.0
# 181                Bucknell        75.0    3.0   -11.0           4  12.0
# 472            Rhode Island        52.0   19.0    22.0          17  21.0
#
#      score  win_kp  win_lasso  win_lin  win_rf  diff_kp
# 421  -11.0     0.0        2.0      2.0     2.0      6.5
# 310   13.0     1.0        1.0      1.0     1.0      5.0
# 430  -12.0     1.0        2.0      2.0     2.0      5.0
# 15   -13.0     0.0        0.0      0.0     0.0      4.0
# 78    -5.0     1.0        1.0      0.0     1.0      4.0
# ..     ...     ...        ...      ...     ...      ...
# 418   13.0     2.0        2.0      2.0     2.0      0.0
# 415   -5.0     2.0        2.0      2.0     2.0      0.0
# 279   10.0     2.0        1.0      1.0     2.0      0.0
# 181    5.0     2.0        0.0      0.0     1.0      0.0
# 472   10.0     2.0        0.0      0.0     0.0      0.0
#
# [473 rows x 16 columns]

# %%
dfe['win_kp'].value_counts(sort = True)
# Out:
# 0.0    205
# 1.0    194
# 2.0     74
# Name: win_kp, dtype: int64

# %%
dfe['win_lasso'].value_counts(sort = True)
# Out:
# 1.0    179
# 0.0    174
# 2.0    120
# Name: win_lasso, dtype: int64

# %%
dfe['win_lin'].value_counts(sort = True)
# Out:
# 1.0    178
# 0.0    174
# 2.0    121
# Name: win_lin, dtype: int64

# %%
dfe['win_rf'].value_counts(sort = True)
# Out:
# 1.0    180
# 0.0    169
# 2.0    124
# Name: win_rf, dtype: int64

# %%
dfe[dfe['diff_kp'] > 3]['win_kp'].value_counts(sort = True)
# Out:
# 0.0    11
# 1.0     9
# 2.0     1
# Name: win_kp, dtype: int64
