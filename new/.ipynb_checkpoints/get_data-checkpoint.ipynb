# %%
from datetime import datetime
from datetime import timedelta
from sportsreference.ncaab.boxscore import Boxscores
from sportsreference.ncaab.teams import Teams
import pandas as pd
import csv
import os
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from csv import reader
from csv import writer
import time
path = os.getcwd()
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
def get_yesterday():
    today = datetime.today()
    yesterday = today - timedelta(days = 1)
    year = yesterday.year
    month = yesterday.month
    day = yesterday.day
    return year,month,day

# %%
def get_today():
    today = datetime.today()
    year = today.year
    month = today.month
    day = today.day
    return year,month,day

# %%
pd.set_option('display.max_columns', None)

# %%
options = webdriver.ChromeOptions() 
#options.add_argument(r'''user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data''')
#"user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data" home
# "user-data-dir=C:\Users\koric1\AppData\Local\Google\Chrome\User Data" work
#options.add_argument("--start-maximized")
#self.options.add_argument("--headless")
#self.options.add_argument("--no-sandbox")
#self.options.add_argument("--disable-gpu")
options.add_argument('--headless')
options.add_argument('--disable-gpu')  # Last I checked this was necessa
driver = webdriver.Chrome(chrome_options= options)



#writer.writerow(["SN", "Name", "Contribution"])
driver.get('https://kenpom.com/')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="login"]/input[1]').send_keys('tarik0219@yahoo.com')
driver.find_element_by_xpath('//*[@id="login"]/input[2]').send_keys('kenporn123')
driver.find_element_by_xpath('//*[@id="login"]/input[3]').click()


teams = []
confs = []
adj_off = []
adj_def = []
adj_tempo = []
poss_off = []
poss_def = []
fg_off = []
fg_def = []
turnover_off = []
turnover_def = []
reb_off = []
reb_def = []
three_off = []
three_def = []
experience = []
height = []
wins_five = []
wins_last = []
for x in range(1,10):
    try:
        for z in range(1,41):
            team_name = str(driver.find_element_by_xpath('//*[@id="ratings-table"]/tbody['+str(x)+']/tr['+str(z)+']/td[2]/a').text)
            conf = str(driver.find_element_by_xpath('//*[@id="ratings-table"]/tbody['+str(x)+']/tr['+str(z)+']/td[3]/a').text)
            teams.append(team_name)
            confs.append(conf)
    except:
        break

for team in teams:
    print(team)
    team_list = team.split()
    new_team = ''
    for x in team_list:
        if x == '&':
            x = '%26'
        if x == 'A&M':
            x = 'A%26M'
        if x == 'A&T':
            x = 'A%26T'
        new_team = new_team + '+' + x
    
    new_team = new_team[1:]
    driver.get('https://kenpom.com/team.php?team='+new_team)
    #time.sleep(1)
    adj_off.append(float(driver.find_element_by_xpath('//*[@id="OE"]/a').text))
    adj_def.append(float(driver.find_element_by_xpath('//*[@id="DE"]/a').text))
    adj_tempo.append(float(driver.find_element_by_xpath('//*[@id="Tempo"]/span/a').text))
    poss_off.append(float(driver.find_element_by_xpath('//*[@id="APLO"]/a').text))
    poss_def.append(float(driver.find_element_by_xpath('//*[@id="APLD"]/a').text))           
    fg_off.append(float(driver.find_element_by_xpath('//*[@id="eFG"]/a').text))
    fg_def.append(float(driver.find_element_by_xpath('//*[@id="DeFG"]/a').text))
    turnover_off.append(float(driver.find_element_by_xpath('//*[@id="TOPct"]/a').text))
    turnover_def.append(float(driver.find_element_by_xpath('//*[@id="DTOPct"]/a').text))
    reb_off.append(float(driver.find_element_by_xpath('//*[@id="ORPct"]/a').text))
    reb_def.append(float(driver.find_element_by_xpath('//*[@id="DORPct"]/a').text))
    three_off.append(float(driver.find_element_by_xpath('//*[@id="3Pct"]/a').text))
    three_def.append(float(driver.find_element_by_xpath('//*[@id="D3Pct"]/a').text))
    experience.append(str(driver.find_element_by_xpath('//*[@id="report-table"]/tbody[2]/tr[29]/td[2]/a').text))
    height.append(str(driver.find_element_by_xpath('//*[@id="report-table"]/tbody[2]/tr[31]/td[2]/a').text))
    
    try:
        z = 1
        none = driver.find_element_by_xpath('//*[@id="schedule-table"]/tbody[2]/tr['+str(z)+']/td[7]').text
        wins_team = []
        while(none == ' ' or none == 'OT' or none == '2OT' or none =='3OT' or none == '4OT' or none == '5OT'):
            wins_team.append(str(driver.find_element_by_xpath('//*[@id="schedule-table"]/tbody[2]/tr['+str(z)+']/td[5]').text).split(',')[0])
            z += 1
            none = driver.find_element_by_xpath('//*[@id="schedule-table"]/tbody[2]/tr['+str(z)+']/td[7]').text
        wins_five.append(wins_team[-5:].count('W'))
        wins_last.append(wins_team[-1].count('W'))
    except:
        wins_five.append(0)
        wins_last.append(0)
driver.close()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()
# Baylor
# Gonzaga
# Michigan
# Iowa
# Houston
# Villanova
# Virginia
# Illinois
# Alabama
# Texas
# Wisconsin
# Texas Tech
# Florida St.
# Creighton
# Ohio St.
# Kansas
# West Virginia
# Colorado
# Tennessee
# Oklahoma
# USC
# Loyola Chicago
# Indiana
# Florida
# Arizona
# Connecticut
# UCLA
# San Diego St.
# Minnesota
# Oregon
# Purdue
# Arkansas
# Oklahoma St.
# North Carolina
# Missouri
# Duke
# LSU
# Louisville
# Virginia Tech
# Rutgers
# Saint Louis
# Penn St.
# Seton Hall
# Maryland
# Syracuse
# Michigan St.
# Stanford
# Utah St.
# Clemson
# BYU
# Xavier
# SMU
# St. Bonaventure
# Drake
# Auburn
# Kentucky
# Richmond
# Memphis
# Georgia Tech
# Providence
# VCU
# Mississippi
# Davidson
# Boise St.
# Rhode Island
# Colorado St.
# Toledo
# Marquette
# Pittsburgh
# N.C. State
# Wright St.
# Northwestern
# South Carolina
# Arizona St.
# Utah
# Saint Mary's
# Marshall
# Mississippi St.
# St. John's
# Wichita St.
# San Francisco
# Dayton
# Western Kentucky
# Notre Dame
# Cincinnati
# Furman
# Butler
# Tulsa
# UC Santa Barbara
# Belmont
# North Texas
# UAB
# TCU
# Boston College
# South Dakota St.
# UCF
# Abilene Christian
# Georgia
# Louisiana Tech
# Vermont
# Yale
# Kent St.
# South Florida
# Colgate
# DePaul
# Liberty
# Winthrop
# Duquesne
# Massachusetts
# Georgetown
# Iowa St.
# Buffalo
# Miami FL
# UC Irvine
# UNC Greensboro
# Wake Forest
# Bradley
# Missouri St.
# Loyola Marymount
# Ohio
# Akron
# New Mexico St.
# UNLV
# Nevada
# Nebraska
# Texas A&M
# Oregon St.
# Pepperdine
# Wofford
# Georgia St.
# Pacific
# Temple
# Bowling Green
# UC Riverside
# Washington St.
# Washington
# Grand Canyon
# Eastern Washington
# Cal St. Bakersfield
# East Tennessee St.
# California
# Indiana St.
# Vanderbilt
# Siena
# Santa Clara
# George Mason
# Ball St.
# Princeton
# East Carolina
# Northern Iowa
# Old Dominion
# Texas St.
# North Dakota St.
# Northeastern
# Drexel
# Mercer
# Murray St.
# Harvard
# Coastal Carolina
# Little Rock
# Stephen F. Austin
# Miami OH
# Eastern Kentucky
# Saint Peter's
# Monmouth
# Charlotte
# Montana
# Cleveland St.
# Louisiana
# Navy
# UTEP
# South Dakota
# Hofstra
# La Salle
# Kansas St.
# Appalachian St.
# Oral Roberts
# Army
# Bryant
# UMBC
# Fresno St.
# Florida Atlantic
# Wyoming
# Gardner Webb
# Montana St.
# Sam Houston St.
# San Diego
# Chattanooga
# Jacksonville St.
# VMI
# Morehead St.
# Rice
# Nicholls St.
# Weber St.
# UT Arlington
# Penn
# Cornell
# Detroit
# Southern Illinois
# Southern Utah
# James Madison
# Tulane
# UC Davis
# UTSA
# UNC Wilmington
# Valparaiso
# Saint Joseph's
# Radford
# Austin Peay
# George Washington
# Lafayette
# Hawaii
# South Alabama
# Bellarmine
# Iona
# Northern Colorado
# UC San Diego
# FIU
# UT Rio Grande Valley
# Charleston
# Albany
# Milwaukee
# Lipscomb
# Hartford
# Sacramento St.
# Elon
# Illinois Chicago
# Brown
# Northern Kentucky
# UMKC
# Western Carolina
# UMass Lowell
# Purdue Fort Wayne
# Mount St. Mary's
# Delaware
# Niagara
# Canisius
# Stetson
# Texas Southern
# UNC Asheville
# Oakland
# New Hampshire
# NJIT
# Green Bay
# Youngstown St.
# Illinois St.
# North Alabama
# Utah Valley
# American
# Stony Brook
# Loyola MD
# Towson
# Southern Miss
# Central Michigan
# LIU
# Norfolk St.
# Robert Morris
# Samford
# Boston University
# Georgia Southern
# Prairie View A&M
# Longwood
# North Carolina Central
# Eastern Michigan
# Bucknell
# Nebraska Omaha
# Campbell
# Morgan St.
# Dartmouth
# St. Francis PA
# Middle Tennessee
# Cal Baptist
# Fordham
# Quinnipiac
# Florida Gulf Coast
# Marist
# Eastern Illinois
# Evansville
# Columbia
# Wagner
# New Mexico
# St. Francis NY
# The Citadel
# Long Beach St.
# Seattle
# Western Michigan
# Southern
# Portland St.
# Arkansas St.
# Troy
# Florida A&M
# Idaho St.
# William & Mary
# North Florida
# IUPUI
# Jackson St.
# Central Arkansas
# North Dakota
# Merrimack
# Cal St. Northridge
# Tennessee St.
# High Point
# SIU Edwardsville
# Cal St. Fullerton
# Rider
# Fairleigh Dickinson
# Manhattan
# New Orleans
# Louisiana Monroe
# Jacksonville
# Howard
# Lehigh
# Air Force
# Portland
# North Carolina A&T
# Hampton
# Northern Illinois
# Northwestern St.
# USC Upstate
# Tennessee Tech
# Sacred Heart
# Southeast Missouri St.
# Grambling St.
# Coppin St.
# San Jose St.
# Northern Arizona
# Lamar
# Southeastern Louisiana
# Tarleton St.
# Alabama A&M
# Fairfield
# Western Illinois
# Houston Baptist
# Dixie St.
# Texas A&M Corpus Chris
# Central Connecticut
# Incarnate Word
# Holy Cross
# Alcorn St.
# Denver
# Maine
# Presbyterian
# Charleston Southern
# Cal Poly
# McNeese St.
# Binghamton
# Kennesaw St.
# Bethune Cookman
# Idaho
# Tennessee Martin
# Delaware St.
# Alabama St.
# Arkansas Pine Bluff
# Maryland Eastern Shore
# South Carolina St.
# Chicago St.
# Mississippi Valley St.

# %%
new_experience = []
new_height = []
for i,team in enumerate(experience):
    new_experience.append(float(experience[i][:-4]))
    new_height.append(float(height[i][:-1]))

# %%
kp = pd.DataFrame(list(zip(teams,confs,adj_off,adj_def,adj_tempo,poss_off,poss_def,fg_off,fg_def,turnover_off,turnover_def,reb_off,reb_def,three_off,three_def,new_experience,new_height,wins_five,wins_last)), columns =['teams','conf','adj_off','adj_def','adj_tempo','poss_off','poss_def','fg_off','fg_def','turnover_off','turnover_def','reb_off','reb_def','three_off','three_def','experience','height','wins_five','wins_last'])
kp
# Out:
#                       teams  conf  adj_off  adj_def  adj_tempo  poss_off  \
# 0                    Baylor   B12    121.3     86.7       69.5      15.9
# 1                   Gonzaga   WCC    124.4     90.3       74.9      14.2
# 2                  Michigan   B10    117.0     88.8       68.3      16.8
# 3                      Iowa   B10    124.6     97.6       71.1      15.7
# 4                   Houston  Amer    113.5     87.4       66.2      19.2
# ..                      ...   ...      ...      ...        ...       ...
# 352     Arkansas Pine Bluff  SWAC     88.9    114.5       69.0      18.3
# 353  Maryland Eastern Shore  MEAC     84.4    110.2       68.5       0.0
# 354      South Carolina St.  MEAC     85.5    112.7       72.8      16.4
# 355             Chicago St.   WAC     88.0    116.9       68.3      17.8
# 356  Mississippi Valley St.  SWAC     81.0    121.6       70.3      16.9
#
#      poss_def  fg_off  fg_def  turnover_off  turnover_def  reb_off  reb_def  \
# 0        17.5    59.2    46.0          17.6          26.5     38.5     29.1
# 1        17.5    60.4    46.9          15.4          20.0     34.0     24.3
# 2        17.7    57.6    43.0          18.4          15.5     30.4     25.1
# 3        17.1    56.4    48.6          13.7          17.8     34.3     30.1
# 4        16.5    48.4    41.6          18.2          23.8     41.1     26.6
# ..        ...     ...     ...           ...           ...      ...      ...
# 352      15.5    41.8    57.3          22.8          16.2     25.9     30.8
# 353       0.0     0.0   100.0         100.0           0.0      0.0    100.0
# 354      16.3    43.7    56.6          24.4          21.9     25.3     34.6
# 355      16.0    41.3    60.1          21.7          16.2     16.6     37.9
# 356      15.9    41.9    59.8          23.7          15.4     16.7     39.6
#
#      three_off  three_def  experience  height  wins_five  wins_last
# 0         44.0       31.4        1.95    76.6          5          1
# 1         35.3       33.9        1.48    78.3          5          1
# 2         37.7       32.2        2.08    77.9          4          1
# 3         38.4       34.8        1.68    77.8          4          0
# 4         33.9       26.1        1.77    77.0          5          1
# ..         ...        ...         ...     ...        ...        ...
# 352       30.9       43.2        2.26    75.8          1          0
# 353        0.0      100.0        0.00     0.0          0          0
# 354       32.6       34.3        1.09    76.5          0          0
# 355       25.1       39.5        1.88    75.6          0          0
# 356       31.2       37.4        1.32    76.1          0          0
#
# [357 rows x 19 columns]

# %%
year,month,day = get_today()
name = path+"\\kenpom\\"+str(year)+"_"+str(month)+"_"+str(day)+"_kenpom.csv"
kp.to_csv(name, index = False)

# %%
options = webdriver.ChromeOptions() 
#options.add_argument(r'''user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data''')
#"user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data" home
# "user-data-dir=C:\Users\koric1\AppData\Local\Google\Chrome\User Data" work
#options.add_argument("--start-maximized")
#self.options.add_argument("--headless")
#self.options.add_argument("--no-sandbox")
#self.options.add_argument("--disable-gpu")
options.add_argument('--headless')
options.add_argument('--disable-gpu')  # Last I checked this was necessa
driver = webdriver.Chrome(chrome_options= options)



#writer.writerow(["SN", "Name", "Contribution"])
driver.get('https://kenpom.com/')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="login"]/input[1]').send_keys('tarik0219@yahoo.com')
driver.find_element_by_xpath('//*[@id="login"]/input[2]').send_keys('kenporn123')
driver.find_element_by_xpath('//*[@id="login"]/input[3]').click()
driver.get('https://kenpom.com/fanmatch.php')
x = 1
home = []
away = []
predict = []
while(True):
    try:
        away.append(str(driver.find_element_by_xpath('//*[@id="fanmatch-table"]/tbody/tr['+str(x)+']/td[1]/a[1]').text))
        home.append((driver.find_element_by_xpath('//*[@id="fanmatch-table"]/tbody/tr['+str(x)+']/td[1]/a[2]').text))
        predict.append((driver.find_element_by_xpath('//*[@id="fanmatch-table"]/tbody/tr['+str(x)+']/td[2]').text))
        x+=1
    except:
        break
driver.close()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()

# %%
score = []
for i,x in enumerate(predict):
    team = home[i]
    list_1 = x.split()
    team_compare = ''
    num = len(list_1) - 2
    
    for i in range(0,num):
        team_compare = team_compare + ' '+ list_1[i]
    team_compare = team_compare[1:]
    if team_compare == team:
        list_2 = list_1[-2].split('-')
        score.append(int(list_2[0]) - int(list_2[1]))
    else:
        list_2 = list_1[-2].split('-')
        score.append(int(list_2[1]) - int(list_2[0]))

# %%
games = pd.DataFrame(list(zip(home,away,score)), columns =['home','away','predict_kp'])
year,month,day = get_today()
name = path+"\\games\\"+str(year)+"_"+str(month)+"_"+str(day)+"_games.csv"
games.to_csv(name, index = False)
games['date'] = str(year)+'-'+str("{0:0=2d}".format(month))+'-'+str("{0:0=2d}".format(day))
games
# Out:
#                       home               away  predict_kp        date
# 0                  Rutgers       Michigan St.           3  2021-01-28
# 1                  Arizona           Stanford           4  2021-01-28
# 2                      SMU            Memphis           2  2021-01-28
# 3                   Kansas                TCU          12  2021-01-28
# 4                     Rice        North Texas          -5  2021-01-28
# 5                     UTSA               UTEP           1  2021-01-28
# 6              Arizona St.         California           9  2021-01-28
# 7               Valparaiso            Bradley          -4  2021-01-28
# 8              Austin Peay            Belmont          -6  2021-01-28
# 9         Jacksonville St.       Morehead St.           2  2021-01-28
# 10                     USC         Oregon St.          13  2021-01-28
# 11            San Jose St.          Air Force          -1  2021-01-28
# 12  Southeast Missouri St.   SIU Edwardsville           1  2021-01-28
# 13           Southern Miss     Louisiana Tech          -8  2021-01-28
# 14        Northern Arizona  Northern Colorado          -3  2021-01-28
# 15      Eastern Washington     Sacramento St.           8  2021-01-28
# 16        Middle Tennessee                UAB          -9  2021-01-28
# 17        Tennessee Martin   Eastern Illinois          -6  2021-01-28
# 18              Fresno St.         New Mexico           7  2021-01-28
# 19                  Tulane            Houston         -17  2021-01-28
# 20               San Diego            Gonzaga         -25  2021-01-28
# 21                Winthrop      UNC Asheville          12  2021-01-28
# 22           San Diego St.            Wyoming          16  2021-01-28
# 23              Murray St.      Tennessee St.          11  2021-01-28
# 24                   Idaho          Weber St.         -10  2021-01-28
# 25            Saint Mary's           Portland          18  2021-01-28

# %%
predict = pd.merge(games, kp, how='left', left_on='home', right_on='teams')
predict.drop(['teams'], axis = 1, inplace = True)
predict = pd.merge(predict, kp, how='left', left_on='away', right_on='teams')
predict.drop(['teams'], axis = 1, inplace = True)
year,month,day = get_today()
name = path+"\\predict\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict.csv"
predict.to_csv(name, index = False)
predict
# Out:
#                       home                 away  predict_kp        date  \
# 0               Seton Hall            Creighton          -2  2021-01-27
# 1                 Maryland            Wisconsin          -2  2021-01-27
# 2                  Clemson           Louisville           1  2021-01-27
# 3                 Arkansas          Mississippi           3  2021-01-27
# 4               Notre Dame        Virginia Tech          -1  2021-01-27
# 5             Colorado St.            Boise St.          -1  2021-01-27
# 6                 Ohio St.             Penn St.           7  2021-01-27
# 7               Providence            Marquette           3  2021-01-27
# 8                   DePaul           St. John's           1  2021-01-27
# 9           South Carolina              Georgia           3  2021-01-27
# 10            Missouri St.                Drake          -5  2021-01-27
# 11                    UNLV             Utah St.          -5  2021-01-27
# 12              Pepperdine                  BYU          -7  2021-01-27
# 13                Kent St.        Bowling Green           5  2021-01-27
# 14              N.C. State          Wake Forest           7  2021-01-27
# 15                La Salle         Rhode Island          -8  2021-01-27
# 16          UNC Greensboro               Mercer           5  2021-01-27
# 17                     UCF        East Carolina           6  2021-01-27
# 18       Abilene Christian    Stephen F. Austin           5  2021-01-27
# 19             Florida St.             Miami FL          13  2021-01-27
# 20                     VMI     Western Carolina           2  2021-01-27
# 21           James Madison               Towson           3  2021-01-27
# 22        Northwestern St.          New Orleans           1  2021-01-27
# 23  Southeastern Louisiana     Central Arkansas          -3  2021-01-27
# 24                 Fordham             Duquesne          -7  2021-01-27
# 25          St. Francis PA  Fairleigh Dickinson           4  2021-01-27
# 26                Colorado       Washington St.          15  2021-01-27
# 27                 Florida           Vanderbilt          15  2021-01-27
# 28          Incarnate Word      Houston Baptist           4  2021-01-27
# 29                     LIU            Merrimack           6  2021-01-27
# 30             The Citadel              Wofford         -10  2021-01-27
# 31  Texas A&M Corpus Chris      Sam Houston St.          -7  2021-01-27
# 32                  Baylor           Kansas St.          25  2021-01-27
# 33            Nicholls St.          McNeese St.          14  2021-01-27
#
#    conf_x  adj_off_x  adj_def_x  adj_tempo_x  poss_off_x  poss_def_x  \
# 0      BE      112.6       96.2         67.7        17.1        17.7
# 1     B10      112.4       95.8         66.2        17.8        18.5
# 2     ACC      107.0       91.7         66.1        17.4        18.4
# 3     SEC      110.5       93.3         73.4        15.4        15.9
# 4     ACC      112.9      102.2         67.1        17.8        18.4
# 5     MWC      108.0       97.1         70.6        16.2        17.6
# 6     B10      118.3       95.4         66.6        18.2        17.4
# 7      BE      110.5       96.7         66.9        17.9        17.4
# 8      BE      102.6       94.8         72.9        15.3        18.0
# 9     SEC      106.7       96.3         74.2        15.6        16.9
# 10    MVC      105.2      100.4         71.5        16.6        16.6
# 11    MWC      104.4       99.6         68.5        17.5        16.8
# 12    WCC      103.9      100.7         71.1        15.6        17.6
# 13    MAC      106.7      100.3         71.5        17.3        16.4
# 14    ACC      109.5       96.9         69.7        16.5        17.3
# 15    A10      100.1      100.9         69.1        16.7        17.5
# 16     SC      102.5       97.2         68.5        16.7        16.7
# 17   Amer      103.5       96.5         66.2        17.6        18.0
# 18   Slnd       98.3       92.8         68.6        17.2        16.3
# 19    ACC      115.1       92.8         69.7        17.1        17.1
# 20     SC      105.6      110.5         69.9        16.6        17.0
# 21    CAA      101.4      106.1         71.8        15.8        17.2
# 22   Slnd       95.9      109.6         71.6        16.5        15.9
# 23   Slnd       93.3      109.9         68.8        17.6        16.3
# 24    A10       89.0       96.9         63.6        19.0        18.7
# 25    NEC       97.6      106.6         70.3        16.7        16.5
# 26    P12      114.4       92.5         67.4        17.0        18.4
# 27    SEC      113.1       93.5         70.5        16.1        17.2
# 28   Slnd       94.8      110.3         66.4        17.9        16.8
# 29    NEC       95.9      103.1         74.5        14.7        17.2
# 30     SC      101.6      113.2         77.2        14.5        16.6
# 31   Slnd       91.3      107.5         68.6        17.4        16.9
# 32    B12      120.6       86.8         68.8        16.1        17.5
# 33   Slnd      100.0      103.0         71.4        16.2        16.3
#
#     fg_off_x  fg_def_x  turnover_off_x  turnover_def_x  reb_off_x  reb_def_x  \
# 0       52.7      50.1            19.2            18.2       27.8       28.5
# 1       53.2      50.6            16.3            16.3       23.9       25.3
# 2       49.0      50.5            19.5            24.2       28.0       27.9
# 3       51.7      47.4            17.0            20.0       34.0       24.5
# 4       54.0      51.5            16.3            12.7       20.7       28.1
# 5       55.7      47.2            19.1            20.1       19.6       26.6
# 6       52.1      47.8            15.2            16.0       31.2       26.3
# 7       49.9      49.9            17.4            17.3       30.7       30.1
# 8       49.2      48.0            22.2            21.5       30.2       29.5
# 9       48.2      52.7            20.7            21.8       35.0       27.9
# 10      56.8      45.8            18.6            14.2       22.5       22.5
# 11      50.3      50.6            19.9            20.0       26.0       26.7
# 12      48.9      50.3            18.5            18.5       22.2       29.3
# 13      53.4      48.3            19.8            17.5       36.6       27.8
# 14      53.2      52.4            17.3            24.0       28.4       31.8
# 15      51.3      50.2            21.2            19.9       23.7       29.3
# 16      47.3      46.7            17.7            21.2       35.7       26.4
# 17      46.2      49.9            20.6            20.0       28.9       32.5
# 18      50.6      43.2            20.1            29.2       28.1       30.6
# 19      54.7      46.7            19.4            20.4       34.5       30.3
# 20      54.0      53.1            17.5            14.5       23.8       28.1
# 21      51.0      50.9            18.5            21.7       25.4       29.4
# 22      46.4      53.7            19.5            17.0       24.6       32.6
# 23      43.7      55.3            23.7            21.7       32.5       30.9
# 24      39.9      51.3            20.6            20.2       22.1       30.9
# 25      47.3      50.6            19.7            19.2       28.2       32.1
# 26      51.8      47.4            15.8            20.5       31.5       24.6
# 27      53.5      47.9            19.6            21.5       32.8       30.8
# 28      53.1      51.9            21.4            18.8       23.3       33.3
# 29      48.8      48.5            20.6            24.1       32.6       30.2
# 30      54.3      54.6            16.9            14.5       25.2       27.9
# 31      44.2      50.5            25.5            18.7       24.8       31.0
# 32      58.4      46.4            17.7            26.5       38.3       30.0
# 33      50.5      49.4            17.9            21.4       29.3       28.7
#
#     three_off_x  three_def_x  experience_x  height_x  wins_five_x  \
# 0          33.5         36.7          2.36      79.2            3
# 1          35.5         35.9          1.84      78.4            3
# 2          32.3         36.7          1.76      76.9            2
# 3          34.3         31.3          1.57      77.9            3
# 4          38.4         36.3          2.16      78.7            2
# 5          39.1         29.7          1.18      75.8            4
# 6          34.5         32.6          1.97      77.5            4
# 7          32.4         31.8          1.87      78.1            1
# 8          33.1         29.8          1.87      76.8            2
# 9          31.3         35.0          1.64      77.5            2
# 10         33.9         33.7          1.62      77.5            4
# 11         34.9         36.5          1.59      77.4            5
# 12         31.3         29.4          1.92      76.7            2
# 13         34.8         33.1          2.26      77.2            4
# 14         36.4         35.6          1.76      77.0            1
# 15         36.3         29.5          1.37      76.6            2
# 16         27.8         30.6          1.74      77.3            4
# 17         33.7         32.9          1.45      77.6            0
# 18         35.2         24.9          2.22      75.0            4
# 19         39.1         33.1          1.98      79.6            4
# 20         38.7         37.3          1.56      76.4            2
# 21         34.5         31.2          1.33      76.3            4
# 22         31.8         33.6          2.02      75.0            2
# 23         27.4         36.0          1.83      76.9            2
# 24         25.6         33.5          1.64      75.8            0
# 25         31.2         27.9          1.29      76.9            2
# 26         35.2         32.9          2.31      77.3            4
# 27         37.2         34.4          1.51      77.3            3
# 28         40.6         28.7          1.17      75.9            3
# 29         28.6         33.8          1.76      76.3            3
# 30         37.4         33.1          1.86      76.5            1
# 31         30.3         32.4          2.23      76.0            2
# 32         42.6         32.0          1.96      76.6            5
# 33         31.8         33.8          2.48      76.1            5
#
#     wins_last_x conf_y  adj_off_y  adj_def_y  adj_tempo_y  poss_off_y  \
# 0             0     BE      115.4       93.0         70.1        15.8
# 1             1    B10      112.7       89.2         64.8        18.3
# 2             0    ACC      111.2       94.0         66.4        17.4
# 3             1    SEC      105.3       90.3         66.9        17.5
# 4             1    ACC      110.5       94.4         66.3        17.9
# 5             1    MWC      110.3       95.5         69.5        16.0
# 6             1    B10      112.4       96.3         69.5        16.5
# 7             0     BE      110.1       97.0         67.4        18.1
# 8             1     BE      109.1       99.3         74.1        14.5
# 9             0    SEC      106.9       98.6         73.9        15.3
# 10            0    MVC      109.9       95.7         67.5        17.0
# 11            1    MWC      103.8       89.0         70.0        16.7
# 12            0    WCC      108.9       93.1         68.7        16.9
# 13            0    MAC      105.8      102.6         70.3        16.2
# 14            0    ACC      104.8       99.8         69.3        18.3
# 15            1    A10      105.7       93.1         70.3        16.8
# 16            1     SC      105.8      104.8         70.9        16.6
# 17            0   Amer       99.4       97.6         68.2        17.5
# 18            1   Slnd      102.2      101.0         70.9        16.5
# 19            1    ACC      102.5       95.6         68.9        18.0
# 20            0     SC      101.9      106.4         71.2        16.4
# 21            1    CAA      100.9      107.7         66.4        18.8
# 22            1   Slnd       96.5      108.3         71.6        16.7
# 23            0   Slnd       99.1      109.1         73.4        15.6
# 24            0    A10      101.7       96.2         68.0        17.3
# 25            0    NEC       99.5      111.5         70.6        16.5
# 26            1    P12       98.2       95.1         68.8        17.5
# 27            1    SEC      104.9      103.3         69.7        17.6
# 28            1   Slnd       95.0      113.0         72.1        16.3
# 29            0    NEC       92.2      104.6         68.4        16.9
# 30            0     SC      107.1      102.2         66.2        18.1
# 31            0   Slnd       99.8      102.7         71.9        16.1
# 32            1    B12      100.9      101.8         65.1        18.4
# 33            1   Slnd       97.3      116.0         70.2        16.7
#
#     poss_def_y  fg_off_y  fg_def_y  turnover_off_y  turnover_def_y  reb_off_y  \
# 0         17.9      57.1      45.7            15.5            18.1       23.8
# 1         17.9      51.4      45.9            12.6            17.8       23.1
# 2         18.6      52.0      47.9            18.6            18.0       30.2
# 3         16.9      49.4      47.2            19.8            25.0       33.2
# 4         17.9      52.1      48.5            17.8            18.2       31.0
# 5         17.8      53.8      44.9            15.1            20.8       32.0
# 6         17.5      50.1      52.8            17.0            20.0       34.6
# 7         16.9      51.3      47.0            20.3            15.6       32.7
# 8         17.3      50.5      55.2            16.8            23.4       29.1
# 9         16.6      51.3      51.5            21.6            22.6       34.5
# 10        17.9      57.8      44.9            17.0            21.7       34.3
# 11        17.3      50.1      45.3            20.3            21.6       35.2
# 12        16.4      52.8      45.5            19.8            16.9       29.1
# 13        16.7      48.5      51.0            15.1            19.6       29.8
# 14        16.2      52.6      52.7            21.3            21.1       27.3
# 15        16.8      50.4      45.9            20.9            18.1       29.6
# 16        16.6      55.3      49.6            17.7            15.9       28.9
# 17        17.2      46.2      47.1            20.0            21.1       27.0
# 18        16.0      58.2      53.8            24.6            26.5       34.8
# 19        16.3      47.4      50.3            20.0            18.8       28.6
# 20        17.0      52.0      52.7            20.2            17.4       24.8
# 21        16.3      46.4      51.1            20.2            14.8       35.5
# 22        15.9      49.4      54.0            22.4            21.8       29.6
# 23        16.0      48.7      52.8            25.4            15.0       28.3
# 24        18.2      46.2      46.2            20.0            19.7       30.1
# 25        17.0      49.9      54.2            20.4            19.0       28.4
# 26        16.8      47.8      44.4            21.1            17.7       27.9
# 27        16.7      50.6      52.7            19.6            17.5       30.3
# 28        15.7      50.8      55.0            24.1            17.8       23.7
# 29        18.5      49.7      51.8            16.9            22.2       21.5
# 30        17.3      56.5      50.8            20.4            18.3       30.3
# 31        15.9      49.2      50.0            22.0            21.6       30.0
# 32        17.8      48.8      54.8            23.0            19.2       32.2
# 33        15.9      52.9      58.7            22.9            17.6       24.2
#
#     reb_def_y  three_off_y  three_def_y  experience_y  height_y  wins_five_y  \
# 0        29.9         36.4         33.1          2.21      77.0            3
# 1        23.2         37.9         32.6          2.39      78.0            3
# 2        26.0         32.7         32.2          0.99      77.5            3
# 3        25.7         29.6         35.1          1.98      77.2            2
# 4        25.2         34.2         32.8          1.62      76.3            3
# 5        20.2         34.5         28.9          2.04      78.2            5
# 6        27.6         36.1         31.6          2.16      76.1            2
# 7        28.1         35.9         35.0          1.71      78.1            3
# 8        29.0         34.9         37.6          1.49      77.0            3
# 9        32.3         31.9         31.6          1.93      76.0            2
# 10       23.0         42.5         28.4          2.04      76.2            5
# 11       20.0         33.6         33.7          1.45      78.2            3
# 12       24.0         33.2         32.3          2.03      78.0            4
# 13       30.0         33.4         34.2          1.81      76.3            2
# 14       26.1         35.5         32.9          1.77      77.5            1
# 15       25.9         32.4         31.5          1.92      76.4            3
# 16       26.8         35.4         32.5          1.96      77.4            3
# 17       26.6         32.6         30.4          1.96      77.8            2
# 18       28.0         33.6         38.7          2.41      76.8            5
# 19       24.9         25.8         37.1          1.48      78.4            2
# 20       26.8         32.0         34.2          1.80      75.9            0
# 21       30.7         26.1         38.6          1.74      77.1            2
# 22       30.7         32.3         34.7          2.17      74.5            3
# 23       28.6         35.2         36.2          2.13      78.0            1
# 24       32.3         29.0         27.1          1.84      76.2            2
# 25       32.7         37.6         30.0          1.41      75.3            2
# 26       27.3         34.2         29.1          1.13      78.7            0
# 27       25.9         33.7         33.3          1.34      77.1            0
# 28       33.2         36.8         32.8          1.39      76.7            0
# 29       29.4         27.4         42.9          1.37      75.7            2
# 30       30.5         37.8         32.1          1.51      75.7            4
# 31       33.7         37.0         29.7          1.85      75.2            5
# 32       27.5         31.0         36.8          1.08      76.8            0
# 33       30.4         35.8         41.6          2.39      76.1            1
#
#     wins_last_y
# 0             1
# 1             0
# 2             1
# 3             1
# 4             0
# 5             1
# 6             1
# 7             0
# 8             1
# 9             0
# 10            1
# 11            0
# 12            1
# 13            0
# 14            1
# 15            1
# 16            1
# 17            0
# 18            1
# 19            0
# 20            0
# 21            0
# 22            0
# 23            0
# 24            0
# 25            1
# 26            0
# 27            0
# 28            0
# 29            1
# 30            1
# 31            1
# 32            0
# 33            1

# %%
year,month,day = get_yesterday()

# %%
options = webdriver.ChromeOptions() 
#options.add_argument(r'''user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data''')
#"user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data" home
# "user-data-dir=C:\Users\koric1\AppData\Local\Google\Chrome\User Data" work
#options.add_argument("--start-maximized")
#self.options.add_argument("--headless")
#self.options.add_argument("--no-sandbox")
#self.options.add_argument("--disable-gpu")
#options.add_argument('--headless')
#options.add_argument('--disable-gpu')  # Last I checked this was necessa
driver = webdriver.Chrome(chrome_options= options)



#writer.writerow(["SN", "Name", "Contribution"])
driver.get('https://kenpom.com/')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="login"]/input[1]').send_keys('tarik0219@yahoo.com')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="login"]/input[2]').send_keys('kenporn123')
time.sleep(1)
driver.find_element_by_xpath('//*[@id="login"]/input[3]').click()
time.sleep(1)
driver.get('https://kenpom.com/fanmatch.php?d='+str(year)+'-'+str("{0:0=2d}".format(month))+'-'+str("{0:0=2d}".format(day)))

x = 1
away = []
home = []
home_score = []
away_score = []
while(True):
    #if x == 5:
        #away.append('Georgia Tech')
        #home.append('Duke')
        #away_score.append(68)
        #home_score.append(75)
        #x += 1
    
    try:
        
        driver.find_element_by_xpath('//*[@id="fanmatch-table"]/tbody/tr['+str(x)+']/td[3]/a').click()
        away.append(str(driver.find_element_by_xpath('//*[@id="linescore-table2"]/tbody/tr[1]/td[1]').text))
        home.append(str(driver.find_element_by_xpath('//*[@id="linescore-table2"]/tbody/tr[2]/td[1]').text))
        

        y = 15
        while(True):
            try:
                w_s = driver.find_element_by_xpath('//*[@id="linescore-table2"]/tbody/tr[1]/td['+str(y)+']/b').text
                l_s = driver.find_element_by_xpath('//*[@id="linescore-table2"]/tbody/tr[2]/td['+str(y)+']/b').text
                away_score.append(int(w_s))
                home_score.append(int(l_s))
                break
            except:
                y -= 1
        driver.get('https://kenpom.com/fanmatch.php?d='+str(year)+'-'+str("{0:0=2d}".format(month))+'-'+str("{0:0=2d}".format(day)))
        
        x+=1
    except:
        break
driver.close()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()

# %%
scores = pd.DataFrame(list(zip(home,away,home_score, away_score)), columns =['home','away','home_score','away_score'])
scores['score'] = scores['home_score'] - scores['away_score']
scores['date'] = str(year)+'-'+str("{0:0=2d}".format(month))+'-'+str("{0:0=2d}".format(day))
scores
# Out:
#                 home                    away  home_score  away_score  score  \
# 0             Auburn                Missouri          88          82      6
# 1              Texas                Oklahoma          79          80     -1
# 2         Pittsburgh          North Carolina          65          75    -10
# 3            Memphis                     SMU          76          72      4
# 4               Duke            Georgia Tech          75          68      7
# 5            Alabama                Kentucky          70          59     11
# 6       Missouri St.                   Drake          61          68     -7
# 7          Texas A&M                     LSU          66          78    -12
# 8        Saint Louis                  Dayton          71          76     -5
# 9        Connecticut                  Butler          63          51     12
# 10            Temple                   Tulsa          76          67      9
# 11         Tennessee         Mississippi St.          56          53      3
# 12          Miami OH                  Toledo          81          90     -9
# 13    Saint Joseph's                Richmond          56          79    -23
# 14       Indiana St.       Southern Illinois          71          59     12
# 15    St. Francis PA     Fairleigh Dickinson          92          94     -2
# 16  Tennessee Martin  Southeast Missouri St.          69          66      3
# 17  Eastern Illinois        SIU Edwardsville          74          87    -13
# 18             Akron        Eastern Michigan          86          65     21
# 19              Ohio        Western Michigan          81          58     23
#
#           date
# 0   2021-01-26
# 1   2021-01-26
# 2   2021-01-26
# 3   2021-01-26
# 4   2021-01-26
# 5   2021-01-26
# 6   2021-01-26
# 7   2021-01-26
# 8   2021-01-26
# 9   2021-01-26
# 10  2021-01-26
# 11  2021-01-26
# 12  2021-01-26
# 13  2021-01-26
# 14  2021-01-26
# 15  2021-01-26
# 16  2021-01-26
# 17  2021-01-26
# 18  2021-01-26
# 19  2021-01-26

# %%
year,month,day = get_yesterday()
name = path+"\\kenpom\\"+str(year)+"_"+str(month)+"_"+str(day)+"_kenpom.csv"
kp_yesterday = pd.read_csv(name)

# %%
kp_scores = pd.merge(scores, kp_yesterday, how='left', left_on='home', right_on='teams')
kp_scores.drop(['teams'], axis = 1, inplace = True)
kp_scores = pd.merge(kp_scores, kp_yesterday, how='left', left_on='away', right_on='teams')
kp_scores.drop(['teams'], axis = 1, inplace = True)
year,month,day = get_yesterday()
name = path+"\\scores_kenpom\\"+str(year)+"_"+str(month)+"_"+str(day)+"_scores_kenpom.csv"
kp_scores.to_csv(name, index = False)
kp_scores
# Out:
#                 home                    away  home_score  away_score  score  \
# 0             Auburn                Missouri          88          82      6
# 1              Texas                Oklahoma          79          80     -1
# 2         Pittsburgh          North Carolina          65          75    -10
# 3            Memphis                     SMU          76          72      4
# 4               Duke            Georgia Tech          75          68      7
# 5            Alabama                Kentucky          70          59     11
# 6       Missouri St.                   Drake          61          68     -7
# 7          Texas A&M                     LSU          66          78    -12
# 8        Saint Louis                  Dayton          71          76     -5
# 9        Connecticut                  Butler          63          51     12
# 10            Temple                   Tulsa          76          67      9
# 11         Tennessee         Mississippi St.          56          53      3
# 12          Miami OH                  Toledo          81          90     -9
# 13    Saint Joseph's                Richmond          56          79    -23
# 14       Indiana St.       Southern Illinois          71          59     12
# 15    St. Francis PA     Fairleigh Dickinson          92          94     -2
# 16  Tennessee Martin  Southeast Missouri St.          69          66      3
# 17  Eastern Illinois        SIU Edwardsville          74          87    -13
# 18             Akron        Eastern Michigan          86          65     21
# 19              Ohio        Western Michigan          81          58     23
#
#           date conf_x  adj_off_x  adj_def_x  adj_tempo_x  poss_off_x  \
# 0   2021-01-26    SEC      110.4       96.1         71.6        16.3
# 1   2021-01-26    B12      114.1       89.4         69.3        16.3
# 2   2021-01-26    ACC      106.4       93.3         70.6        16.4
# 3   2021-01-26   Amer      102.8       88.2         71.9        15.8
# 4   2021-01-26    ACC      111.8       93.9         69.2        16.4
# 5   2021-01-26    SEC      114.6       90.3         74.6        14.2
# 6   2021-01-26    MVC      106.2      101.4         70.7        16.7
# 7   2021-01-26    SEC      100.3       95.1         64.9        17.8
# 8   2021-01-26    A10      110.9       93.1         68.5        16.1
# 9   2021-01-26     BE      110.7       92.2         64.4        19.2
# 10  2021-01-26   Amer      100.1       97.7         68.6        17.5
# 11  2021-01-26    SEC      109.8       88.0         66.1        17.3
# 12  2021-01-26    MAC      103.9      103.9         66.4        18.5
# 13  2021-01-26    A10      102.2      105.4         73.4        16.1
# 14  2021-01-26    MVC      101.6      100.1         69.0        17.2
# 15  2021-01-26    NEC       97.5      105.9         70.2        16.5
# 16  2021-01-26    OVC       94.2      115.4         69.8        17.5
# 17  2021-01-26    OVC       98.8      106.4         70.1        16.7
# 18  2021-01-26    MAC      105.1      100.8         68.8        17.1
# 19  2021-01-26    MAC      109.1      104.9         69.5        16.9
#
#     poss_def_x  fg_off_x  fg_def_x  turnover_off_x  turnover_def_x  reb_off_x  \
# 0         16.1      53.5      48.7            22.8            20.2       34.5
# 1         18.0      52.8      43.3            18.8            17.3       32.0
# 2         16.7      48.9      45.7            18.7            19.1       35.3
# 3         17.2      48.4      42.9            21.4            22.0       33.9
# 4         17.1      51.3      52.6            19.3            20.4       32.3
# 5         17.4      52.5      45.6            18.1            21.1       31.8
# 6         16.6      58.8      46.6            18.2            15.1       21.9
# 7         18.3      48.3      52.1            24.8            24.5       32.0
# 8         17.3      56.8      47.2            17.9            24.0       38.1
# 9         17.0      48.3      47.5            19.1            21.6       39.8
# 10        17.5      44.1      47.7            19.6            16.3       27.6
# 11        17.7      50.5      46.1            16.4            24.4       32.8
# 12        16.6      50.9      50.2            15.9            19.7       26.5
# 13        16.5      48.7      54.4            19.8            19.0       22.5
# 14        17.1      48.2      53.2            20.4            22.3       24.9
# 15        16.6      46.7      50.0            19.6            19.2       26.7
# 16        16.2      43.3      61.4            22.1            20.2       28.9
# 17        17.0      47.7      53.2            18.8            19.8       29.2
# 18        17.8      53.6      47.8            19.9            15.4       29.3
# 19        16.9      55.3      53.3            16.9            20.6       28.0
#
#     reb_def_x  three_off_x  three_def_x  experience_x  height_x  wins_five_x  \
# 0        30.2         33.8         30.4          0.78      78.7            3
# 1        27.4         35.2         28.7          1.91      77.9            4
# 2        26.9         31.7         28.5          1.21      77.7            3
# 3        23.7         33.5         27.2          1.10      77.8            3
# 4        24.7         33.2         37.4          0.87      76.9            2
# 5        30.2         36.2         29.7          1.90      77.9            5
# 6        23.0         35.6         34.1          1.61      77.5            5
# 7        30.3         29.3         33.8          1.57      77.4            1
# 8        22.9         41.0         32.9          1.84      76.2            4
# 9        29.9         35.1         30.3          1.97      78.1            3
# 10       27.2         32.9         36.5          1.61      77.5            2
# 11       26.8         33.9         31.2          1.63      77.5            3
# 12       30.0         38.1         32.5          1.96      75.1            4
# 13       33.8         30.0         38.1          1.16      78.0            1
# 14       28.3         33.9         33.6          1.85      76.7            4
# 15       31.4         31.3         26.1          1.26      76.8            2
# 16       30.7         31.6         41.3          1.59      76.9            0
# 17       27.3         32.7         39.7          2.59      76.7            0
# 18       26.9         33.6         29.6          1.93      75.6            4
# 19       28.5         37.1         36.2          1.45      77.0            3
#
#     wins_last_x conf_y  adj_off_y  adj_def_y  adj_tempo_y  poss_off_y  \
# 0             1    SEC      109.8       91.7         68.9        16.8
# 1             1    B12      112.7       93.0         68.9        16.8
# 2             0    ACC      109.4       91.8         71.4        15.7
# 3             1   Amer      111.7       96.4         70.3        15.7
# 4             0    ACC      111.3       97.0         66.4        17.9
# 5             1    SEC      105.7       90.6         67.0        17.4
# 6             1    MVC      110.6       97.2         67.0        17.0
# 7             0    SEC      117.0       99.9         70.9        15.9
# 8             1    A10      107.0       97.2         65.0        19.0
# 9             0     BE      104.4       95.1         65.4        19.6
# 10            0   Amer      102.7       93.4         65.4        17.6
# 11            0    SEC      108.6       98.3         65.7        18.4
# 12            1    MAC      113.9      101.8         67.7        17.4
# 13            0    A10      112.6       98.7         70.0        16.4
# 14            1    MVC      101.3      104.5         68.1        17.3
# 15            0    NEC       98.8      111.1         70.6        16.6
# 16            0    OVC       94.4      107.6         68.6        17.4
# 17            0    OVC       93.4      107.2         70.8        17.1
# 18            1    MAC       97.5      105.3         69.0        17.1
# 19            1    MAC       95.5      105.1         65.7        18.6
#
#     poss_def_y  fg_off_y  fg_def_y  turnover_off_y  turnover_def_y  reb_off_y  \
# 0         17.3      51.0      44.6            20.2            18.2       30.8
# 1         17.6      51.6      48.9            14.7            20.1       29.0
# 2         17.5      47.2      49.8            20.7            19.4       40.7
# 3         17.4      53.6      45.6            18.0            19.8       30.3
# 4         16.8      55.0      52.6            16.0            22.1       24.6
# 5         17.5      46.0      45.8            21.3            17.3       35.8
# 6         18.0      59.6      45.2            18.0            21.7       36.4
# 7         16.7      53.8      49.1            17.4            20.4       32.9
# 8         17.9      55.4      48.0            22.3            19.6       23.3
# 9         17.0      49.1      52.3            17.8            17.8       24.8
# 10        18.0      48.8      45.7            20.6            22.6       26.9
# 11        17.5      50.6      48.6            19.9            18.0       37.1
# 12        17.2      53.5      48.2            16.3            18.7       32.2
# 13        17.6      54.4      53.4            15.2            22.0       21.3
# 14        18.2      53.7      54.1            18.2            20.7       16.4
# 15        16.9      49.1      54.4            20.4            18.8       27.1
# 16        17.1      48.8      51.8            21.4            18.5       26.2
# 17        16.0      49.9      53.5            25.2            22.5       26.9
# 18        16.8      45.0      61.3            18.5            19.5       28.9
# 19        16.3      49.0      50.6            21.0            14.8       25.0
#
#     reb_def_y  three_off_y  three_def_y  experience_y  height_y  wins_five_y  \
# 0        30.4         29.0         28.6          2.51      77.6            4
# 1        26.7         34.6         36.8          2.12      77.1            3
# 2        24.5         31.0         35.7          1.11      78.8            4
# 3        28.2         36.2         33.5          2.12      77.4            3
# 4        27.2         38.3         38.0          2.57      76.1            4
# 5        31.3         28.2         30.3          0.92      78.9            2
# 6        22.6         43.5         29.7          1.99      76.2            5
# 7        31.6         33.9         30.3          1.06      77.5            3
# 8        30.6         36.2         31.8          2.00      77.8            3
# 9        21.5         34.7         35.5          1.58      76.5            3
# 10       35.7         28.0         32.3          2.25      77.2            3
# 11       25.2         36.7         35.8          1.28      78.9            2
# 12       31.6         38.9         28.7          1.74      76.7            4
# 13       29.3         34.6         32.8          2.52      76.2            3
# 14       27.7         39.4         39.4          0.99      76.3            1
# 15       31.4         35.9         30.0          1.39      75.3            2
# 16       20.0         34.0         34.6          1.77      76.2            2
# 17       33.6         33.5         36.7          1.81      76.5            2
# 18       31.0         25.7         40.0          2.30      76.3            1
# 19       29.1         32.3         32.1          1.74      76.3            0
#
#     wins_last_y
# 0             1
# 1             1
# 2             1
# 3             1
# 4             0
# 5             1
# 6             1
# 7             0
# 8             0
# 9             1
# 10            0
# 11            0
# 12            1
# 13            0
# 14            0
# 15            0
# 16            0
# 17            0
# 18            0
# 19            0

# %%
df = pd.read_csv('all.csv')
df.to_csv('all_copy.csv', index = False)
frames = [df,kp_scores]
df = pd.concat(frames, ignore_index = True)

# %%
df.to_csv('all.csv', index = False)

# %%
df = pd.read_csv('all.csv')

# %%
df
# Out:
#                  home                    away  home_score  away_score  score  \
# 0            Michigan               Wisconsin          77          54     23
# 1        Oklahoma St.                  Kansas          75          70      5
# 2       Virginia Tech                    Duke          74          67      7
# 3            Kentucky                 Alabama          65          85    -20
# 4      North Carolina                Syracuse          81          75      6
# ..                ...                     ...         ...         ...    ...
# 529    St. Francis PA     Fairleigh Dickinson          92          94     -2
# 530  Tennessee Martin  Southeast Missouri St.          69          66      3
# 531  Eastern Illinois        SIU Edwardsville          74          87    -13
# 532             Akron        Eastern Michigan          86          65     21
# 533              Ohio        Western Michigan          81          58     23
#
#            date conf_x  adj_off_x  adj_def_x  adj_tempo_x  poss_off_x  \
# 0    2021-01-12    B10      116.4       91.4         68.0        16.6
# 1    2021-01-12    B12      109.8       92.3         71.7        15.7
# 2    2021-01-12    ACC      111.7       93.9         67.2        17.7
# 3    2021-01-12    SEC      107.7       91.1         68.0        17.0
# 4    2021-01-12    ACC      108.6       90.3         71.1        15.8
# ..          ...    ...        ...        ...          ...         ...
# 529  2021-01-26    NEC       97.5      105.9         70.2        16.5
# 530  2021-01-26    OVC       94.2      115.4         69.8        17.5
# 531  2021-01-26    OVC       98.8      106.4         70.1        16.7
# 532  2021-01-26    MAC      105.1      100.8         68.8        17.1
# 533  2021-01-26    MAC      109.1      104.9         69.5        16.9
#
#      poss_def_x  fg_off_x  fg_def_x  turnover_off_x  turnover_def_x  \
# 0          17.6      59.0      43.8            18.2            15.2
# 1          17.6      51.3      46.8            19.2            19.5
# 2          18.0      53.0      48.8            17.9            18.6
# 3          18.0      47.2      45.9            20.8            18.3
# 4          17.7      46.1      48.7            22.0            18.8
# ..          ...       ...       ...             ...             ...
# 529        16.6      46.7      50.0            19.6            19.2
# 530        16.2      43.3      61.4            22.1            20.2
# 531        17.0      47.7      53.2            18.8            19.8
# 532        17.8      53.6      47.8            19.9            15.4
# 533        16.9      55.3      53.3            16.9            20.6
#
#      reb_off_x  reb_def_x  three_off_x  three_def_x  experience_x  height_x  \
# 0         31.1       24.1         35.8         34.8          2.10      77.9
# 1         32.2       29.6         31.6         33.2          1.12      77.6
# 2         31.8       23.0         35.3         33.8          1.63      76.3
# 3         33.8       30.4         31.1         30.8          0.90      79.0
# 4         40.7       23.7         30.4         34.7          1.08      78.8
# ..         ...        ...          ...          ...           ...       ...
# 529       26.7       31.4         31.3         26.1          1.26      76.8
# 530       28.9       30.7         31.6         41.3          1.59      76.9
# 531       29.2       27.3         32.7         39.7          2.59      76.7
# 532       29.3       26.9         33.6         29.6          1.93      75.6
# 533       28.0       28.5         37.1         36.2          1.45      77.0
#
#      wins_five_x  wins_last_x conf_y  adj_off_y  adj_def_y  adj_tempo_y  \
# 0              5            1    B10      114.9       89.2         64.9
# 1              2            1    B12      112.7       89.5         68.7
# 2              4            1    ACC      112.8       92.9         69.0
# 3              3            1    SEC      111.6       93.0         74.6
# 4              3            1    ACC      109.6       92.7         70.6
# ..           ...          ...    ...        ...        ...          ...
# 529            2            0    NEC       98.8      111.1         70.6
# 530            0            0    OVC       94.4      107.6         68.6
# 531            0            0    OVC       93.4      107.2         70.8
# 532            4            1    MAC       97.5      105.3         69.0
# 533            3            1    MAC       95.5      105.1         65.7
#
#      poss_off_y  poss_def_y  fg_off_y  fg_def_y  turnover_off_y  \
# 0          18.1        18.0      53.8      44.4            12.1
# 1          16.3        17.5      49.9      47.2            18.0
# 2          16.4        16.8      52.7      52.2            20.0
# 3          14.2        17.5      49.4      47.4            18.0
# 4          15.3        17.0      51.3      46.3            17.5
# ..          ...         ...       ...       ...             ...
# 529        16.6        16.9      49.1      54.4            20.4
# 530        17.4        17.1      48.8      51.8            21.4
# 531        17.1        16.0      49.9      53.5            25.2
# 532        17.1        16.8      45.0      61.3            18.5
# 533        18.6        16.3      49.0      50.6            21.0
#
#      turnover_def_y  reb_off_y  reb_def_y  three_off_y  three_def_y  \
# 0              18.2       23.7       21.9         41.4         33.0
# 1              18.1       35.0       25.9         35.5         32.1
# 2              21.8       35.3       24.9         35.2         37.1
# 3              21.0       32.8       29.2         32.2         31.6
# 4              22.8       29.6       28.0         32.6         29.8
# ..              ...        ...        ...          ...          ...
# 529            18.8       27.1       31.4         35.9         30.0
# 530            18.5       26.2       20.0         34.0         34.6
# 531            22.5       26.9       33.6         33.5         36.7
# 532            19.5       28.9       31.0         25.7         40.0
# 533            14.8       25.0       29.1         32.3         32.1
#
#      experience_y  height_y  wins_five_y  wins_last_y
# 0            2.33      78.2          4.0          1.0
# 1            1.42      78.2          4.0          1.0
# 2            0.90      76.9          4.0          1.0
# 3            1.93      77.9          5.0          1.0
# 4            1.49      77.9          4.0          1.0
# ..            ...       ...          ...          ...
# 529          1.39      75.3          2.0          0.0
# 530          1.77      76.2          2.0          0.0
# 531          1.81      76.5          2.0          0.0
# 532          2.30      76.3          1.0          0.0
# 533          1.74      76.3          0.0          0.0
#
# [534 rows x 42 columns]

# %%
x = df[['adj_off_x', 'adj_def_x', 'adj_tempo_x', 'poss_off_x', 'poss_def_x',
       'fg_off_x', 'fg_def_x', 'turnover_off_x', 'turnover_def_x', 'reb_off_x',
       'reb_def_x', 'three_off_x', 'three_def_x', 'experience_x', 'height_x','wins_five_x','wins_last_x',
       'adj_off_y', 'adj_def_y', 'adj_tempo_y', 'poss_off_y',
       'poss_def_y', 'fg_off_y', 'fg_def_y', 'turnover_off_y',
       'turnover_def_y', 'reb_off_y', 'reb_def_y', 'three_off_y',
       'three_def_y', 'experience_y', 'height_y','wins_five_y','wins_last_y']].values
y = df[['score']].values
predict_x = predict[['adj_off_x', 'adj_def_x', 'adj_tempo_x', 'poss_off_x', 'poss_def_x',
       'fg_off_x', 'fg_def_x', 'turnover_off_x', 'turnover_def_x', 'reb_off_x',
       'reb_def_x', 'three_off_x', 'three_def_x', 'experience_x', 'height_x','wins_five_x','wins_last_x',
       'adj_off_y', 'adj_def_y', 'adj_tempo_y', 'poss_off_y',
       'poss_def_y', 'fg_off_y', 'fg_def_y', 'turnover_off_y',
       'turnover_def_y', 'reb_off_y', 'reb_def_y', 'three_off_y',
       'three_def_y', 'experience_y', 'height_y','wins_five_y','wins_last_y']].values

# %%
lasso = Lasso()
lasso.fit(x, y)
lasso.coef_
# Out:
# array([ 7.71741252e-01, -8.66740519e-01, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -2.96545593e-03,  0.00000000e+00,
#         1.43597104e-01,  9.04623939e-02, -5.46811862e-05, -0.00000000e+00,
#         8.20766469e-02,  0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -8.58439660e-01,  8.79330863e-01,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -2.08673699e-01,  4.91685529e-02, -0.00000000e+00,  2.29937983e-01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         7.87941697e-01,  0.00000000e+00])

# %%
lin = LinearRegression()
lin.fit(x, y)
lin.coef_
# Out:
# array([[ 0.99106343, -0.67423821, -0.15381607, -0.34957385,  0.04620909,
#          0.05024   , -0.45966324,  0.15840817,  0.36207518,  0.07040677,
#         -0.15039104, -0.13577108,  0.35800756, -0.26995787, -0.80642141,
#         -0.17703691, -0.20049154, -0.88409431,  0.91349536,  0.34393811,
#          0.47599995, -0.33843706, -0.35078547, -0.02556214, -0.36345605,
#          0.17308974, -0.07778996,  0.33438739,  0.20741915,  0.17727978,
#          0.01263082,  0.17750773,  1.94219613,  0.29905755]])

# %%
rf = RandomForestRegressor()
rf.fit(x, y)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
games['lasso'] = lasso.predict(predict_x)
games['lasso'] = round(games['lasso'])
games['linear'] = lin.predict(predict_x)
games['linear'] = round(games['linear'])
games['rf'] = rf.predict(predict_x)
games['rf'] = round(games['rf'])
games
# Out:
#                       home                 away  predict_kp        date  \
# 0               Seton Hall            Creighton          -2  2021-01-27
# 1                 Maryland            Wisconsin          -2  2021-01-27
# 2                  Clemson           Louisville           1  2021-01-27
# 3                 Arkansas          Mississippi           3  2021-01-27
# 4               Notre Dame        Virginia Tech          -1  2021-01-27
# 5             Colorado St.            Boise St.          -1  2021-01-27
# 6                 Ohio St.             Penn St.           7  2021-01-27
# 7               Providence            Marquette           3  2021-01-27
# 8                   DePaul           St. John's           1  2021-01-27
# 9           South Carolina              Georgia           3  2021-01-27
# 10            Missouri St.                Drake          -5  2021-01-27
# 11                    UNLV             Utah St.          -5  2021-01-27
# 12              Pepperdine                  BYU          -7  2021-01-27
# 13                Kent St.        Bowling Green           5  2021-01-27
# 14              N.C. State          Wake Forest           7  2021-01-27
# 15                La Salle         Rhode Island          -8  2021-01-27
# 16          UNC Greensboro               Mercer           5  2021-01-27
# 17                     UCF        East Carolina           6  2021-01-27
# 18       Abilene Christian    Stephen F. Austin           5  2021-01-27
# 19             Florida St.             Miami FL          13  2021-01-27
# 20                     VMI     Western Carolina           2  2021-01-27
# 21           James Madison               Towson           3  2021-01-27
# 22        Northwestern St.          New Orleans           1  2021-01-27
# 23  Southeastern Louisiana     Central Arkansas          -3  2021-01-27
# 24                 Fordham             Duquesne          -7  2021-01-27
# 25          St. Francis PA  Fairleigh Dickinson           4  2021-01-27
# 26                Colorado       Washington St.          15  2021-01-27
# 27                 Florida           Vanderbilt          15  2021-01-27
# 28          Incarnate Word      Houston Baptist           4  2021-01-27
# 29                     LIU            Merrimack           6  2021-01-27
# 30             The Citadel              Wofford         -10  2021-01-27
# 31  Texas A&M Corpus Chris      Sam Houston St.          -7  2021-01-27
# 32                  Baylor           Kansas St.          25  2021-01-27
# 33            Nicholls St.          McNeese St.          14  2021-01-27
#
#     lasso  linear    rf
# 0    -2.0    -3.0   8.0
# 1    -5.0    -5.0   6.0
# 2     1.0     1.0   3.0
# 3     3.0     2.0   2.0
# 4    -5.0    -8.0   5.0
# 5    -1.0     0.0  -7.0
# 6     7.0     6.0   9.0
# 7     2.0     1.0   7.0
# 8     2.0     4.0  -0.0
# 9     5.0     3.0  -0.0
# 10   -6.0    -5.0  -8.0
# 11   -8.0    -9.0  -1.0
# 12  -10.0   -11.0  -1.0
# 13    6.0     7.0   5.0
# 14    7.0     6.0   5.0
# 15  -10.0   -12.0  -8.0
# 16    7.0     7.0  -1.0
# 17    6.0     5.0   6.0
# 18    8.0    11.0   8.0
# 19   14.0    12.0  17.0
# 20   -1.0    -4.0  -1.0
# 21    4.0     4.0   6.0
# 22    1.0     2.0   9.0
# 23   -4.0    -5.0  -2.0
# 24   -8.0   -12.0 -11.0
# 25    6.0     4.0  -2.0
# 26   15.0    14.0  17.0
# 27   15.0    13.0  12.0
# 28    3.0    -1.0   9.0
# 29    9.0    12.0   9.0
# 30  -11.0   -14.0  -3.0
# 31   -6.0    -2.0  -1.0
# 32   30.0    28.0  15.0
# 33   15.0    16.0   6.0

# %%
map_team_name = {'Ole Miss':'Mississippi',
                 'Miami (FL)' : 'Miami FL',
                 'Miami Ohio' : 'Miami OH',
                 "St. Joseph's" : "Saint Joseph's",
                 'NC State' : 'N.C. State',
                 'Texas A&M-CC' : 'Texas A&M Corpus Chris',
                 'LIU Sharks' : "LIU",
                 'Central Connecticut State' : 'Central Connecticut',
                 'LA-Lafayette' : 'Louisiana',
                 'Cal State Bakersfield' : 'Cal St. Bakersfield',
                 'CSU Northridge' : 'Cal St. Northridge',
                 'Louisiana-Monroe' : 'Louisiana Monroe',
                 'Tarleton State Texans':'Tarleton St.',
                 'Florida Intl' : "FIU",
                 'Citadel':'The Citadel',
                 'UC San Diego Tritons':'UC San Diego',
                 'Grambling St' : 'Grambling St.',
                 'Arkansas-Pine Bluff': 'Arkansas Pine Bluff',
                 'UMass' : 'Massachusetts',
                 'North Carolina Asheville' : 'UNC Asheville',
                 'St. Francis (PA)' : 'St. Francis PA',
                 'San José State' : 'San Jose St.',
                 "Mt. St. Mary's" : "Mount St. Mary's",
                 "Tennessee-Martin" : "Tennessee Martin",
                 'Arkansas Little Rock' : 'Little Rock',
                 'Southern Mississippi' : 'Southern Miss',
                 'Kansas City' : 'UMKC',
                 'Charleston Southern' : "Charleston Southern",
                 'Southern University' : 'Southern'
                 
                 
                 
                }

# %%
options = webdriver.ChromeOptions() 
#options.add_argument(r'''user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data''')
#"user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data" home
# "user-data-dir=C:\Users\koric1\AppData\Local\Google\Chrome\User Data" work
#options.add_argument("--start-maximized")
#self.options.add_argument("--headless")
#self.options.add_argument("--no-sandbox")
#self.options.add_argument("--disable-gpu")
options.add_argument('--headless')
options.add_argument('--disable-gpu')  # Last I checked this was necessa
driver = webdriver.Chrome(chrome_options= options)
driver.get('https://sportsbook.draftkings.com/leagues/basketball/3230960?category=game-lines&subcategory=game')

x = True
i = 1
teams = {}
while(x):
    try:
        team_name = str(driver.find_element_by_xpath('//*[@id="root"]/section/section[2]/section/div[3]/div/div[3]/div/div/div[2]/div/div[2]/div[2]/section/div[2]/div[1]/div['+str(i)+']/a/div/div[2]/span').text)
        team_score = float(driver.find_element_by_xpath('//*[@id="root"]/section/section[2]/section/div[3]/div/div[3]/div/div/div[2]/div/div[2]/div[2]/section/div[2]/div[2]/div['+str(i)+']/div/div/div/div[1]/span').text)
        teams[team_name] = team_score 
        i += 1
    except:
        x = False

        
for key in list(teams):
    name_list = key.split()
    
    if key in map_team_name.keys():
        teams[map_team_name[key]] =   teams[key]
        del teams[key]
    elif name_list[-1] == "State":
        name_list[-1] = "St."
        new_name = " ".join(str(x) for x in name_list)
        home_team = new_name
        teams[home_team] = teams[key] 
        del teams[key]
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()

# %%
games['draft_kings'] = games['away'].apply(lambda x: teams[x] if x in teams else -99)
games[games['draft_kings'] == -99]
# Out:
#               home                 away  predict_kp        date  lasso  \
# 0       Seton Hall            Creighton          -2  2021-01-27   -2.0
# 25  St. Francis PA  Fairleigh Dickinson           4  2021-01-27    6.0
#
#     linear   rf  draft_kings
# 0     -3.0  8.0        -99.0
# 25     4.0 -2.0        -99.0

# %%
games
# Out:
#                       home                 away  predict_kp        date  \
# 0               Seton Hall            Creighton          -2  2021-01-27
# 1                 Maryland            Wisconsin          -2  2021-01-27
# 2                  Clemson           Louisville           1  2021-01-27
# 3                 Arkansas          Mississippi           3  2021-01-27
# 4               Notre Dame        Virginia Tech          -1  2021-01-27
# 5             Colorado St.            Boise St.          -1  2021-01-27
# 6                 Ohio St.             Penn St.           7  2021-01-27
# 7               Providence            Marquette           3  2021-01-27
# 8                   DePaul           St. John's           1  2021-01-27
# 9           South Carolina              Georgia           3  2021-01-27
# 10            Missouri St.                Drake          -5  2021-01-27
# 11                    UNLV             Utah St.          -5  2021-01-27
# 12              Pepperdine                  BYU          -7  2021-01-27
# 13                Kent St.        Bowling Green           5  2021-01-27
# 14              N.C. State          Wake Forest           7  2021-01-27
# 15                La Salle         Rhode Island          -8  2021-01-27
# 16          UNC Greensboro               Mercer           5  2021-01-27
# 17                     UCF        East Carolina           6  2021-01-27
# 18       Abilene Christian    Stephen F. Austin           5  2021-01-27
# 19             Florida St.             Miami FL          13  2021-01-27
# 20                     VMI     Western Carolina           2  2021-01-27
# 21           James Madison               Towson           3  2021-01-27
# 22        Northwestern St.          New Orleans           1  2021-01-27
# 23  Southeastern Louisiana     Central Arkansas          -3  2021-01-27
# 24                 Fordham             Duquesne          -7  2021-01-27
# 25          St. Francis PA  Fairleigh Dickinson           4  2021-01-27
# 26                Colorado       Washington St.          15  2021-01-27
# 27                 Florida           Vanderbilt          15  2021-01-27
# 28          Incarnate Word      Houston Baptist           4  2021-01-27
# 29                     LIU            Merrimack           6  2021-01-27
# 30             The Citadel              Wofford         -10  2021-01-27
# 31  Texas A&M Corpus Chris      Sam Houston St.          -7  2021-01-27
# 32                  Baylor           Kansas St.          25  2021-01-27
# 33            Nicholls St.          McNeese St.          14  2021-01-27
#
#     lasso  linear    rf  draft_kings
# 0    -2.0    -3.0   8.0        -99.0
# 1    -5.0    -5.0   6.0         -3.0
# 2     1.0     1.0   3.0          1.5
# 3     3.0     2.0   2.0          4.5
# 4    -5.0    -8.0   5.0         -0.5
# 5    -1.0     0.0  -7.0         -2.5
# 6     7.0     6.0   9.0          7.5
# 7     2.0     1.0   7.0          1.0
# 8     2.0     4.0  -0.0         -0.5
# 9     5.0     3.0  -0.0          4.0
# 10   -6.0    -5.0  -8.0         -4.0
# 11   -8.0    -9.0  -1.0         -6.5
# 12  -10.0   -11.0  -1.0         -6.0
# 13    6.0     7.0   5.0          5.0
# 14    7.0     6.0   5.0          7.5
# 15  -10.0   -12.0  -8.0         -7.0
# 16    7.0     7.0  -1.0          5.0
# 17    6.0     5.0   6.0          5.5
# 18    8.0    11.0   8.0          2.5
# 19   14.0    12.0  17.0         11.0
# 20   -1.0    -4.0  -1.0          2.0
# 21    4.0     4.0   6.0          3.0
# 22    1.0     2.0   9.0          0.5
# 23   -4.0    -5.0  -2.0         -1.5
# 24   -8.0   -12.0 -11.0         -7.0
# 25    6.0     4.0  -2.0        -99.0
# 26   15.0    14.0  17.0         14.5
# 27   15.0    13.0  12.0         13.0
# 28    3.0    -1.0   9.0          2.5
# 29    9.0    12.0   9.0          6.0
# 30  -11.0   -14.0  -3.0         -9.0
# 31   -6.0    -2.0  -1.0         -9.0
# 32   30.0    28.0  15.0         23.5
# 33   15.0    16.0   6.0         14.0

# %%
games = games[games['draft_kings']!=-99]
year,month,day = get_today()
name = path+"\\predict_scores\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict_scores.csv"
games.to_csv(name, index = False)

# %%
games['diff_kp'] = abs(games['predict_kp'] - games['draft_kings'])
games = games.sort_values(by=['diff_kp'], ascending = False)
games['bet'] = 'none'
for index, row in games.iterrows():
    line = row['predict_kp']
    dk = row['draft_kings']
    home = row['home']
    away = row['away']
    if line < dk:
        games.loc[index,'bet'] = away
    elif line > dk:
        games.loc[index,'bet'] = home
    else:
        pass
games
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                       home               away  predict_kp        date  lasso  \
# 18       Abilene Christian  Stephen F. Austin           5  2021-01-27    8.0
# 19             Florida St.           Miami FL          13  2021-01-27   14.0
# 27                 Florida         Vanderbilt          15  2021-01-27   15.0
# 31  Texas A&M Corpus Chris    Sam Houston St.          -7  2021-01-27   -6.0
# 7               Providence          Marquette           3  2021-01-27    2.0
# 11                    UNLV           Utah St.          -5  2021-01-27   -8.0
# 28          Incarnate Word    Houston Baptist           4  2021-01-27    3.0
# 23  Southeastern Louisiana   Central Arkansas          -3  2021-01-27   -4.0
# 8                   DePaul         St. John's           1  2021-01-27    2.0
# 5             Colorado St.          Boise St.          -1  2021-01-27   -1.0
# 32                  Baylor         Kansas St.          25  2021-01-27   30.0
# 3                 Arkansas        Mississippi           3  2021-01-27    3.0
# 9           South Carolina            Georgia           3  2021-01-27    5.0
# 10            Missouri St.              Drake          -5  2021-01-27   -6.0
# 12              Pepperdine                BYU          -7  2021-01-27  -10.0
# 30             The Citadel            Wofford         -10  2021-01-27  -11.0
# 15                La Salle       Rhode Island          -8  2021-01-27  -10.0
# 1                 Maryland          Wisconsin          -2  2021-01-27   -5.0
# 22        Northwestern St.        New Orleans           1  2021-01-27    1.0
# 26                Colorado     Washington St.          15  2021-01-27   15.0
# 17                     UCF      East Carolina           6  2021-01-27    6.0
# 2                  Clemson         Louisville           1  2021-01-27    1.0
# 14              N.C. State        Wake Forest           7  2021-01-27    7.0
# 6                 Ohio St.           Penn St.           7  2021-01-27    7.0
# 4               Notre Dame      Virginia Tech          -1  2021-01-27   -5.0
# 21           James Madison             Towson           3  2021-01-27    4.0
# 20                     VMI   Western Carolina           2  2021-01-27   -1.0
# 24                 Fordham           Duquesne          -7  2021-01-27   -8.0
# 16          UNC Greensboro             Mercer           5  2021-01-27    7.0
# 29                     LIU          Merrimack           6  2021-01-27    9.0
# 13                Kent St.      Bowling Green           5  2021-01-27    6.0
# 33            Nicholls St.        McNeese St.          14  2021-01-27   15.0
#
#     linear    rf  draft_kings  diff_kp                     bet
# 18    11.0   8.0          2.5      2.5       Abilene Christian
# 19    12.0  17.0         11.0      2.0             Florida St.
# 27    13.0  12.0         13.0      2.0                 Florida
# 31    -2.0  -1.0         -9.0      2.0  Texas A&M Corpus Chris
# 7      1.0   7.0          1.0      2.0              Providence
# 11    -9.0  -1.0         -6.5      1.5                    UNLV
# 28    -1.0   9.0          2.5      1.5          Incarnate Word
# 23    -5.0  -2.0         -1.5      1.5        Central Arkansas
# 8      4.0  -0.0         -0.5      1.5                  DePaul
# 5      0.0  -7.0         -2.5      1.5            Colorado St.
# 32    28.0  15.0         23.5      1.5                  Baylor
# 3      2.0   2.0          4.5      1.5             Mississippi
# 9      3.0  -0.0          4.0      1.0                 Georgia
# 10    -5.0  -8.0         -4.0      1.0                   Drake
# 12   -11.0  -1.0         -6.0      1.0                     BYU
# 30   -14.0  -3.0         -9.0      1.0                 Wofford
# 15   -12.0  -8.0         -7.0      1.0            Rhode Island
# 1     -5.0   6.0         -3.0      1.0                Maryland
# 22     2.0   9.0          0.5      0.5        Northwestern St.
# 26    14.0  17.0         14.5      0.5                Colorado
# 17     5.0   6.0          5.5      0.5                     UCF
# 2      1.0   3.0          1.5      0.5              Louisville
# 14     6.0   5.0          7.5      0.5             Wake Forest
# 6      6.0   9.0          7.5      0.5                Penn St.
# 4     -8.0   5.0         -0.5      0.5           Virginia Tech
# 21     4.0   6.0          3.0      0.0                    none
# 20    -4.0  -1.0          2.0      0.0                    none
# 24   -12.0 -11.0         -7.0      0.0                    none
# 16     7.0  -1.0          5.0      0.0                    none
# 29    12.0   9.0          6.0      0.0                    none
# 13     7.0   5.0          5.0      0.0                    none
# 33    16.0   6.0         14.0      0.0                    none

# %%
games.drop(columns=['lasso','linear','rf'])
# Out:
#                       home               away  predict_kp        date  \
# 18       Abilene Christian  Stephen F. Austin           5  2021-01-27
# 19             Florida St.           Miami FL          13  2021-01-27
# 27                 Florida         Vanderbilt          15  2021-01-27
# 31  Texas A&M Corpus Chris    Sam Houston St.          -7  2021-01-27
# 7               Providence          Marquette           3  2021-01-27
# 11                    UNLV           Utah St.          -5  2021-01-27
# 28          Incarnate Word    Houston Baptist           4  2021-01-27
# 23  Southeastern Louisiana   Central Arkansas          -3  2021-01-27
# 8                   DePaul         St. John's           1  2021-01-27
# 5             Colorado St.          Boise St.          -1  2021-01-27
# 32                  Baylor         Kansas St.          25  2021-01-27
# 3                 Arkansas        Mississippi           3  2021-01-27
# 9           South Carolina            Georgia           3  2021-01-27
# 10            Missouri St.              Drake          -5  2021-01-27
# 12              Pepperdine                BYU          -7  2021-01-27
# 30             The Citadel            Wofford         -10  2021-01-27
# 15                La Salle       Rhode Island          -8  2021-01-27
# 1                 Maryland          Wisconsin          -2  2021-01-27
# 22        Northwestern St.        New Orleans           1  2021-01-27
# 26                Colorado     Washington St.          15  2021-01-27
# 17                     UCF      East Carolina           6  2021-01-27
# 2                  Clemson         Louisville           1  2021-01-27
# 14              N.C. State        Wake Forest           7  2021-01-27
# 6                 Ohio St.           Penn St.           7  2021-01-27
# 4               Notre Dame      Virginia Tech          -1  2021-01-27
# 21           James Madison             Towson           3  2021-01-27
# 20                     VMI   Western Carolina           2  2021-01-27
# 24                 Fordham           Duquesne          -7  2021-01-27
# 16          UNC Greensboro             Mercer           5  2021-01-27
# 29                     LIU          Merrimack           6  2021-01-27
# 13                Kent St.      Bowling Green           5  2021-01-27
# 33            Nicholls St.        McNeese St.          14  2021-01-27
#
#     draft_kings  diff_kp                     bet
# 18          2.5      2.5       Abilene Christian
# 19         11.0      2.0             Florida St.
# 27         13.0      2.0                 Florida
# 31         -9.0      2.0  Texas A&M Corpus Chris
# 7           1.0      2.0              Providence
# 11         -6.5      1.5                    UNLV
# 28          2.5      1.5          Incarnate Word
# 23         -1.5      1.5        Central Arkansas
# 8          -0.5      1.5                  DePaul
# 5          -2.5      1.5            Colorado St.
# 32         23.5      1.5                  Baylor
# 3           4.5      1.5             Mississippi
# 9           4.0      1.0                 Georgia
# 10         -4.0      1.0                   Drake
# 12         -6.0      1.0                     BYU
# 30         -9.0      1.0                 Wofford
# 15         -7.0      1.0            Rhode Island
# 1          -3.0      1.0                Maryland
# 22          0.5      0.5        Northwestern St.
# 26         14.5      0.5                Colorado
# 17          5.5      0.5                     UCF
# 2           1.5      0.5              Louisville
# 14          7.5      0.5             Wake Forest
# 6           7.5      0.5                Penn St.
# 4          -0.5      0.5           Virginia Tech
# 21          3.0      0.0                    none
# 20          2.0      0.0                    none
# 24         -7.0      0.0                    none
# 16          5.0      0.0                    none
# 29          6.0      0.0                    none
# 13          5.0      0.0                    none
# 33         14.0      0.0                    none

# %%
year,month,day = get_yesterday()
name = path+"\\predict_scores\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict_scores.csv"
predict_yesterday = pd.read_csv(name)
predict_yesterday
# Out:
#                 home                    away  predict_kp        date  lasso  \
# 0             Auburn                Missouri          -1  2021-01-26    0.0
# 1              Texas                Oklahoma           6  2021-01-26    7.0
# 2         Pittsburgh          North Carolina          -1  2021-01-26   -1.0
# 3            Memphis                     SMU           2  2021-01-26    4.0
# 4               Duke            Georgia Tech           5  2021-01-26    8.0
# 5            Alabama                Kentucky           9  2021-01-26    9.0
# 6       Missouri St.                   Drake          -4  2021-01-26   -5.0
# 7          Texas A&M                     LSU          -6  2021-01-26   -4.0
# 8        Saint Louis                  Dayton           8  2021-01-26   11.0
# 9        Connecticut                  Butler           8  2021-01-26   10.0
# 10            Temple                   Tulsa          -3  2021-01-26   -2.0
# 11         Tennessee         Mississippi St.           9  2021-01-26   12.0
# 12          Miami OH                  Toledo          -5  2021-01-26   -5.0
# 13    Saint Joseph's                Richmond         -10  2021-01-26  -10.0
# 14       Indiana St.       Southern Illinois           5  2021-01-26    6.0
# 15  Tennessee Martin  Southeast Missouri St.          -3  2021-01-26   -6.0
# 16  Eastern Illinois        SIU Edwardsville           7  2021-01-26    9.0
# 17             Akron        Eastern Michigan          11  2021-01-26   11.0
# 18           Buffalo        Central Michigan          13  2021-01-26   15.0
# 19              Ohio        Western Michigan          11  2021-01-26   11.0
#
#     linear    rf  draft_kings
# 0     -2.0  11.0          2.5
# 1      7.0  -0.0          4.5
# 2     -1.0  14.0         -2.5
# 3      2.0   5.0          2.5
# 4     12.0   4.0          6.0
# 5      6.0  17.0          7.5
# 6     -5.0 -12.0         -4.0
# 7     -4.0   6.0         -5.0
# 8     13.0   8.0          9.0
# 9     10.0   3.0          6.0
# 10    -3.0  -3.0          1.0
# 11    12.0  -7.0          9.5
# 12    -4.0   1.0         -4.5
# 13   -12.0   2.0        -12.0
# 14     4.0   2.0          5.5
# 15    -8.0   2.0         -5.0
# 16    12.0  13.0          6.0
# 17    11.0   9.0         11.0
# 18    15.0  14.0         13.0
# 19     8.0  14.0         14.0

# %%
scores = scores.drop(columns=['date','away'])
scores
# Out:
#                 home  home_score  away_score  score
# 0             Auburn          88          82      6
# 1              Texas          79          80     -1
# 2         Pittsburgh          65          75    -10
# 3            Memphis          76          72      4
# 4               Duke          75          68      7
# 5            Alabama          70          59     11
# 6       Missouri St.          61          68     -7
# 7          Texas A&M          66          78    -12
# 8        Saint Louis          71          76     -5
# 9        Connecticut          63          51     12
# 10            Temple          76          67      9
# 11         Tennessee          56          53      3
# 12          Miami OH          81          90     -9
# 13    Saint Joseph's          56          79    -23
# 14       Indiana St.          71          59     12
# 15    St. Francis PA          92          94     -2
# 16  Tennessee Martin          69          66      3
# 17  Eastern Illinois          74          87    -13
# 18             Akron          86          65     21
# 19              Ohio          81          58     23

# %%
import math
error = pd.merge(predict_yesterday, scores, how='left', left_on='home', right_on='home')
error = error[error['home'] !='Georgetown']
error
# Out:
#                 home                    away  predict_kp        date  lasso  \
# 0             Auburn                Missouri          -1  2021-01-26    0.0
# 1              Texas                Oklahoma           6  2021-01-26    7.0
# 2         Pittsburgh          North Carolina          -1  2021-01-26   -1.0
# 3            Memphis                     SMU           2  2021-01-26    4.0
# 4               Duke            Georgia Tech           5  2021-01-26    8.0
# 5            Alabama                Kentucky           9  2021-01-26    9.0
# 6       Missouri St.                   Drake          -4  2021-01-26   -5.0
# 7          Texas A&M                     LSU          -6  2021-01-26   -4.0
# 8        Saint Louis                  Dayton           8  2021-01-26   11.0
# 9        Connecticut                  Butler           8  2021-01-26   10.0
# 10            Temple                   Tulsa          -3  2021-01-26   -2.0
# 11         Tennessee         Mississippi St.           9  2021-01-26   12.0
# 12          Miami OH                  Toledo          -5  2021-01-26   -5.0
# 13    Saint Joseph's                Richmond         -10  2021-01-26  -10.0
# 14       Indiana St.       Southern Illinois           5  2021-01-26    6.0
# 15  Tennessee Martin  Southeast Missouri St.          -3  2021-01-26   -6.0
# 16  Eastern Illinois        SIU Edwardsville           7  2021-01-26    9.0
# 17             Akron        Eastern Michigan          11  2021-01-26   11.0
# 18           Buffalo        Central Michigan          13  2021-01-26   15.0
# 19              Ohio        Western Michigan          11  2021-01-26   11.0
#
#     linear    rf  draft_kings  home_score  away_score  score
# 0     -2.0  11.0          2.5        88.0        82.0    6.0
# 1      7.0  -0.0          4.5        79.0        80.0   -1.0
# 2     -1.0  14.0         -2.5        65.0        75.0  -10.0
# 3      2.0   5.0          2.5        76.0        72.0    4.0
# 4     12.0   4.0          6.0        75.0        68.0    7.0
# 5      6.0  17.0          7.5        70.0        59.0   11.0
# 6     -5.0 -12.0         -4.0        61.0        68.0   -7.0
# 7     -4.0   6.0         -5.0        66.0        78.0  -12.0
# 8     13.0   8.0          9.0        71.0        76.0   -5.0
# 9     10.0   3.0          6.0        63.0        51.0   12.0
# 10    -3.0  -3.0          1.0        76.0        67.0    9.0
# 11    12.0  -7.0          9.5        56.0        53.0    3.0
# 12    -4.0   1.0         -4.5        81.0        90.0   -9.0
# 13   -12.0   2.0        -12.0        56.0        79.0  -23.0
# 14     4.0   2.0          5.5        71.0        59.0   12.0
# 15    -8.0   2.0         -5.0        69.0        66.0    3.0
# 16    12.0  13.0          6.0        74.0        87.0  -13.0
# 17    11.0   9.0         11.0        86.0        65.0   21.0
# 18    15.0  14.0         13.0         NaN         NaN    NaN
# 19     8.0  14.0         14.0        81.0        58.0   23.0

# %%
dfe = pd.read_csv('all_e.csv')
dfe.to_csv('all_e_copy.csv', index = False)
frames = [dfe,error]
dfe = pd.concat(frames, ignore_index = True)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %%
dfe.to_csv('all_e.csv', index = False)

# %%
dfe
# Out:
#                        away  away_score        date  draft_kings  \
# 0                 Wisconsin        54.0  2021-01-12          3.5
# 1                    Kansas        70.0  2021-01-12         -3.5
# 2                      Duke        67.0  2021-01-12         -1.0
# 3                   Alabama        85.0  2021-01-12          3.0
# 4                  Syracuse        75.0  2021-01-12          4.5
# ..                      ...         ...         ...          ...
# 502  Southeast Missouri St.        66.0  2021-01-26         -5.0
# 503        SIU Edwardsville        87.0  2021-01-26          6.0
# 504        Eastern Michigan        65.0  2021-01-26         11.0
# 505        Central Michigan         NaN  2021-01-26         13.0
# 506        Western Michigan        58.0  2021-01-26         14.0
#
#                  home  home_score  lasso  linear  predict_kp    rf  score
# 0            Michigan        77.0   -7.0    -8.0           1 -16.0   23.0
# 1        Oklahoma St.        75.0   -3.0    -2.0          -1  -4.0    5.0
# 2       Virginia Tech        74.0   -6.0    -2.0           1  -6.0    7.0
# 3            Kentucky        65.0    1.0     2.0           1  -4.0  -20.0
# 4      North Carolina        81.0    6.0     4.0           3  -4.0    6.0
# ..                ...         ...    ...     ...         ...   ...    ...
# 502  Tennessee Martin        69.0   -6.0    -8.0          -3   2.0    3.0
# 503  Eastern Illinois        74.0    9.0    12.0           7  13.0  -13.0
# 504             Akron        86.0   11.0    11.0          11   9.0   21.0
# 505           Buffalo         NaN   15.0    15.0          13  14.0    NaN
# 506              Ohio        81.0   11.0     8.0          11  14.0   23.0
#
# [507 rows x 11 columns]

# %%
for index, row in dfe.iterrows():
    line = row['predict_kp']
    dk = row['draft_kings']
    score = row['score']
    win = -99
    if line > dk:
        if score > dk:
            win = 1
        elif score < dk:
            win = 0
        else:
            win = 2
    elif line < dk:
        if score < dk:
            win = 1
        elif score > dk:
            win = 0
        else:
            win = 2
    else:
        win = 2
    
    
    dfe.loc[index,'win_kp'] = win

# %%
for index, row in dfe.iterrows():
    line = row['lasso']
    dk = row['draft_kings']
    score = row['score']
    win = -99
    if line > dk:
        if score > dk:
            win = 1
        elif score < dk:
            win = 0
        else:
            win = 2
    elif line < dk:
        if score < dk:
            win = 1
        elif score > dk:
            win = 0
        else:
            win = 2
    else:
        win = 2
    
    
    dfe.loc[index,'win_lasso'] = win

# %%
for index, row in dfe.iterrows():
    line = row['linear']
    dk = row['draft_kings']
    score = row['score']
    win = -99
    if line > dk:
        if score > dk:
            win = 1
        elif score < dk:
            win = 0
        else:
            win = 2
    elif line < dk:
        if score < dk:
            win = 1
        elif score > dk:
            win = 0
        else:
            win = 2
    else:
        win = 2
    
    
    dfe.loc[index,'win_lin'] = win

# %%
for index, row in dfe.iterrows():
    line = row['rf']
    dk = row['draft_kings']
    score = row['score']
    win = -99
    if line > dk:
        if score > dk:
            win = 1
        elif score < dk:
            win = 0
        else:
            win = 2
    elif line < dk:
        if score < dk:
            win = 1
        elif score > dk:
            win = 0
        else:
            win = 2
    else:
        win = 2
    
    
    dfe.loc[index,'win_rf'] = win

# %%
dfe['diff_kp'] = abs(dfe['predict_kp'] - dfe['draft_kings'])
dfe = dfe.sort_values(by=['diff_kp'], ascending = False)

# %%
dfe
# Out:
#                        away  away_score        date  draft_kings  \
# 421              Oregon St.        75.0  2021-01-23          8.5
# 430            San Jose St.        83.0  2021-01-23         10.0
# 310              High Point        54.0  2021-01-20         -2.0
# 186            UC San Diego        53.0  2021-01-16         12.0
# 15              Alabama St.        64.0  2021-01-12         -9.0
# ..                      ...         ...         ...          ...
# 420  Texas A&M Corpus Chris        53.0  2021-01-23          1.0
# 254          Saint Joseph's        83.0  2021-01-18          2.0
# 418        Western Carolina        78.0  2021-01-23          8.0
# 256        Western Carolina        78.0  2021-01-18         -2.0
# 222              Holy Cross        55.0  2021-01-16         19.0
#
#                        home  home_score  lasso  linear  predict_kp    rf  \
# 421                  Oregon        64.0    NaN     NaN          15   NaN
# 430              New Mexico        71.0    NaN     NaN           5   NaN
# 310                Longwood        67.0    2.0     0.0           3   9.0
# 186        UC Santa Barbara        84.0   21.0    19.0           8  20.0
# 15   Mississippi Valley St.        51.0    4.0    -0.0          -5   2.0
# ..                      ...         ...    ...     ...         ...   ...
# 420          Incarnate Word        72.0    NaN     NaN           1   NaN
# 254                La Salle        90.0    4.0     2.0           2  11.0
# 418                 Wofford        91.0    NaN     NaN           8   NaN
# 256                 Samford        82.0   -2.0    -3.0          -2   9.0
# 222                 Colgate        95.0   16.0     7.0          19   8.0
#
#      score  win_kp  win_lasso  win_lin  win_rf  diff_kp
# 421  -11.0     0.0        2.0      2.0     2.0      6.5
# 430  -12.0     1.0        2.0      2.0     2.0      5.0
# 310   13.0     1.0        1.0      1.0     1.0      5.0
# 186   31.0     0.0        1.0      1.0     1.0      4.0
# 15   -13.0     0.0        0.0      0.0     0.0      4.0
# ..     ...     ...        ...      ...     ...      ...
# 420   19.0     2.0        2.0      2.0     2.0      0.0
# 254    7.0     2.0        1.0      2.0     1.0      0.0
# 418   13.0     2.0        2.0      2.0     2.0      0.0
# 256    4.0     2.0        2.0      0.0     1.0      0.0
# 222   40.0     2.0        0.0      0.0     0.0      0.0
#
# [507 rows x 16 columns]

# %%
dfe['win_kp'].value_counts(sort = True)
# Out:
# 0.0    219
# 1.0    206
# 2.0     82
# Name: win_kp, dtype: int64

# %%
dfe['win_lasso'].value_counts(sort = True)
# Out:
# 1.0    191
# 0.0    190
# 2.0    126
# Name: win_lasso, dtype: int64

# %%
dfe['win_lin'].value_counts(sort = True)
# Out:
# 0.0    194
# 1.0    186
# 2.0    127
# Name: win_lin, dtype: int64

# %%
dfe['win_rf'].value_counts(sort = True)
# Out:
# 1.0    191
# 0.0    186
# 2.0    130
# Name: win_rf, dtype: int64

# %%
dfe[dfe['diff_kp'] > 3]['win_kp'].value_counts(sort = True)
# Out:
# 0.0    13
# 1.0     9
# 2.0     1
# Name: win_kp, dtype: int64
