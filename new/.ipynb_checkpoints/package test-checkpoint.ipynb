# %%
from datetime import datetime
from datetime import timedelta
import os
path = os.getcwd()
import pandas as pd
def get_yesterday():
    today = datetime.today()
    yesterday = today - timedelta(days = 1)
    year = yesterday.year
    month = yesterday.month
    day = yesterday.day
    return year,month,day

# %%
from kenpompy.utils import login

# Returns an authenticated browser that can then be used to scrape pages that require authorization.
browser = login('tarik0219@yahoo.com', 'kenporn123')

# %%
import kenpompy.summary as kp

# Returns a pandas dataframe containing the efficiency and tempo stats for the current season (https://kenpom.com/summary.php).
eff_stats = kp.get_efficiency(browser)

# %%
eff_stats
# Out:
#                  Team Conference Tempo-Adj Tempo-Adj.Rank Tempo-Raw  \
# 0          Coppin St.       MEAC      77.4              1      79.4
# 1         The Citadel         SC      76.4              2      76.4
# 2              Bryant        NEC      76.3              3      78.6
# 3            Monmouth       MAAC      75.7              4      75.1
# 4    Eastern Kentucky        OVC      75.6              5      76.1
# ..                ...        ...       ...            ...       ...
# 368         Charlotte       CUSA      62.5            353      63.8
# 369         Air Force        MWC      62.3            354      64.5
# 370  Mount St. Mary's        NEC      61.5            355      63.7
# 371        Evansville        MVC      61.4            356      62.6
# 372          Virginia        ACC      59.9            357      61.1
#
#     Tempo-Raw.Rank Avg. Poss Length-Offense Avg. Poss Length-Offense.Rank  \
# 0                1                     14.1                             1
# 1                4                     14.9                            12
# 2                2                     14.5                             5
# 3               13                     14.6                             7
# 4                6                     15.2                            16
# ..             ...                      ...                           ...
# 368            343                     18.9                           322
# 369            337                     19.3                           334
# 370            344                     20.3                           346
# 371            346                     21.4                           347
# 372            347                     19.9                           344
#
#     Avg. Poss Length-Defense Avg. Poss Length-Defense.Rank  \
# 0                       16.0                            12
# 1                       16.6                            68
# 2                       16.0                            13
# 3                       17.5                           240
# 4                       16.2                            21
# ..                       ...                           ...
# 368                     18.2                           330
# 369                     17.6                           260
# 370                     17.1                           167
# 371                     16.3                            32
# 372                     18.9                           345
#
#     Off. Efficiency-Adj Off. Efficiency-Adj.Rank Off. Efficiency-Raw  \
# 0                  89.8                      343                90.1
# 1                 102.6                      153               107.1
# 2                 102.4                      162               107.5
# 3                 102.6                      152               103.6
# 4                  99.9                      206               104.3
# ..                  ...                      ...                 ...
# 368                99.0                      228                99.0
# 369                95.0                      297                91.8
# 370                97.1                      262                99.8
# 371                99.8                      207               100.8
# 372               115.7                       11               115.9
#
#     Off. Efficiency-Raw.Rank Def. Efficiency-Adj Def. Efficiency-Adj.Rank  \
# 0                        324               103.9                      215
# 1                         59               113.1                      349
# 2                         57               105.4                      245
# 3                        123               103.0                      193
# 4                        110               100.7                      147
# ..                       ...                 ...                      ...
# 368                      207                99.9                      136
# 369                      309               109.5                      320
# 370                      192               104.1                      218
# 371                      168               106.9                      274
# 372                        6                90.9                       19
#
#     Def. Efficiency-Raw Def. Efficiency-Raw.Rank
# 0                 102.0                      191
# 1                 113.8                      339
# 2                  99.9                      153
# 3                  96.7                       81
# 4                  95.0                       53
# ..                  ...                      ...
# 368                96.8                       85
# 369               113.3                      334
# 370                99.2                      138
# 371               104.7                      251
# 372                96.5                       76
#
# [357 rows x 18 columns]

# %%
import kenpompy.FanMatch as fm

# %%
fm
# Out:
# <module 'kenpompy.FanMatch' from 'C:\\Program Files (x86)\\Microsoft Visual Studio\\Shared\\Python36_64\\lib\\site-packages\\kenpompy\\FanMatch.py'>

# %%
year,month,day = get_yesterday()
test = fm.FanMatch(browser, date = str(year)+'-'+str("{0:0=2d}".format(month))+'-'+str("{0:0=2d}".format(day)))

# %%
df = test.fm_df
df
# Out:
#                                                 Game  \
# 0                     35 Penn St. 55, 43 Maryland 50
# 1                     103 Nevada 74, 60 Boise St. 72
# 2                       106 Akron 72, 95 Kent St. 61
# 3           111 Louisiana Tech 68, 85 North Texas 63
# 4                145 Old Dominion 82, 78 Marshall 81
# 5       116 UC Irvine 70, 148 Cal St. Bakersfield 53
# 6      218 South Alabama 71, 154 Coastal Carolina 65
# 7               157 Texas St. 57, 169 Little Rock 47
# 8       162 South Dakota 64, 100 South Dakota St. 56
# 9               172 Cleveland St. 80, 208 Oakland 72
# 10      152 North Dakota St. 61, 181 Oral Roberts 54
# 11                 81 Dayton 74, 146 George Mason 65
# 12                           209 UTSA 87, 219 FIU 80
# 13                   226 Stetson 73, 216 Lipscomb 68
# 14                            92 UAB 63, 173 UTEP 51
# 15             275 Arkansas St. 95, 168 Louisiana 87
# 16        300 Cal St. Northridge 80, 213 UC Davis 77
# 17  253 Youngstown St. 84, 268 Robert Morris 78 (OT)
# 18         229 UMass Lowell 74, 279 New Hampshire 69
# 19        236 Northern Kentucky 87, 223 Milwaukee 73
# 20   287 Florida Gulf Coast 86, 254 North Alabama 60
# 21         266 Wagner 84, 301 St. Francis NY 81 (OT)
# 22         276 Middle Tennessee 66, 170 Charlotte 65
# 23            290 Fairleigh Dickinson 77, 250 LIU 62
# 24                  333 Dixie St. 77, 292 Seattle 76
# 25                 200 Rice 88, 249 Southern Miss 62
# 26           299 Merrimack 59, 294 St. Francis PA 54
# 27           315 North Dakota 85, 340 Denver 82 (OT)
# 28              271 Troy 68, 269 Georgia Southern 56
# 29                    296 IUPUI 80, 248 Green Bay 71
# 30          182 Detroit 82, 259 Purdue Fort Wayne 72
# 31    322 Western Illinois 85, 291 Nebraska Omaha 77
# 32                 167 Monmouth 70, 307 Manhattan 65
# 33         67 Wright St. 72, 232 Illinois Chicago 47
# 34            203 Bellarmine 71, 302 Jacksonville 56
# 35      207 UT Arlington 63, 311 Louisiana Monroe 56
# 36               204 Radford 102, 310 USC Upstate 66
# 37         273 Cal Baptist 85, 137 New Mexico St. 75
# 38          206 Gardner Webb 91, 334 Presbyterian 64
# 39                    202 Hawaii 84, 346 Cal Poly 68
# 40             108 Liberty 90, NR Lancaster Bible 49
#
#                                      Location ThrillScore Comeback Excitement  \
# 0     University Park, PA Bryce Jordan Center        69.9        9       1.73
# 1               Reno, NV Lawlor Events Center        58.2        6       2.16
# 2              Kent, OH Memorial A & C Center        51.2        0       0.49
# 3                    Denton, TX The Super Pit        47.1        9       2.10
# 4                  Norfolk, VA Chartway Arena        46.7       21       1.93
# 5               Irvine, CA Bren Events Center        37.8        7       0.53
# 6                  Mobile, AL Mitchell Center        36.9        0       2.24
# 7             San Marcos, TX Strahan Coliseum        36.6        6       0.48
# 8                   Brookings, SD Frost Arena        36.6        3       2.11
# 9          Oakland, MI Athletics Center Orena        36.2        1       0.50
# 10                   Fargo, ND Scheels Center        35.4        3       1.30
# 11      Dayton, OH University of Dayton Arena        34.9        0       0.31
# 12    Miami, FL Ocean Bank Convocation Center        34.9        5       1.95
# 13                  DeLand, FL Edmunds Center        32.6       16       1.89
# 14                Birmingham, AL Bartow Arena        32.2        0       0.45
# 15    Jonesboro, AR First National Bank Arena        31.6       12       1.25
# 16                    Northridge, CA Matadome        31.6        6       1.74
# 17       Moon Township, PA UPMC Events Center        31.5        7       2.88
# 18                    Durham, NH Lundholm Gym        31.2       12       1.95
# 19            Milwaukee, WI UWM Panther Arena        31.1        5       1.39
# 20                 Fort Myers, FL Alico Arena        30.9        0       0.28
# 21  Brooklyn Heights, NY Peter Aquilone Court        30.3        4       2.70
# 22    Murfreesboro, TN Murphy Athletic Center        29.6        9       1.72
# 23     Brooklyn, NY Steinberg Wellness Center        29.3       10       1.39
# 24                 St. George, UT Burns Arena        29.1       14       2.30
# 25               Houston, TX Tudor Fieldhouse        29.1        2       0.32
# 26             North Andover, MA Hammel Court        28.7        4       0.93
# 27                   Denver, CO Magness Arena        28.6        8       2.72
# 28                      Troy, AL Trojan Arena        28.5        5       1.20
# 29                 Green Bay, WI Resch Center        27.7        4       2.31
# 30                   Detroit, MI Calihan Hall        27.3        5       0.82
# 31                     Omaha, NE Baxter Arena        26.9      NaN        NaN
# 32             Riverdale, NY Draddy Gymnasium        26.4        1       0.41
# 33           Chicago, IL Credit Union 1 Arena        26.4        1      -0.32
# 34                Louisville, KY Knights Hall        23.0        5       0.07
# 35          Arlington, TX College Park Center        21.6        8       1.27
# 36                  Radford, VA Dedmon Center        21.6        0      -0.36
# 37         Las Cruces, NM Pan American Center        20.5        8       1.47
# 38      Boiling Springs, NC Paul Porter Arena        18.0        3      -0.03
# 39           Honolulu, HI Stan Sheriff Center        14.0        3      -0.08
# 40                Lynchburg, VA Liberty Arena        0.04      NaN        NaN
#
#    ThrillScoreRank  ExcitementRank  ComebackRank  \
# 0                1             NaN           NaN
# 1                2             NaN           NaN
# 2                3             NaN           NaN
# 3                4             NaN           NaN
# 4                5             NaN           NaN
# 5                6             NaN           NaN
# 6                7             NaN           NaN
# 7                8             NaN           NaN
# 8                9             NaN           NaN
# 9               10             NaN           NaN
# 10              11             NaN           NaN
# 11              12             NaN           NaN
# 12              13             NaN           NaN
# 13              14             NaN           NaN
# 14              15             NaN           NaN
# 15              16             NaN           NaN
# 16              17             NaN           NaN
# 17              18             NaN           NaN
# 18              19             NaN           NaN
# 19              20             NaN           NaN
# 20              21             NaN           NaN
# 21              22             NaN           NaN
# 22              23             NaN           NaN
# 23              24             NaN           NaN
# 24              25             NaN           NaN
# 25              26             NaN           NaN
# 26              27             NaN           NaN
# 27              28             NaN           NaN
# 28              29             NaN           NaN
# 29              30             NaN           NaN
# 30              31             NaN           NaN
# 31              32             NaN           NaN
# 32              33             NaN           NaN
# 33              34             NaN           NaN
# 34              35             NaN           NaN
# 35              36             NaN           NaN
# 36              37             NaN           NaN
# 37              38             NaN           NaN
# 38              39             NaN           NaN
# 39              40             NaN           NaN
# 40               1             NaN           NaN
#
#                                         MVP Possessions  ... PredictedMOV  \
# 0              Eric Ayala (23p/3r/1a/1b/1s)          66  ...          3.0
# 1           Grant Sherfield (20p/3r/14a/3s)          67  ...          3.0
# 2                    Bryan Trimble (26p/1r)          71  ...          2.0
# 3         Isaiah Crawford (27p/6r/1a/1b/1s)          62  ...          5.0
# 4            Kalu Ezikpe (16p/12r/2a/2b/3s)          70  ...          4.0
# 5             Collin Welp (16p/5r/1a/4b/2s)          63  ...          5.0
# 6               Michael Flowers (28p/7r/6a)          66  ...          2.0
# 7                  Mason Harrell (9p/5r/4a)          58  ...          3.0
# 8      Baylor Scheierman (15p/16r/4a/1b/1s)          77  ...          7.0
# 9             Torrey Patton (21p/10r/4a/1s)          70  ...          1.0
# 10          Kevin Obanor (26p/11r/3a/1b/1s)          65  ...          4.0
# 11                Ibi Watson (20p/5r/3a/1s)          69  ...          8.0
# 12               Keaton Wallace (33p/7r/2s)          70  ...          1.0
# 13                 Rob Perry (15p/4r/7a/5s)          69  ...          2.0
# 14          Trey Jemison (14p/13r/2a/4b/2s)          67  ...          8.0
# 15             Marquis Eaton (32p/1r/9a/1s)          72  ...          4.0
# 16                    Caleb Fuller (30p/6r)          72  ...          3.0
# 17          Kahliel Spear (17p/5r/3a/3b/3s)          78  ...          1.0
# 18            Connor Withers (19p/3r/2a/1b)          68  ...          1.0
# 19            Bryson Langdon (19p/1r/4a/3s)          69  ...          3.0
# 20                Eli Abaev (14p/10r/3a/2b)          79  ...          1.0
# 21                Alex Morales (25p/12r/3a)          76  ...          1.0
# 22           Dontrell Shuler (16p/2r/3a/1s)          62  ...          4.0
# 23        Elyjah Williams (17p/6r/3a/3b/1s)          69  ...          4.0
# 24          Darrion Trammell (30p/5r/6a/2s)          74  ...          2.0
# 25               Quincy Olivari (29p/7r/1a)          71  ...          5.0
# 26             Mikey Watkins (15p/8r/7a/2s)          64  ...          2.0
# 27             Jase Townsend (25p/7r/3a/1s)          81  ...          1.0
# 28             Duke Miles (20p/5r/8a/1b/4s)          74  ...          3.0
# 29               Marcus Burk (25p/3r/6a/1s)          68  ...          5.0
# 30                Antoine Davis (30p/2r/3a)          63  ...          7.0
# 31              Ayo Akinwole (27p/5r/4a/1s)          77  ...          5.0
# 32       Warren Williams (16p/10r/1a/1b/1s)          74  ...          6.0
# 33              Loudon Love (23p/12r/2b/2s)          68  ...         11.0
# 34        Pedro Bradshaw (24p/10r/5a/1b/1s)          65  ...          7.0
# 35               Sam Griffin (23p/3r/3a/1s)          65  ...          9.0
# 36  Quinton Morton-Robertson (16p/2r/1a/2s)          70  ...          8.0
# 37                 Reed Nottage (19p/4r/2a)          66  ...         11.0
# 38              Jaheam Cornwall (19p/2r/6a)          59  ...         10.0
# 39            Justin Webster (20p/6r/1a/1s)          67  ...         12.0
# 40             Elijah Cuffee (19p/2r/4a/3s)          64  ...          NaN
#
#          PredictedLoser   OT                Loser LoserRank LoserScore  \
# 0              Maryland  nan             Maryland        43         50
# 1                Nevada  nan            Boise St.        60         72
# 2                 Akron  nan             Kent St.        95         61
# 3        Louisiana Tech  nan          North Texas        85         63
# 4          Old Dominion  nan             Marshall        78         81
# 5   Cal St. Bakersfield  nan  Cal St. Bakersfield       148         53
# 6         South Alabama  nan     Coastal Carolina       154         65
# 7           Little Rock  nan          Little Rock       169         47
# 8          South Dakota  nan     South Dakota St.       100         56
# 9               Oakland  nan              Oakland       208         72
# 10         Oral Roberts  nan         Oral Roberts       181         54
# 11         George Mason  nan         George Mason       146         65
# 12                 UTSA  nan                  FIU       219         80
# 13             Lipscomb  nan             Lipscomb       216         68
# 14                 UTEP  nan                 UTEP       173         51
# 15         Arkansas St.  nan            Louisiana       168         87
# 16   Cal St. Northridge  nan             UC Davis       213         77
# 17       Youngstown St.   OT        Robert Morris       268         78
# 18        New Hampshire  nan        New Hampshire       279         69
# 19    Northern Kentucky  nan            Milwaukee       223         73
# 20        North Alabama  nan        North Alabama       254         60
# 21               Wagner   OT       St. Francis NY       301         81
# 22     Middle Tennessee  nan            Charlotte       170         65
# 23  Fairleigh Dickinson  nan                  LIU       250         62
# 24            Dixie St.  nan              Seattle       292         76
# 25        Southern Miss  nan        Southern Miss       249         62
# 26       St. Francis PA  nan       St. Francis PA       294         54
# 27               Denver   OT               Denver       340         82
# 28     Georgia Southern  nan     Georgia Southern       269         56
# 29                IUPUI  nan            Green Bay       248         71
# 30    Purdue Fort Wayne  nan    Purdue Fort Wayne       259         72
# 31     Western Illinois  nan       Nebraska Omaha       291         77
# 32            Manhattan  nan            Manhattan       307         65
# 33     Illinois Chicago  nan     Illinois Chicago       232         47
# 34         Jacksonville  nan         Jacksonville       302         56
# 35     Louisiana Monroe  nan     Louisiana Monroe       311         56
# 36          USC Upstate  nan          USC Upstate       310         66
# 37          Cal Baptist  nan       New Mexico St.       137         75
# 38         Presbyterian  nan         Presbyterian       334         64
# 39             Cal Poly  nan             Cal Poly       346         68
# 40              Liberty  nan      Lancaster Bible        NR         49
#
#                  Winner WinnerRank WinnerScore ActualMOV
# 0              Penn St.         35          55         5
# 1                Nevada        103          74         2
# 2                 Akron        106          72        11
# 3        Louisiana Tech        111          68         5
# 4          Old Dominion        145          82         1
# 5             UC Irvine        116          70        17
# 6         South Alabama        218          71         6
# 7             Texas St.        157          57        10
# 8          South Dakota        162          64         8
# 9         Cleveland St.        172          80         8
# 10     North Dakota St.        152          61         7
# 11               Dayton         81          74         9
# 12                 UTSA        209          87         7
# 13              Stetson        226          73         5
# 14                  UAB         92          63        12
# 15         Arkansas St.        275          95         8
# 16   Cal St. Northridge        300          80         3
# 17       Youngstown St.        253          84         6
# 18         UMass Lowell        229          74         5
# 19    Northern Kentucky        236          87        14
# 20   Florida Gulf Coast        287          86        26
# 21               Wagner        266          84         3
# 22     Middle Tennessee        276          66         1
# 23  Fairleigh Dickinson        290          77        15
# 24            Dixie St.        333          77         1
# 25                 Rice        200          88        26
# 26            Merrimack        299          59         5
# 27         North Dakota        315          85         3
# 28                 Troy        271          68        12
# 29                IUPUI        296          80         9
# 30              Detroit        182          82        10
# 31     Western Illinois        322          85         8
# 32             Monmouth        167          70         5
# 33           Wright St.         67          72        25
# 34           Bellarmine        203          71        15
# 35         UT Arlington        207          63         7
# 36              Radford        204         102        36
# 37          Cal Baptist        273          85        10
# 38         Gardner Webb        206          91        27
# 39               Hawaii        202          84        16
# 40              Liberty        108          90        41
#
# [41 rows x 23 columns]

# %%
wt = df['Winner'].tolist()
lt = df['Loser'].tolist()
ws = df['WinnerScore'].tolist()
ls = df['LoserScore'].tolist()

# %%
wt
# Out:
# ['Penn St.',
#  'Nevada',
#  'Akron',
#  'Louisiana Tech',
#  'Old Dominion',
#  'UC Irvine',
#  'South Alabama',
#  'Texas St.',
#  'South Dakota',
#  'Cleveland St.',
#  'North Dakota St.',
#  'Dayton',
#  'UTSA',
#  'Stetson',
#  'UAB',
#  'Arkansas St.',
#  'Cal St. Northridge',
#  'Youngstown St.',
#  'UMass Lowell',
#  'Northern Kentucky',
#  'Florida Gulf Coast',
#  'Wagner',
#  'Middle Tennessee',
#  'Fairleigh Dickinson',
#  'Dixie St.',
#  'Rice',
#  'Merrimack',
#  'North Dakota',
#  'Troy',
#  'IUPUI',
#  'Detroit',
#  'Western Illinois',
#  'Monmouth',
#  'Wright St.',
#  'Bellarmine',
#  'UT Arlington',
#  'Radford',
#  'Cal Baptist',
#  'Gardner Webb',
#  'Hawaii',
#  'Liberty']

# %%
year,month,day = get_yesterday()
name = path+"\\games\\"+str(year)+"_"+str(month)+"_"+str(day)+"_games.csv"
scores = pd.read_csv(name)

# %%
scores['home_score'] = -99
scores['away_score'] = -99
scores
# Out:
#                   home                 away  predict_kp  home_score  \
# 0             Penn St.             Maryland           3         -99
# 1               Nevada            Boise St.          -3         -99
# 2             Kent St.                Akron           2         -99
# 3          North Texas       Louisiana Tech           5         -99
# 4         Old Dominion             Marshall          -4         -99
# 5     Florida Atlantic     Western Kentucky          -6         -99
# 6            UC Irvine  Cal St. Bakersfield           5         -99
# 7        South Alabama     Coastal Carolina          -2         -99
# 8            Texas St.          Little Rock           3         -99
# 9     South Dakota St.         South Dakota           7         -99
# 10             Oakland        Cleveland St.          -1         -99
# 11    North Dakota St.         Oral Roberts           4         -99
# 12              Dayton         George Mason           8         -99
# 13                 FIU                 UTSA           1         -99
# 14             Stetson             Lipscomb           2         -99
# 15                 UAB                 UTEP           8         -99
# 16        Arkansas St.            Louisiana          -4         -99
# 17  Cal St. Northridge             UC Davis          -3         -99
# 18       Robert Morris       Youngstown St.           1         -99
# 19       New Hampshire         UMass Lowell          -1         -99
# 20           Milwaukee    Northern Kentucky           3         -99
# 21  Florida Gulf Coast        North Alabama           1         -99
# 22      St. Francis NY               Wagner           1         -99
# 23    Middle Tennessee            Charlotte          -4         -99
# 24                 LIU  Fairleigh Dickinson           4         -99
# 25           Dixie St.              Seattle          -2         -99
# 26                Rice        Southern Miss           5         -99
# 27           Merrimack       St. Francis PA           2         -99
# 28              Denver         North Dakota          -1         -99
# 29                Troy     Georgia Southern           3         -99
# 30           Green Bay                IUPUI           5         -99
# 31             Detroit    Purdue Fort Wayne           7         -99
# 32      Nebraska Omaha     Western Illinois           5         -99
# 33           Manhattan             Monmouth          -6         -99
# 34    Illinois Chicago           Wright St.         -11         -99
# 35          Bellarmine         Jacksonville           7         -99
# 36        UT Arlington     Louisiana Monroe           9         -99
# 37             Radford          USC Upstate           8         -99
# 38      New Mexico St.          Cal Baptist          11         -99
# 39        Gardner Webb         Presbyterian          10         -99
# 40              Hawaii             Cal Poly          12         -99
#
#     away_score
# 0          -99
# 1          -99
# 2          -99
# 3          -99
# 4          -99
# 5          -99
# 6          -99
# 7          -99
# 8          -99
# 9          -99
# 10         -99
# 11         -99
# 12         -99
# 13         -99
# 14         -99
# 15         -99
# 16         -99
# 17         -99
# 18         -99
# 19         -99
# 20         -99
# 21         -99
# 22         -99
# 23         -99
# 24         -99
# 25         -99
# 26         -99
# 27         -99
# 28         -99
# 29         -99
# 30         -99
# 31         -99
# 32         -99
# 33         -99
# 34         -99
# 35         -99
# 36         -99
# 37         -99
# 38         -99
# 39         -99
# 40         -99

# %%
for index, row in scores.iterrows():
    home = row['home']
    away = row['away']
    for i,x in enumerate(wt):
        if home == x:
            scores.loc[index,'home_score'] = int(ws[i])
        if away == x:
            scores.loc[index,'away_score'] = int(ws[i])
        if home == lt[i]:
            scores.loc[index,'home_score'] = int(ls[i])
        if away == lt[i]:
            scores.loc[index,'away_score'] = int(ls[i])

# %%
scores = scores.drop(columns=['predict_kp'])

# %%
scores = scores[scores['home_score']!=-99]
scores['score'] = scores['home_score'] - scores['away_score']
scores['date'] = str(year)+'-'+str("{0:0=2d}".format(month))+'-'+str("{0:0=2d}".format(day))
scores
# Out:
#                   home                 away  home_score  away_score  score  \
# 0             Penn St.             Maryland          55          50      5
# 1               Nevada            Boise St.          74          72      2
# 2             Kent St.                Akron          61          72    -11
# 3          North Texas       Louisiana Tech          63          68     -5
# 4         Old Dominion             Marshall          82          81      1
# 6            UC Irvine  Cal St. Bakersfield          70          53     17
# 7        South Alabama     Coastal Carolina          71          65      6
# 8            Texas St.          Little Rock          57          47     10
# 9     South Dakota St.         South Dakota          56          64     -8
# 10             Oakland        Cleveland St.          72          80     -8
# 11    North Dakota St.         Oral Roberts          61          54      7
# 12              Dayton         George Mason          74          65      9
# 13                 FIU                 UTSA          80          87     -7
# 14             Stetson             Lipscomb          73          68      5
# 15                 UAB                 UTEP          63          51     12
# 16        Arkansas St.            Louisiana          95          87      8
# 17  Cal St. Northridge             UC Davis          80          77      3
# 18       Robert Morris       Youngstown St.          78          84     -6
# 19       New Hampshire         UMass Lowell          69          74     -5
# 20           Milwaukee    Northern Kentucky          73          87    -14
# 21  Florida Gulf Coast        North Alabama          86          60     26
# 22      St. Francis NY               Wagner          81          84     -3
# 23    Middle Tennessee            Charlotte          66          65      1
# 24                 LIU  Fairleigh Dickinson          62          77    -15
# 25           Dixie St.              Seattle          77          76      1
# 26                Rice        Southern Miss          88          62     26
# 27           Merrimack       St. Francis PA          59          54      5
# 28              Denver         North Dakota          82          85     -3
# 29                Troy     Georgia Southern          68          56     12
# 30           Green Bay                IUPUI          71          80     -9
# 31             Detroit    Purdue Fort Wayne          82          72     10
# 32      Nebraska Omaha     Western Illinois          77          85     -8
# 33           Manhattan             Monmouth          65          70     -5
# 34    Illinois Chicago           Wright St.          47          72    -25
# 35          Bellarmine         Jacksonville          71          56     15
# 36        UT Arlington     Louisiana Monroe          63          56      7
# 37             Radford          USC Upstate         102          66     36
# 38      New Mexico St.          Cal Baptist          75          85    -10
# 39        Gardner Webb         Presbyterian          91          64     27
# 40              Hawaii             Cal Poly          84          68     16
#
#           date
# 0   2021-02-05
# 1   2021-02-05
# 2   2021-02-05
# 3   2021-02-05
# 4   2021-02-05
# 6   2021-02-05
# 7   2021-02-05
# 8   2021-02-05
# 9   2021-02-05
# 10  2021-02-05
# 11  2021-02-05
# 12  2021-02-05
# 13  2021-02-05
# 14  2021-02-05
# 15  2021-02-05
# 16  2021-02-05
# 17  2021-02-05
# 18  2021-02-05
# 19  2021-02-05
# 20  2021-02-05
# 21  2021-02-05
# 22  2021-02-05
# 23  2021-02-05
# 24  2021-02-05
# 25  2021-02-05
# 26  2021-02-05
# 27  2021-02-05
# 28  2021-02-05
# 29  2021-02-05
# 30  2021-02-05
# 31  2021-02-05
# 32  2021-02-05
# 33  2021-02-05
# 34  2021-02-05
# 35  2021-02-05
# 36  2021-02-05
# 37  2021-02-05
# 38  2021-02-05
# 39  2021-02-05
# 40  2021-02-05

# %%
scores.to_csv('df.csv', index=False)
