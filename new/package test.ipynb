# %%
from kenpompy.utils import login

# Returns an authenticated browser that can then be used to scrape pages that require authorization.
browser = login('tarik0219@yahoo.com', 'kenporn123')

# %%
import kenpompy.summary as kp

# Returns a pandas dataframe containing the efficiency and tempo stats for the current season (https://kenpom.com/summary.php).
eff_stats = kp.get_efficiency(browser)

# %%
eff_stats
# Out:
#                  Team Conference Tempo-Adj Tempo-Adj.Rank Tempo-Raw  \
# 0          Coppin St.       MEAC      77.7              1      79.2
# 1         The Citadel         SC      77.2              2      77.4
# 2              Bryant        NEC      76.6              3      78.8
# 3            Monmouth       MAAC      76.3              4      76.3
# 4            Winthrop       BSth      76.2              5      75.4
# ..                ...        ...       ...            ...       ...
# 368         Air Force        MWC      63.1            353      64.7
# 369              UMKC        Sum      62.9            354      63.8
# 370  Mount St. Mary's        NEC      62.2            355      64.6
# 371        Evansville        MVC      61.7            356      63.1
# 372          Virginia        ACC      60.4            357      61.4
#
#     Tempo-Raw.Rank Avg. Poss Length-Offense Avg. Poss Length-Offense.Rank  \
# 0                1                     14.1                             1
# 1                3                     14.5                             9
# 2                2                     14.4                             5
# 3                6                     14.5                             7
# 4               16                     14.2                             3
# ..             ...                      ...                           ...
# 368            337                     19.4                           340
# 369            343                     19.4                           338
# 370            339                     20.1                           345
# 371            344                     21.1                           347
# 372            347                     19.7                           344
#
#     Avg. Poss Length-Defense Avg. Poss Length-Defense.Rank  \
# 0                       16.0                            19
# 1                       16.6                            89
# 2                       16.0                            20
# 3                       17.1                           171
# 4                       17.6                           262
# ..                       ...                           ...
# 368                     17.4                           230
# 369                     18.0                           311
# 370                     16.7                           104
# 371                     16.3                            40
# 372                     18.8                           346
#
#     Off. Efficiency-Adj Off. Efficiency-Adj.Rank Off. Efficiency-Raw  \
# 0                  89.7                      345                89.2
# 1                 101.6                      175               109.9
# 2                 102.8                      141               108.0
# 3                 101.9                      167               103.3
# 4                 105.0                      105               109.9
# ..                  ...                      ...                 ...
# 368                96.7                      269                91.4
# 369                96.8                      267                96.6
# 370                96.2                      277                97.1
# 371                98.3                      240                99.7
# 372               115.7                        9               118.7
#
#     Off. Efficiency-Raw.Rank Def. Efficiency-Adj Def. Efficiency-Adj.Rank  \
# 0                        325               103.5                      204
# 1                         39               113.2                      350
# 2                         58               104.4                      226
# 3                        123               102.2                      178
# 4                         38                98.5                      115
# ..                       ...                 ...                      ...
# 368                      310               109.7                      325
# 369                      244               102.8                      191
# 370                      234               102.8                      189
# 371                      179               107.6                      297
# 372                        6                89.9                        9
#
#     Def. Efficiency-Raw Def. Efficiency-Raw.Rank
# 0                 101.3                      177
# 1                 113.2                      331
# 2                  97.7                      112
# 3                  95.4                       70
# 4                  93.0                       39
# ..                  ...                      ...
# 368               114.3                      338
# 369               103.4                      229
# 370                97.9                      115
# 371               107.1                      287
# 372                95.4                       73
#
# [357 rows x 18 columns]

# %%
import kenpompy.FanMatch as fm

# %%
fm
# Out:
# <module 'kenpompy.FanMatch' from 'C:\\Program Files (x86)\\Microsoft Visual Studio\\Shared\\Python36_64\\lib\\site-packages\\kenpompy\\FanMatch.py'>

# %%
test = fm.FanMatch(browser, date = "2021-01-25")

# %%
test.fm_df
# Out:
#                                                  Game  \
# 0               16 West Virginia 88, 13 Texas Tech 87
# 1                       9 Virginia 81, 36 Syracuse 58
# 2                  38 Oklahoma St. 81, 96 Iowa St. 60
# 3                    27 Arizona 80, 72 Arizona St. 67
# 4                         127 UNLV 59, 49 Utah St. 56
# 5                21 Loyola Chicago 65, 117 Bradley 58
# 6        145 Indiana St. 69, 195 Southern Illinois 66
# 7                226 Radford 73, 224 UNC Asheville 63
# 8            129 Loyola Marymount 75, 298 Portland 50
# 9   276 Prairie View A&M 73, 352 Arkansas Pine Blu...
# 10                353 Alabama St. 66, 275 Southern 64
# 11             346 Presbyterian 71, 286 High Point 56
# 12    184 Gardner Webb 80, 340 Charleston Southern 71
# 13    119 New Mexico St. 70, NR Western New Mexico 41
# 14           328 Tarleton St. 113, NR Howard Payne 53
# 15                    152 Northern Iowa 70, NR Coe 60
#
#                                      Location ThrillScore Comeback Excitement  \
# 0                 Morgantown, WV WVU Coliseum        78.4       12       2.26
# 1   Charlottesville, VA John Paul Jones Arena        63.8        4       0.40
# 2                    Ames, IA Hilton Coliseum        59.1       11       0.64
# 3           Tucson, AZ McKale Memorial Center        56.9        0      -0.21
# 4          Las Vegas, NV Thomas & Mack Center        50.7        6       2.06
# 5                     Peoria, IL Carver Arena        50.3       10       1.97
# 6               Terre Haute, IN Hulman Center        32.4        7       2.50
# 7                  Asheville, NC Kimmel Arena        31.9        0       0.52
# 8         Portland, OR Earle A. Chiles Center        24.9        4      -0.20
# 9               Pine Bluff, AR Clemmons Arena        19.5        0      -0.35
# 10         Montgomery, AL Dunn-Oliver Acadome        18.9       15       1.27
# 11               High Point, NC Millis Center        18.3        9       1.28
# 12      Boiling Springs, NC Paul Porter Arena        14.3        7       0.83
# 13             El Paso, TX Don Haskins Center        0.01      NaN        NaN
# 14          Stephenville, TX Wisdom Gymnasium        0.01      NaN        NaN
# 15              Cedar Falls, IA McLeod Center        0.01      NaN        NaN
#
#    ThrillScoreRank  ExcitementRank  ComebackRank  \
# 0                1             NaN           NaN
# 1                2             NaN           NaN
# 2                3             NaN           NaN
# 3                4             NaN           NaN
# 4                5             NaN           NaN
# 5                6             NaN           NaN
# 6                7             NaN           NaN
# 7                8             NaN           NaN
# 8                9             NaN           NaN
# 9               10             NaN           NaN
# 10              11             NaN           NaN
# 11              12             NaN           NaN
# 12              13             NaN           NaN
# 13               4             NaN           NaN
# 14               4             NaN           NaN
# 15               4             NaN           NaN
#
#                                                 MVP Possessions  ...  \
# 0                      Miles McBride (24p/7r/6a/1s)          71  ...
# 1                       Jay Huff (21p/12r/2a/2b/1s)          71  ...
# 2   Matthew-Alexander Moncrieffe (22p/12r/2a/1b/1s)          76  ...
# 3                      Terrell Brown (18p/4r/3a/4s)          75  ...
# 4                      Marco Anthony (18p/9r/3a/2s)          72  ...
# 5                   Marquise Kennedy (18p/9r/2a/3s)          67  ...
# 6                      Tyreke Key (23p/7r/2a/1b/2s)          66  ...
# 7                      Lewis Djonkam (12p/5r/1a/1b)          66  ...
# 8                    Mattias Markusson (25p/13r/3b)          58  ...
# 9                  Jeremiah Gambrell (23p/2r/3a/1s)          64  ...
# 10                      Kenny Strawbridge (16p/14r)          72  ...
# 11                      Brandon Younger (18p/9r/1s)          67  ...
# 12                      Jaheam Cornwall (21p/5r/5a)          61  ...
# 13                   Wilfried Likayi (20p/6r/1a/1b)          65  ...
# 14                    Montre' Gipson (23p/8r/6a/2s)          76  ...
# 15                     Nate Heise (18p/5r/4a/1b/3s)          68  ...
#
#    PredictedMOV       PredictedLoser   OT                Loser LoserRank  \
# 0           2.0           Texas Tech  nan           Texas Tech        13
# 1           7.0             Syracuse  nan             Syracuse        36
# 2           4.0             Iowa St.  nan             Iowa St.        96
# 3           7.0          Arizona St.  nan          Arizona St.        72
# 4           6.0                 UNLV  nan             Utah St.        49
# 5           7.0              Bradley  nan              Bradley       117
# 6           5.0    Southern Illinois  nan    Southern Illinois       195
# 7           2.0              Radford  nan        UNC Asheville       224
# 8           9.0             Portland  nan             Portland       298
# 9           8.0  Arkansas Pine Bluff  nan  Arkansas Pine Bluff       352
# 10          8.0          Alabama St.  nan             Southern       275
# 11          9.0         Presbyterian  nan           High Point       286
# 12         13.0  Charleston Southern  nan  Charleston Southern       340
# 13          NaN       New Mexico St.  nan   Western New Mexico        NR
# 14          NaN         Tarleton St.  nan         Howard Payne        NR
# 15          NaN        Northern Iowa  nan                  Coe        NR
#
#    LoserScore            Winner WinnerRank WinnerScore ActualMOV
# 0          87     West Virginia         16          88         1
# 1          58          Virginia          9          81        23
# 2          60      Oklahoma St.         38          81        21
# 3          67           Arizona         27          80        13
# 4          56              UNLV        127          59         3
# 5          58    Loyola Chicago         21          65         7
# 6          66       Indiana St.        145          69         3
# 7          63           Radford        226          73        10
# 8          50  Loyola Marymount        129          75        25
# 9          56  Prairie View A&M        276          73        17
# 10         64       Alabama St.        353          66         2
# 11         56      Presbyterian        346          71        15
# 12         71      Gardner Webb        184          80         9
# 13         41    New Mexico St.        119          70        29
# 14         53      Tarleton St.        328         113        60
# 15         60     Northern Iowa        152          70        10
#
# [16 rows x 23 columns]
