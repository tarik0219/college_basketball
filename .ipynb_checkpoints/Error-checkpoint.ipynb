# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.neural_network import MLPRegressor
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import matplotlib.pyplot as plt
from datetime import timedelta
from datetime import datetime
import os

# %%
df = pd.read_csv('all_e.csv')
df['win'] = -99
df.tail(10)
# Out:
#                    home                away  line  draft_kings  diff  score  \
# 464        Northeastern                Elon   5.0          6.5   1.5      8
# 465      Nebraska Omaha        Oral Roberts  -5.0         -3.5   1.5    -11
# 466   George Washington            Duquesne  -9.0         -7.5   1.5      2
# 467            Hartford          Binghamton   9.0          8.0   1.0      3
# 468        South Dakota              Denver  12.0         12.5   0.5     22
# 469               Drake   Southern Illinois  11.0         10.5   0.5     18
# 470        Missouri St.         Indiana St.   5.0          5.0   0.0      4
# 471  South Carolina St.  North Carolina A&T -10.0        -10.0   0.0     -7
# 472            Michigan        Northwestern   8.0          8.0   0.0     19
# 473             Hofstra      William & Mary  11.0         11.0   0.0      9
#
#          date  win
# 464  1/3/2021  -99
# 465  1/3/2021  -99
# 466  1/3/2021  -99
# 467  1/3/2021  -99
# 468  1/3/2021  -99
# 469  1/3/2021  -99
# 470  1/3/2021  -99
# 471  1/3/2021  -99
# 472  1/3/2021  -99
# 473  1/3/2021  -99

# %%
for index, row in df.iterrows():
    line = row['line']
    dk = row['draft_kings']
    score = row['score']
    win = -99
    if line > dk:
        if score > dk:
            win = 1
        elif score < dk:
            win = 0
        else:
            win = 2
    elif line < dk:
        if score < dk:
            win = 1
        elif score > dk:
            win = 0
        else:
            win = 2
    else:
        win = 2
    
    
    df.loc[index,'win'] = win

# %%
df.sort_values(by=['diff'], ascending = False)
# Out:
#                  home              away  line  draft_kings  diff  score  \
# 371      San Jose St.         Boise St. -18.0        -26.5   8.5     -1
# 372  Georgia Southern     South Alabama  -5.0          2.0   7.0     13
# 16                BYU              Utah  -5.0          2.0   7.0     18
# 178           Gonzaga  Northwestern St.  34.0         40.5   6.5     38
# 128            Howard           Hampton   8.0          1.5   6.5      5
# ..                ...               ...   ...          ...   ...    ...
# 115              Troy           Samford  -1.0         -1.0   0.0      8
# 298     New Hampshire          Hartford   4.0          4.0   0.0      2
# 93          Tennessee   Appalachian St.  19.0         19.0   0.0     41
# 91        Saint Louis       Indiana St.  13.0         13.0   0.0     19
# 473           Hofstra    William & Mary  11.0         11.0   0.0      9
#
#            date  win
# 371    1/2/2021    1
# 372    1/2/2021    0
# 16   12/12/2020    0
# 178  12/21/2020    1
# 128  12/18/2020    1
# ..          ...  ...
# 115  12/16/2020    2
# 298  12/28/2020    2
# 93   12/15/2020    2
# 91   12/15/2020    2
# 473    1/3/2021    2
#
# [474 rows x 8 columns]

# %%
def get_yesterday():
    today = datetime.today()
    yesterday = today - timedelta(days = 1)
    year = yesterday.year
    month = yesterday.month
    day = yesterday.day
    return year,month,day
year,month,day = get_yesterday()

# %%
date = str(month)+'/'+str(day)+'/'+str(year)
date
# Out:
# '1/3/2021'

# %%
df_yesterday = df[df['date'] == date]

# %%
df_yesterday['win'].value_counts(sort = False)
# Out:
# 0    9
# 1    6
# 2    4
# Name: win, dtype: int64

# %%
df_yesterday['line_diff'] = abs(df_yesterday['line'] - df_yesterday['score'])
df_yesterday['dk_diff'] = abs(df_yesterday['draft_kings'] - df_yesterday['score'])
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df_yesterday['line_diff'].mean(),df_yesterday['dk_diff'].mean())
# Out:
# 7.2631578947368425 6.684210526315789

# %%
df['line_diff'] = abs(df['line'] - df['score'])
df['dk_diff'] = abs(df['draft_kings'] - df['score'])

# %%
print(df['line_diff'].mean(),df['dk_diff'].mean())
# Out:
# 9.453586497890296 9.218354430379748

# %%
df_yesterday_3 = df_yesterday[df_yesterday['diff'] > 3.0]
df_yesterday_3['win'].value_counts(sort = False)
# Out:
# 0    3
# 1    1
# Name: win, dtype: int64

# %%
df['win'].value_counts(sort = False)
# Out:
# 0    227
# 1    203
# 2     44
# Name: win, dtype: int64

# %%
df_3 = df[df['diff'] > 3.0]

# %%
df_3['win'].value_counts(sort = False)
# Out:
# 0    35
# 1    38
# Name: win, dtype: int64

# %%
df_3_5 = df[df['diff'] > 3.5]
df_3_5['win'].value_counts(sort = False)
# Out:
# 0    19
# 1    23
# Name: win, dtype: int64

# %%
bet = 10

# %%
df_3['line_diff'] = abs(df_3['line'] - df_3['score'])
df_3['dk_diff'] = abs(df_3['draft_kings'] - df_3['score'])
print(df_3['line_diff'].mean(),df_3['dk_diff'].mean())
# Out:
# 10.945205479452055 10.39041095890411
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
win = []
loss = []
index = []
for i in range(0,20):
    x = i/2
    df_new = df[df['diff'] == x]
    series = df_new['win'].value_counts(sort = False)
    
    index.append(x)
    try:
        win.append(series[1])
    except:
        win.append(0)
    try:
        loss.append(series[0])
    except:
        loss.append(0)

# %%
win_percentage = []
for i,x in enumerate(win):
    if (win[i]+loss[i]) != 0:
        if win[i] == 0:
            win_percentage.append(1/100)
        else:
            win_percentage.append(win[i]/(win[i]+loss[i]))
    else:
        win_percentage.append(0)

# %%
plot = pd.DataFrame({'Win_percentage': win_percentage}, index=index)
ax = plot.plot.bar(rot=0, figsize=(20,10))
plt.axhline(y=.5,linewidth=1, color='k')

# %%
df_yesterday
# Out:
#                  home                    away  line  draft_kings  diff  score  \
# 299             Tulsa                 Houston -11.0         -7.5   3.5      1
# 300               USC             Santa Clara  13.0         10.0   3.0     23
# 301           Memphis           South Florida   6.0          9.0   3.0      1
# 302             Lamar  Southeastern Louisiana   2.0          5.0   3.0     10
# 303            Baylor        Central Arkansas  32.0         34.0   2.0     37
# 304            Mercer                 Wofford   0.0          2.0   2.0    -13
# 305           Gonzaga               Dixie St.  36.0         37.5   1.5     45
# 306  Eastern Michigan        Central Michigan   6.0          4.5   1.5    -27
# 307               LSU               Texas A&M   8.0          6.5   1.5     23
# 308     West Virginia            Northeastern  19.0         18.0   1.0     22
# 309              Iowa            Northwestern  10.0         10.5   0.5     15
# 310        Texas Tech          Incarnate Word  34.0         34.5   0.5     28
# 311           Clemson             Florida St.   2.0          1.5   0.5     10
#
#            date  win  line_diff  dk_diff
# 299  12/29/2020    0       12.0      8.5
# 300  12/29/2020    1       10.0     13.0
# 301  12/29/2020    1        5.0      8.0
# 302  12/29/2020    0        8.0      5.0
# 303  12/29/2020    0        5.0      3.0
# 304  12/29/2020    1       13.0     15.0
# 305  12/29/2020    0        9.0      7.5
# 306  12/29/2020    0       33.0     31.5
# 307  12/29/2020    1       15.0     16.5
# 308  12/29/2020    1        3.0      4.0
# 309  12/29/2020    0        5.0      4.5
# 310  12/29/2020    1        6.0      6.5
# 311  12/29/2020    1        8.0      8.5

# %%
plot = pd.DataFrame({'Win': win,
                   'loss': loss}, index=index)
ax = plot.plot.bar(rot=0, figsize=(20,10))

# %%
import time
conf = {}
options = webdriver.ChromeOptions() 
#options.add_argument(r'''user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data''')
#"user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data" home
# "user-data-dir=C:\Users\koric1\AppData\Local\Google\Chrome\User Data" work
#options.add_argument("--start-maximized")
#self.options.add_argument("--headless")
#self.options.add_argument("--no-sandbox")
#self.options.add_argument("--disable-gpu")
options.add_argument('--headless')
options.add_argument('--disable-gpu')  # Last I checked this was necessa
driver = webdriver.Chrome(chrome_options= options)



driver.get('https://kenpom.com/')
time.sleep(1)

for x in range(1,10):
    try:
        for z in range(1,41):

            team_name = str(driver.find_element_by_xpath('//*[@id="ratings-table"]/tbody['+str(x)+']/tr['+str(z)+']/td[2]/a').text)
            team_conf = str(driver.find_element_by_xpath('//*[@id="ratings-table"]/tbody['+str(x)+']/tr['+str(z)+']/td[3]').text)
            conf[team_name] = team_conf
    except:
        break
driver.close()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: use options instead of chrome_options
#   del sys.path[0]

# %%
conf
# Out:
# {'Gonzaga': 'WCC',
#  'Baylor': 'B12',
#  'Villanova': 'BE',
#  'Iowa': 'B10',
#  'West Virginia': 'B12',
#  'Wisconsin': 'B10',
#  'Texas': 'B12',
#  'Kansas': 'B12',
#  'Texas Tech': 'B12',
#  'Illinois': 'B10',
#  'Tennessee': 'SEC',
#  'Duke': 'ACC',
#  'Houston': 'Amer',
#  'Florida St.': 'ACC',
#  'Creighton': 'BE',
#  'Michigan': 'B10',
#  'Indiana': 'B10',
#  'Virginia': 'ACC',
#  'Rutgers': 'B10',
#  'Michigan St.': 'B10',
#  'Clemson': 'ACC',
#  'Louisville': 'ACC',
#  'Oregon': 'P12',
#  'Ohio St.': 'B10',
#  'Florida': 'SEC',
#  'UCLA': 'P12',
#  'North Carolina': 'ACC',
#  'Saint Louis': 'A10',
#  'San Diego St.': 'MWC',
#  'Syracuse': 'ACC',
#  'Purdue': 'B10',
#  'LSU': 'SEC',
#  'Colorado': 'P12',
#  'Stanford': 'P12',
#  'Arkansas': 'SEC',
#  'Missouri': 'SEC',
#  'Oklahoma': 'B12',
#  'Mississippi': 'SEC',
#  'USC': 'P12',
#  'Kentucky': 'SEC',
#  'Virginia Tech': 'ACC',
#  'Marquette': 'BE',
#  'N.C. State': 'ACC',
#  'Arizona': 'P12',
#  'Penn St.': 'B10',
#  'Connecticut': 'BE',
#  'Seton Hall': 'BE',
#  'SMU': 'Amer',
#  'Xavier': 'BE',
#  'Oklahoma St.': 'B12',
#  'Maryland': 'B10',
#  'Alabama': 'SEC',
#  'Richmond': 'A10',
#  'VCU': 'A10',
#  'Minnesota': 'B10',
#  'Loyola Chicago': 'MVC',
#  'Memphis': 'Amer',
#  'Arizona St.': 'P12',
#  'TCU': 'B12',
#  'Dayton': 'A10',
#  'Providence': 'BE',
#  'Miami FL': 'ACC',
#  'Utah': 'P12',
#  'Butler': 'BE',
#  "Saint Mary's": 'WCC',
#  'Furman': 'SC',
#  'Cincinnati': 'Amer',
#  'Northwestern': 'B10',
#  'South Carolina': 'SEC',
#  'San Francisco': 'WCC',
#  'Georgia Tech': 'ACC',
#  'St. Bonaventure': 'A10',
#  'Rhode Island': 'A10',
#  'Pittsburgh': 'ACC',
#  'Auburn': 'SEC',
#  'Notre Dame': 'ACC',
#  'BYU': 'WCC',
#  'Mississippi St.': 'SEC',
#  'Texas A&M': 'SEC',
#  'Western Kentucky': 'CUSA',
#  'DePaul': 'BE',
#  'Davidson': 'A10',
#  'Marshall': 'CUSA',
#  'Duquesne': 'A10',
#  'Utah St.': 'MWC',
#  'Northern Iowa': 'MVC',
#  'UAB': 'CUSA',
#  'Iowa St.': 'B12',
#  'Vermont': 'AE',
#  'Boise St.': 'MWC',
#  "St. John's": 'BE',
#  'South Dakota St.': 'Sum',
#  'Georgia': 'SEC',
#  'Wichita St.': 'Amer',
#  'Georgetown': 'BE',
#  'Toledo': 'MAC',
#  'South Florida': 'Amer',
#  'Tulsa': 'Amer',
#  'North Texas': 'CUSA',
#  'Boston College': 'ACC',
#  'Yale': 'Ivy',
#  'Murray St.': 'OVC',
#  'Pepperdine': 'WCC',
#  'Wright St.': 'Horz',
#  'New Mexico St.': 'WAC',
#  'Washington': 'P12',
#  'Georgia St.': 'SB',
#  'Colorado St.': 'MWC',
#  'Ohio': 'MAC',
#  'Massachusetts': 'A10',
#  'Winthrop': 'BSth',
#  'Belmont': 'OVC',
#  'UCF': 'Amer',
#  'Liberty': 'ASun',
#  'Old Dominion': 'CUSA',
#  'Bradley': 'MVC',
#  'Santa Clara': 'WCC',
#  'UNC Greensboro': 'SC',
#  'Nebraska': 'B10',
#  'Drake': 'MVC',
#  'George Mason': 'A10',
#  'Buffalo': 'MAC',
#  'Abilene Christian': 'Slnd',
#  'Nevada': 'MWC',
#  'Louisiana Tech': 'CUSA',
#  'Wake Forest': 'ACC',
#  'East Carolina': 'Amer',
#  'UC Santa Barbara': 'BW',
#  'Vanderbilt': 'SEC',
#  'Oregon St.': 'P12',
#  'Wofford': 'SC',
#  'Ball St.': 'MAC',
#  'Pacific': 'WCC',
#  'Eastern Washington': 'BSky',
#  'California': 'P12',
#  'Loyola Marymount': 'WCC',
#  'UNLV': 'MWC',
#  'Little Rock': 'SB',
#  'Siena': 'MAAC',
#  'Princeton': 'Ivy',
#  'Indiana St.': 'MVC',
#  'Kent St.': 'MAC',
#  'Grand Canyon': 'WAC',
#  'Akron': 'MAC',
#  'Colgate': 'Pat',
#  'Kansas St.': 'B12',
#  'Temple': 'Amer',
#  'Mercer': 'SC',
#  'Washington St.': 'P12',
#  'Montana': 'BSky',
#  'Fresno St.': 'MWC',
#  'Harvard': 'Ivy',
#  'UC Riverside': 'BW',
#  'Drexel': 'CAA',
#  'Hofstra': 'CAA',
#  'Texas St.': 'SB',
#  'UC Irvine': 'BW',
#  'UTEP': 'CUSA',
#  'Valparaiso': 'MVC',
#  'UT Arlington': 'SB',
#  'Northeastern': 'CAA',
#  "Saint Joseph's": 'A10',
#  'Southern Illinois': 'MVC',
#  'San Diego': 'WCC',
#  "Saint Peter's": 'MAAC',
#  'Louisiana': 'SB',
#  'Charlotte': 'CUSA',
#  'Bowling Green': 'MAC',
#  'Eastern Michigan': 'MAC',
#  'Missouri St.': 'MVC',
#  'North Dakota St.': 'Sum',
#  'Stephen F. Austin': 'Slnd',
#  'Wyoming': 'MWC',
#  'FIU': 'CUSA',
#  'Chattanooga': 'SC',
#  'Coastal Carolina': 'SB',
#  'East Tennessee St.': 'SC',
#  'La Salle': 'A10',
#  'Youngstown St.': 'Horz',
#  'Southern Utah': 'BSky',
#  'Boston University': 'Pat',
#  'Navy': 'Pat',
#  'UMBC': 'AE',
#  'Eastern Illinois': 'OVC',
#  'UTSA': 'CUSA',
#  'Fordham': 'A10',
#  'Austin Peay': 'OVC',
#  'Oral Roberts': 'Sum',
#  'Montana St.': 'BSky',
#  'UC San Diego': 'BW',
#  'UC Davis': 'BW',
#  'Monmouth': 'MAAC',
#  'Penn': 'Ivy',
#  'Northern Colorado': 'BSky',
#  'Cornell': 'Ivy',
#  'NJIT': 'AE',
#  'Appalachian St.': 'SB',
#  'Charleston': 'CAA',
#  'Eastern Kentucky': 'OVC',
#  'Western Carolina': 'SC',
#  'Middle Tennessee': 'CUSA',
#  'Detroit': 'Horz',
#  'Northern Kentucky': 'Horz',
#  'Cal St. Bakersfield': 'BW',
#  'Elon': 'CAA',
#  'New Mexico': 'MWC',
#  'Tulane': 'Amer',
#  'South Dakota': 'Sum',
#  'Sacramento St.': 'BSky',
#  'Army': 'Pat',
#  'Miami OH': 'MAC',
#  'South Alabama': 'SB',
#  'Purdue Fort Wayne': 'Horz',
#  'Florida Atlantic': 'CUSA',
#  'UNC Asheville': 'BSth',
#  'Illinois Chicago': 'Horz',
#  'Lipscomb': 'ASun',
#  'New Hampshire': 'AE',
#  'Bryant': 'NEC',
#  'Towson': 'CAA',
#  'UT Rio Grande Valley': 'WAC',
#  'UMass Lowell': 'AE',
#  'Texas Southern': 'SWAC',
#  'UNC Wilmington': 'CAA',
#  'Illinois St.': 'MVC',
#  'Brown': 'Ivy',
#  'Lafayette': 'Pat',
#  'Cleveland St.': 'Horz',
#  'Robert Morris': 'Horz',
#  'Canisius': 'MAAC',
#  'Central Michigan': 'MAC',
#  'Georgia Southern': 'SB',
#  'Gardner Webb': 'BSth',
#  'Hawaii': 'BW',
#  'Nicholls St.': 'Slnd',
#  "Mount St. Mary's": 'NEC',
#  'Delaware': 'CAA',
#  'Norfolk St.': 'MEAC',
#  'Jacksonville St.': 'OVC',
#  'George Washington': 'A10',
#  'Stetson': 'ASun',
#  'Central Arkansas': 'Slnd',
#  'VMI': 'SC',
#  'Bucknell': 'Pat',
#  'Florida Gulf Coast': 'ASun',
#  'Nebraska Omaha': 'Sum',
#  'Rice': 'CUSA',
#  'Loyola MD': 'Pat',
#  'Iona': 'MAAC',
#  'Campbell': 'BSth',
#  'Long Beach St.': 'BW',
#  'Marist': 'MAAC',
#  'William & Mary': 'CAA',
#  'Milwaukee': 'Horz',
#  'American': 'Pat',
#  'North Dakota': 'Sum',
#  'St. Francis PA': 'NEC',
#  'Air Force': 'MWC',
#  'Western Michigan': 'MAC',
#  'IUPUI': 'Horz',
#  'Bellarmine': 'ASun',
#  'Portland': 'WCC',
#  'Rider': 'MAAC',
#  'Niagara': 'MAAC',
#  'North Alabama': 'ASun',
#  'North Carolina Central': 'MEAC',
#  'Hartford': 'AE',
#  'Stony Brook': 'AE',
#  'Dartmouth': 'Ivy',
#  'Quinnipiac': 'MAAC',
#  'Cal St. Northridge': 'BW',
#  'Green Bay': 'Horz',
#  'Samford': 'SC',
#  'Cal Baptist': 'WAC',
#  'LIU': 'NEC',
#  'Fairleigh Dickinson': 'NEC',
#  'Louisiana Monroe': 'SB',
#  'James Madison': 'CAA',
#  'Northwestern St.': 'Slnd',
#  'Columbia': 'Ivy',
#  'Arkansas St.': 'SB',
#  'UMKC': 'Sum',
#  'High Point': 'BSth',
#  'Weber St.': 'BSky',
#  'San Jose St.': 'MWC',
#  'Utah Valley': 'WAC',
#  'Troy': 'SB',
#  'Oakland': 'Horz',
#  'Lamar': 'Slnd',
#  'Southern': 'SWAC',
#  'Charleston Southern': 'BSth',
#  'Tennessee St.': 'OVC',
#  'Wagner': 'NEC',
#  'Lehigh': 'Pat',
#  'Morehead St.': 'OVC',
#  'Northern Illinois': 'MAC',
#  'Seattle': 'WAC',
#  'Albany': 'AE',
#  'North Florida': 'ASun',
#  'Merrimack': 'NEC',
#  'Manhattan': 'MAAC',
#  'Radford': 'BSth',
#  'Sam Houston St.': 'Slnd',
#  'Florida A&M': 'MEAC',
#  'Portland St.': 'BSky',
#  'Southern Miss': 'CUSA',
#  'Jacksonville': 'ASun',
#  'Prairie View A&M': 'SWAC',
#  'Dixie St.': 'WAC',
#  'Texas A&M Corpus Chris': 'Slnd',
#  'USC Upstate': 'BSth',
#  'Fairfield': 'MAAC',
#  'Idaho St.': 'BSky',
#  'Evansville': 'MVC',
#  'North Carolina A&T': 'MEAC',
#  'Grambling St.': 'SWAC',
#  'St. Francis NY': 'NEC',
#  'Longwood': 'BSth',
#  'New Orleans': 'Slnd',
#  'Howard': 'MEAC',
#  'Sacred Heart': 'NEC',
#  'Denver': 'Sum',
#  'Morgan St.': 'MEAC',
#  'Jackson St.': 'SWAC',
#  'Cal Poly': 'BW',
#  'Cal St. Fullerton': 'BW',
#  'The Citadel': 'SC',
#  'Tennessee Tech': 'OVC',
#  'Southeast Missouri St.': 'OVC',
#  'McNeese St.': 'Slnd',
#  'Southeastern Louisiana': 'Slnd',
#  'SIU Edwardsville': 'OVC',
#  'Coppin St.': 'MEAC',
#  'Northern Arizona': 'BSky',
#  'Tarleton St.': 'WAC',
#  'Central Connecticut': 'NEC',
#  'Tennessee Martin': 'OVC',
#  'Idaho': 'BSky',
#  'Hampton': 'BSth',
#  'Alabama A&M': 'SWAC',
#  'Alcorn St.': 'SWAC',
#  'Binghamton': 'AE',
#  'Western Illinois': 'Sum',
#  'Presbyterian': 'BSth',
#  'Incarnate Word': 'Slnd',
#  'Holy Cross': 'Pat',
#  'Maine': 'AE',
#  'Bethune Cookman': 'MEAC',
#  'Houston Baptist': 'Slnd',
#  'Kennesaw St.': 'ASun',
#  'Arkansas Pine Bluff': 'SWAC',
#  'Alabama St.': 'SWAC',
#  'Delaware St.': 'MEAC',
#  'Maryland Eastern Shore': 'MEAC',
#  'South Carolina St.': 'MEAC',
#  'Chicago St.': 'WAC',
#  'Mississippi Valley St.': 'SWAC'}

# %%
df['home_conf'] = df.apply(lambda x: conf[x['home']], axis = 1)
df['away_conf'] = df.apply(lambda x: conf[x['away']], axis = 1)
df.head()
# Out:
#             home                away  line  draft_kings  diff  score  \
# 0     Georgetown           Villanova -15.0        -11.5   3.5    -13
# 1     Charleston  South Carolina St.  23.0         19.5   3.5     27
# 2  West Virginia         North Texas  15.0         12.0   3.0     12
# 3           Iowa            Iowa St.  11.0         13.5   2.5     28
# 4       Canisius              Marist   6.0          3.5   2.5      9
#
#          date  win  line_diff  dk_diff home_conf away_conf
# 0  12/11/2020    1        2.0      1.5        BE        BE
# 1  12/11/2020    1        4.0      7.5       CAA      MEAC
# 2  12/11/2020    2        3.0      0.0       B12      CUSA
# 3  12/11/2020    0       17.0     14.5       B10       B12
# 4  12/11/2020    1        3.0      5.5      MAAC      MAAC

# %%
win = []
loss = []
index = []
for i in range(0,20):
    x = i/2
    df_new = df[(df['home_conf'] == 'B10')  |  (df['away_conf'] == 'B10')]
    df_new = df_new[(df_new['diff'] == x)]
    series = df_new['win'].value_counts(sort = False)

    index.append(x)
    try:
        win.append(series[1])
    except:
        win.append(0)
    try:
        loss.append(series[0])
    except:
        loss.append(0)

# %%
plot = pd.DataFrame({'Win': win,
                   'loss': loss}, index=index)
ax = plot.plot.bar(rot=0, figsize=(20,10))

# %%
df_new = df[(df['home_conf'] == 'B10')  |  (df['away_conf'] == 'B10')]
df_new
# Out:
#          home         away  line  draft_kings  diff  score        date  win  \
# 3        Iowa     Iowa St.  11.0         13.5   2.5     28  12/11/2020    0
# 6   Creighton     Nebraska  15.0         13.0   2.0     24  12/11/2020    1
# 44   Missouri     Illinois  -2.0         -3.0   1.0      3  12/12/2020    1
# 51     Purdue  Indiana St.  14.0         14.5   0.5     12  12/12/2020    1
# 72   Illinois    Minnesota   5.0          8.0   3.0     27  12/15/2020    0
# 95     Purdue     Ohio St.  -1.0          4.0   5.0      7  12/16/2020    0
#
#     line_diff  dk_diff home_conf away_conf
# 3        17.0     14.5       B10       B12
# 6         9.0     11.0        BE       B10
# 44        5.0      6.0       SEC       B10
# 51        2.0      2.5       B10       MVC
# 72       22.0     19.0       B10       B10
# 95        8.0      3.0       B10       B10
