# %%
import numpy as np
import pandas as pd

# %%
colnames=['home','away','SCORE_1','SCORE_2','OFF_1','DEF_1','TEMPO_1','LUCK_1','OFF_2','DEF_2','TEMPO_2','LUCK_2','date']
df = pd.read_csv('all.csv', names=colnames, header=None)

# %%
df
# Out:
#                 home              away  SCORE_1  SCORE_2  OFF_1  DEF_1  \
# 0               UNLV    North Carolina       51       78  102.5  100.2
# 1           Davidson             Texas       76       78  106.7   97.4
# 2           Duquesne       Little Rock       66       76  105.1   95.2
# 3                UCF            Auburn       63       55  100.5   95.1
# 4    Appalachian St.     Bowling Green       76       78   98.0  100.6
# ..               ...               ...      ...      ...    ...    ...
# 719           DePaul  Western Illinois       91       72  105.0   95.5
# 720        Minnesota              Iowa      102       95  108.9   93.3
# 721     Michigan St.         Wisconsin       76       85  111.7   93.2
# 722         Nebraska          Michigan       69       80  101.6   96.5
# 723           Purdue          Maryland       73       70  109.8   92.0
#
#      TEMPO_1  LUCK_1  OFF_2  DEF_2  TEMPO_2  LUCK_2        date
# 0       72.6   0.000  109.2   89.4     74.6   0.000  11/30/2020
# 1       69.9   0.000  108.6   85.9     71.5   0.000  11/30/2020
# 2       71.8   0.000  101.7   99.9     72.6   0.044  11/30/2020
# 3       71.3   0.000  106.3   94.8     73.1   0.184  11/30/2020
# 4       72.4   0.000  102.2  102.9     75.2  -0.051  11/30/2020
# ..       ...     ...    ...    ...      ...     ...         ...
# 719     72.1   0.000   92.5  108.8     72.6  -0.149  2020-12-23
# 720     74.9   0.174  119.5   94.4     73.7  -0.032  2020-12-25
# 721     72.9   0.090  112.2   86.5     66.8  -0.023  2020-12-25
# 722     73.5  -0.124  112.9   91.6     69.2   0.024  2020-12-25
# 723     67.9   0.010  111.2   95.4     67.7  -0.005  2020-12-25
#
# [724 rows x 13 columns]

# %%
df['line'] = df['SCORE_1'] - df['SCORE_2']
df['total'] = df['SCORE_1'] + df['SCORE_2']

# %%
x = df[['OFF_1','DEF_1','TEMPO_1','LUCK_1','OFF_2','DEF_2','TEMPO_2','LUCK_2']].values
y = df[['line']].values

# %%
#x = df[['OFF_1','DEF_1','TEMPO_1','LUCK_1','OFF_2','DEF_2','TEMPO_2','LUCK_2']].values
#y = df[['total']].values

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.neural_network import MLPRegressor
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
rf = RandomForestRegressor(n_estimators = 1000)  
rf.fit(X_train, y_train)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=1000,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
lg = LinearRegression()  
lg.fit(X_train, y_train)
ridge = Ridge()
ridge.fit(X_train, y_train)
lasso = Lasso()
lasso.fit(X_train, y_train)
mlp = MLPRegressor(max_iter = 10000).fit(X_train, y_train)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:1321: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = rf.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 9.726702134646963

# %%
y_pred = lg.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 9.63277673009679

# %%
y_pred = ridge.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 9.638194559261425

# %%
y_pred = lasso.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 9.701319877206123

# %%
y_pred = mlp.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 9.675301380006188

# %%
from datetime import datetime
import os
def get_today():
    today = datetime.today()
    year = today.year
    month = today.month
    day = today.day
    return year,month,day
year,month,day = get_today()
path = os.getcwd() 
name = path+"\\predict\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict.csv"

# %%
lasso = Lasso()
lasso.fit(x, y)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
predict = pd.read_csv(name)

# %%
predict
# Out:
#                   home                    away  home_off  home_def  \
# 0                 Iowa       Northern Illinois     118.4      94.5
# 1         Michigan St.                 Oakland     111.1      90.2
# 2        West Virginia                Richmond     110.4      87.4
# 3             Ohio St.           Cleveland St.     111.9      90.4
# 4         Grand Canyon             Arizona St.     100.6      99.5
# 5                Drake               Air Force     102.8      99.4
# 6                  VMI                 Hampton      97.1     104.5
# 7        UNC Asheville              High Point      98.5     103.3
# 8   South Carolina St.            Jacksonville      84.8     112.5
# 9       Tennessee Tech        Jacksonville St.      90.1     102.1
# 10          Coppin St.                    UMBC      88.2     102.0
# 11    Georgia Southern                  Mercer      96.6     102.5
# 12    Western Michigan               Milwaukee      94.3     101.5
# 13          Vanderbilt  Mississippi Valley St.     100.6      96.9
# 14                NJIT           New Hampshire      96.0      99.4
# 15      UNC Greensboro             Norfolk St.     102.3      96.9
# 16             Indiana           North Alabama     108.5      88.0
# 17            Kent St.       Northern Kentucky     100.9     100.2
# 18            Marshall                    Ohio     105.1      95.7
# 19            Michigan                Penn St.     112.9      91.7
# 20      Washington St.            Portland St.      96.3      95.2
# 21    Western Kentucky            Rhode Island     107.9      98.5
# 22          California           San Francisco      98.8      96.3
# 23            Cal Poly            San Jose St.      92.2     105.8
# 24        Northwestern        SIU Edwardsville     104.6      92.6
# 25          Georgetown              St. John's     103.0      95.8
# 26                 USC                Stanford     108.1      90.9
# 27           Boise St.               Weber St.     104.5      96.2
# 28         USC Upstate                Winthrop      96.3     107.3
# 29       Bowling Green              Wright St.     102.9     102.5
# 30          Binghamton          Youngstown St.      90.1     107.6
#
#     home_tempo  home_luck  away_off  away_def  away_tempo  away_luck
# 0         74.0      0.002      94.0     103.9        67.1     -0.089
# 1         72.8      0.029      95.3     105.8        71.6     -0.070
# 2         70.7     -0.046     108.1      93.0        72.8      0.015
# 3         68.7      0.091      94.3     101.5        71.1     -0.150
# 4         68.7      0.073     110.9      93.8        75.5      0.021
# 5         69.5      0.000      96.5     103.3        63.0      0.165
# 6         72.6     -0.040      93.0     108.8        74.0      0.158
# 7         71.3     -0.175      95.2     105.0        71.4     -0.135
# 8         74.1     -0.004      92.8     103.4        71.8      0.079
# 9         70.4     -0.130      93.8     102.2        69.1      0.075
# 10        76.7      0.049      98.6     101.5        71.3     -0.039
# 11        70.7      0.227     101.2      99.9        72.6      0.001
# 12        68.4     -0.060      95.2     104.3        71.2      0.000
# 13        73.0      0.000      83.9     115.8        77.5     -0.002
# 14        70.2      0.000      94.0      99.2        73.0     -0.000
# 15        72.8     -0.054      94.2      99.9        69.4      0.150
# 16        68.8     -0.055      95.0     103.2        70.7      0.000
# 17        71.2     -0.079      99.1     101.7        69.5      0.034
# 18        75.5      0.000     103.1      96.6        72.6     -0.071
# 19        71.0      0.003     109.3      93.4        71.7     -0.024
# 20        71.2      0.000      96.4     107.7        75.9      0.000
# 21        70.6      0.121     105.6      94.5        72.8     -0.113
# 22        67.6     -0.058     106.0      94.2        71.9     -0.018
# 23        71.7     -0.104      96.4     105.7        74.7      0.000
# 24        72.8     -0.201      91.0     105.4        71.7     -0.111
# 25        72.9     -0.128     105.0      95.9        75.6      0.064
# 26        69.7     -0.054     105.1      87.0        72.2     -0.125
# 27        71.2      0.015      93.4     103.5        70.9      0.000
# 28        73.6     -0.051     103.6      98.9        74.6      0.063
# 29        73.2      0.140     100.7      95.3        72.5     -0.069
# 30        70.5     -0.000     100.6     102.9        70.4      0.000

# %%
predict_x = predict[['home_off','home_def','home_tempo','home_luck','away_off','away_def','away_tempo','away_luck']].values

# %%
predict['line'] = lasso.predict(predict_x)
predict['line'] = round(predict['line'])

# %%
#predict['total'] = lg.predict(predict_x)
#predict['total'] = round(predict['total'])

# %%
predict
# Out:
#                   home                    away  home_off  home_def  \
# 0                 Iowa       Northern Illinois     118.4      94.5
# 1         Michigan St.                 Oakland     111.1      90.2
# 2        West Virginia                Richmond     110.4      87.4
# 3             Ohio St.           Cleveland St.     111.9      90.4
# 4         Grand Canyon             Arizona St.     100.6      99.5
# 5                Drake               Air Force     102.8      99.4
# 6                  VMI                 Hampton      97.1     104.5
# 7        UNC Asheville              High Point      98.5     103.3
# 8   South Carolina St.            Jacksonville      84.8     112.5
# 9       Tennessee Tech        Jacksonville St.      90.1     102.1
# 10          Coppin St.                    UMBC      88.2     102.0
# 11    Georgia Southern                  Mercer      96.6     102.5
# 12    Western Michigan               Milwaukee      94.3     101.5
# 13          Vanderbilt  Mississippi Valley St.     100.6      96.9
# 14                NJIT           New Hampshire      96.0      99.4
# 15      UNC Greensboro             Norfolk St.     102.3      96.9
# 16             Indiana           North Alabama     108.5      88.0
# 17            Kent St.       Northern Kentucky     100.9     100.2
# 18            Marshall                    Ohio     105.1      95.7
# 19            Michigan                Penn St.     112.9      91.7
# 20      Washington St.            Portland St.      96.3      95.2
# 21    Western Kentucky            Rhode Island     107.9      98.5
# 22          California           San Francisco      98.8      96.3
# 23            Cal Poly            San Jose St.      92.2     105.8
# 24        Northwestern        SIU Edwardsville     104.6      92.6
# 25          Georgetown              St. John's     103.0      95.8
# 26                 USC                Stanford     108.1      90.9
# 27           Boise St.               Weber St.     104.5      96.2
# 28         USC Upstate                Winthrop      96.3     107.3
# 29       Bowling Green              Wright St.     102.9     102.5
# 30          Binghamton          Youngstown St.      90.1     107.6
#
#     home_tempo  home_luck  away_off  away_def  away_tempo  away_luck  line
# 0         74.0      0.002      94.0     103.9        67.1     -0.089  32.0
# 1         72.8      0.029      95.3     105.8        71.6     -0.070  26.0
# 2         70.7     -0.046     108.1      93.0        72.8      0.015   7.0
# 3         68.7      0.091      94.3     101.5        71.1     -0.150  26.0
# 4         68.7      0.073     110.9      93.8        75.5      0.021 -11.0
# 5         69.5      0.000      96.5     103.3        63.0      0.165  11.0
# 6         72.6     -0.040      93.0     108.8        74.0      0.158   9.0
# 7         71.3     -0.175      95.2     105.0        71.4     -0.135   7.0
# 8         74.1     -0.004      92.8     103.4        71.8      0.079 -11.0
# 9         70.4     -0.130      93.8     102.2        69.1      0.075  -2.0
# 10        76.7      0.049      98.6     101.5        71.3     -0.039  -9.0
# 11        70.7      0.227     101.2      99.9        72.6      0.001  -4.0
# 12        68.4     -0.060      95.2     104.3        71.2      0.000   3.0
# 13        73.0      0.000      83.9     115.8        77.5     -0.002  30.0
# 14        70.2      0.000      94.0      99.2        73.0     -0.000   4.0
# 15        72.8     -0.054      94.2      99.9        69.4      0.150  11.0
# 16        68.8     -0.055      95.0     103.2        70.7      0.000  24.0
# 17        71.2     -0.079      99.1     101.7        69.5      0.034   5.0
# 18        75.5      0.000     103.1      96.6        72.6     -0.071   4.0
# 19        71.0      0.003     109.3      93.4        71.7     -0.024   6.0
# 20        71.2      0.000      96.4     107.7        75.9      0.000   9.0
# 21        70.6      0.121     105.6      94.5        72.8     -0.113   2.0
# 22        67.6     -0.058     106.0      94.2        71.9     -0.018  -6.0
# 23        71.7     -0.104      96.4     105.7        74.7      0.000  -2.0
# 24        72.8     -0.201      91.0     105.4        71.7     -0.111  22.0
# 25        72.9     -0.128     105.0      95.9        75.6      0.064  -0.0
# 26        69.7     -0.054     105.1      87.0        72.2     -0.125   2.0
# 27        71.2      0.015      93.4     103.5        70.9      0.000  17.0
# 28        73.6     -0.051     103.6      98.9        74.6      0.063 -10.0
# 29        73.2      0.140     100.7      95.3        72.5     -0.069   0.0
# 30        70.5     -0.000     100.6     102.9        70.4      0.000 -10.0

# %%
options = webdriver.ChromeOptions() 
#options.add_argument(r'''user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data''')
#"user-data-dir=C:\Users\Tarik's PC\AppData\Local\Google\Chrome\User Data" home
# "user-data-dir=C:\Users\koric1\AppData\Local\Google\Chrome\User Data" work
#options.add_argument("--start-maximized")
#self.options.add_argument("--headless")
#self.options.add_argument("--no-sandbox")
#self.options.add_argument("--disable-gpu")
options.add_argument('--headless')
options.add_argument('--disable-gpu')  # Last I checked this was necessa
driver = webdriver.Chrome(chrome_options= options)
driver.get('https://sportsbook.draftkings.com/leagues/basketball/3230960?category=game-lines&subcategory=game')

x = True
i = 1
teams = {}
while(x):
    print(i)
    try:
        team_name = str(driver.find_element_by_xpath('//*[@id="root"]/section/section[2]/section/div[3]/div/div[3]/div/div/div[2]/div/div[2]/div[2]/section/div[2]/div[1]/div['+str(i)+']/a/div/div[2]/span').text)
        team_score = float(driver.find_element_by_xpath('//*[@id="root"]/section/section[2]/section/div[3]/div/div[3]/div/div/div[2]/div/div[2]/div[2]/section/div[2]/div[2]/div['+str(i)+']/div/div/div/div[1]/span').text)
        teams[team_name] = team_score 
        i += 1
    except:
        x = False
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: use options instead of chrome_options
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-84-cc746c05aee1> in <module>
#      10 options.add_argument('--disable-gpu')  # Last I checked this was necessa
#      11 driver = webdriver.Chrome(chrome_options= options)
# ---> 12 driver.get('https://sportsbook.draftkings.com/leagues/basketball/3230960?category=game-lines&subcategory=game')
#      13
#      14 x = True
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: disconnected: Unable to receive message from renderer
#   (Session info: headless chrome=87.0.4280.88)
#   (Driver info: chromedriver=2.42.591088 (7b2b2dca23cca0862f674758c9a3933e685c27d5),platform=Windows NT 10.0.17763 x86_64)

# %%
teams
# Out:
# {'Florida': 1.5,
#  'Notre Dame': 7.5,
#  'Kentucky': -7.5,
#  'Kansas City': 11.0,
#  'Toledo': -11.0,
#  'Wofford': 4.0,
#  'South Florida': -4.0,
#  'Florida Gulf Coast': 18.5,
#  'Miami (FL)': -18.5,
#  'IUPUI': -2.0,
#  'Cincinnati': 7.0,
#  'Tennessee': -7.0,
#  'Syracuse': -3.0,
#  'Boston College': 3.0,
#  'Stony Brook': 5.5,
#  'Bryant': -5.5,
#  'Texas A&M': 1.0,
#  'TCU': -1.0,
#  'La Salle': 3.0,
#  'Drexel': -3.0,
#  'Arkansas-Pine Bluff': 17.0,
#  'Tulane': -17.0,
#  'Detroit': 1.0,
#  'Western Michigan': -1.0,
#  'North Carolina Central': 25.5,
#  'North Carolina': -25.5,
#  'St. Francis (PA)': 15.0,
#  'St. Bonaventure': -15.0,
#  'Texas A&M-CC': 26.5,
#  'Texas Tech': -26.5,
#  'High Point': 4.5,
#  'North Carolina Asheville': -4.5,
#  'Dayton': -4.0,
#  'Evansville': 22.5,
#  'Saint Louis': -22.5,
#  'South Alabama': -4.0,
#  'Southern Mississippi': 4.0,
#  'Denver': -3.0,
#  'Wyoming': -7.0,
#  'Utah Valley': 7.0,
#  'Gardner-Webb': 14.0,
#  'Pittsburgh': -14.0,
#  'Idaho': 11.5,
#  'Cal State Bakersfield': -11.5,
#  'Winthrop': -10.5,
#  'USC Upstate': 10.5,
#  'UAB': -4.0,
#  'Western Carolina': -7.0,
#  'North Carolina A&T': 7.0,
#  'Valparaiso': -3.0,
#  'Central Michigan': 3.0,
#  'Old Dominion': 7.0,
#  'VCU': -7.0,
#  'UNC Wilmington': 18.5,
#  'Ole Miss': -18.5,
#  'Western Illinois': 12.5,
#  'Eastern Illinois': -12.5,
#  'Florida Intl': -7.0,
#  'North Florida': 7.0,
#  'UC Santa Barbara': 1.0,
#  'Loyola Marymount': -1.0,
#  'Stephen F. Austin': -5.5,
#  'Louisiana-Monroe': 5.5,
#  'Florida A&M': 26.5,
#  'Oklahoma': -26.5,
#  'Auburn': 6.5,
#  'Memphis': -6.5,
#  'UTEP': 17.0,
#  'Arizona': -17.0,
#  'Utah': 2.0,
#  'BYU': -2.0,
#  'North Dakota': 5.5,
#  'Samford': 18.0,
#  'Georgia': -18.0,
#  'Louisiana Tech': -4.5,
#  'LA-Lafayette': 4.5,
#  'Iona': -6.5,
#  'Fairfield': 6.5,
#  'Marist': 4.5,
#  'Canisius': -4.5,
#  'Purdue': -14.5,
#  'Illinois': -3.0,
#  'Missouri': 3.0,
#  'Oregon': -8.0,
#  'Washington': 8.0,
#  'Alabama': -2.0,
#  'Clemson': 2.0,
#  'Belmont': -6.5,
#  'Lipscomb': 6.5,
#  'Central Arkansas': 23.5,
#  'Arkansas': -23.5,
#  'CSU Northridge': 15.0,
#  'Pepperdine': -15.0,
#  'South Dakota': 11.5,
#  'Florida St.': -1.5,
#  'Tennessee St.': 2.0,
#  'Oklahoma St.': -3.5,
#  'Wichita St.': 3.5,
#  'Mississippi St.': 4.0,
#  'Dixie St.': 3.0,
#  'East Tennessee St.': 4.0,
#  'North Dakota St.': -5.5,
#  'Illinois St.': 5.0,
#  'Ball St.': -5.0,
#  'Indiana St.': 14.5,
#  'South Dakota St.': -11.5}

# %%
for key in list(teams):
    name_list = key.split()
    if name_list[-1] == "State":
        name_list[-1] = "St."
        new_name = " ".join(str(x) for x in name_list)
        home_team = new_name
        teams[home_team] = teams[key] 
        del teams[key]

# %%
teams
# Out:
# {'Florida': 1.5,
#  'Notre Dame': 7.5,
#  'Kentucky': -7.5,
#  'Kansas City': 11.0,
#  'Toledo': -11.0,
#  'Wofford': 4.0,
#  'South Florida': -4.0,
#  'Florida Gulf Coast': 18.5,
#  'Miami (FL)': -18.5,
#  'IUPUI': -2.0,
#  'Cincinnati': 7.0,
#  'Tennessee': -7.0,
#  'Syracuse': -3.0,
#  'Boston College': 3.0,
#  'Stony Brook': 5.5,
#  'Bryant': -5.5,
#  'Texas A&M': 1.0,
#  'TCU': -1.0,
#  'La Salle': 3.0,
#  'Drexel': -3.0,
#  'Arkansas-Pine Bluff': 17.0,
#  'Tulane': -17.0,
#  'Detroit': 1.0,
#  'Western Michigan': -1.0,
#  'North Carolina Central': 25.5,
#  'North Carolina': -25.5,
#  'St. Francis (PA)': 15.0,
#  'St. Bonaventure': -15.0,
#  'Texas A&M-CC': 26.5,
#  'Texas Tech': -26.5,
#  'High Point': 4.5,
#  'North Carolina Asheville': -4.5,
#  'Dayton': -4.0,
#  'Evansville': 22.5,
#  'Saint Louis': -22.5,
#  'South Alabama': -4.0,
#  'Southern Mississippi': 4.0,
#  'Denver': -3.0,
#  'Wyoming': -7.0,
#  'Utah Valley': 7.0,
#  'Gardner-Webb': 14.0,
#  'Pittsburgh': -14.0,
#  'Idaho': 11.5,
#  'Cal State Bakersfield': -11.5,
#  'Winthrop': -10.5,
#  'USC Upstate': 10.5,
#  'UAB': -4.0,
#  'Western Carolina': -7.0,
#  'North Carolina A&T': 7.0,
#  'Valparaiso': -3.0,
#  'Central Michigan': 3.0,
#  'Old Dominion': 7.0,
#  'VCU': -7.0,
#  'UNC Wilmington': 18.5,
#  'Ole Miss': -18.5,
#  'Western Illinois': 12.5,
#  'Eastern Illinois': -12.5,
#  'Florida Intl': -7.0,
#  'North Florida': 7.0,
#  'UC Santa Barbara': 1.0,
#  'Loyola Marymount': -1.0,
#  'Stephen F. Austin': -5.5,
#  'Louisiana-Monroe': 5.5,
#  'Florida A&M': 26.5,
#  'Oklahoma': -26.5,
#  'Auburn': 6.5,
#  'Memphis': -6.5,
#  'UTEP': 17.0,
#  'Arizona': -17.0,
#  'Utah': 2.0,
#  'BYU': -2.0,
#  'North Dakota': 5.5,
#  'Samford': 18.0,
#  'Georgia': -18.0,
#  'Louisiana Tech': -4.5,
#  'LA-Lafayette': 4.5,
#  'Iona': -6.5,
#  'Fairfield': 6.5,
#  'Marist': 4.5,
#  'Canisius': -4.5,
#  'Purdue': -14.5,
#  'Illinois': -3.0,
#  'Missouri': 3.0,
#  'Oregon': -8.0,
#  'Washington': 8.0,
#  'Alabama': -2.0,
#  'Clemson': 2.0,
#  'Belmont': -6.5,
#  'Lipscomb': 6.5,
#  'Central Arkansas': 23.5,
#  'Arkansas': -23.5,
#  'CSU Northridge': 15.0,
#  'Pepperdine': -15.0,
#  'South Dakota': 11.5,
#  'Florida St.': -1.5,
#  'Tennessee St.': 2.0,
#  'Oklahoma St.': -3.5,
#  'Wichita St.': 3.5,
#  'Mississippi St.': 4.0,
#  'Dixie St.': 3.0,
#  'East Tennessee St.': 4.0,
#  'North Dakota St.': -5.5,
#  'Illinois St.': 5.0,
#  'Ball St.': -5.0,
#  'Indiana St.': 14.5,
#  'South Dakota St.': -11.5}

# %%
predict['draft_kings'] = predict['away'].apply(lambda x: teams[x] if x in teams else -99)

# %%
predict = predict[predict['draft_kings']!=-99]

# %%
predict['diff'] = abs(predict['line'] - predict['draft_kings'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'line'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-8bb9203e15b8> in <module>
# ----> 1 predict['diff'] = abs(predict['line'] - predict['draft_kings'])
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'line'

# %%
predict = predict.sort_values(by=['diff'], ascending = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-ea6198e3234c> in <module>
# ----> 1 predict = predict.sort_values(by=['diff'], ascending = False)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    5006
#    5007             by = by[0]
# -> 5008             k = self._get_label_or_level_values(by, axis=axis)
#    5009
#    5010             if isinstance(ascending, (tuple, list)):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python36_64\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'diff'

# %%
predict = predict.drop(columns=['home_off','home_def','home_tempo','home_luck','away_off','away_def','away_tempo','away_luck'])
predict
# Out:
#              home        away  draft_kings
# 7   UNC Asheville  High Point          4.5
# 28    USC Upstate    Winthrop        -10.5

# %%
from datetime import datetime
import os
def get_today():
    today = datetime.today()
    year = today.year
    month = today.month
    day = today.day
    return year,month,day
year,month,day = get_today()
year = 2012
day = 12
month = 12
path = os.getcwd() 
name = path+"\\predict_scores\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict_scores.csv"
predict.to_csv(name, index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ce4fb9d35822> in <module>
#      13 path = os.getcwd()
#      14 name = path+"\\predict_scores\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict_scores.csv"
# ---> 15 predict.to_csv(name, index = False)
#
# NameError: name 'predict' is not defined

# %%
map_names_not_same = {
                        "Alabama-Birmingham" : "UAB",
                        "Albany (NY)": "Albany",
                        "Arkansas-Pine Bluff" : "Arkansas Pine Bluff",
                        "Bethune-Cookman" : "Bethune Cookman",
                        "Bowling Green State" : "Bowling Green",
                        "Brigham Young" : "BYU",
                        "Cal State Bakersfield" : "Cal St. Bakersfield",
                        "Cal State Fullerton" : "Cal St. Fullerton",
                        "Cal State Northridge" : "Cal St. Northridge",
                        "California Baptist" : "Cal Baptist",
                        "UC-Davis" : "UC Davis",
                        "UC-Irvine" : "UC Irvine",
                        "UC-Riverside" : "UC Riverside",
                        "UCSB" : "UC Santa Barbara",
                        "University of California" : "California",
                        "Central Connecticut State" : "Central Connecticut",
                        "Central Florida" : "UCF",
                        "Citadel" : "The Citadel",
                        "College of Charleston" : "Charleston",
                        "Detroit Mercy" : "Detroit",
                        "Florida International" : "FIU",
                        "Gardner-Webb" : "Gardner Webb",
                        "Grambling" : "Grambling St.",
                        "Illinois-Chicago" : "Illinois Chicago",
                        "Purdue-Fort Wayne" : "Purdue Fort Wayne",
                        "Cal State Long Beach" : "Long Beach St.",
                        "Long Island University" : "LIU",
                        "Louisiana-Monroe" : "Louisiana Monroe",
                        "Louisiana State" : "LSU",
                        "Loyola (IL)" : "Loyola Chicago",
                        "Loyola (MD)" : "Loyola Marymount",
                        "Maryland-Baltimore County" : "UMBC",
                        "Maryland-Eastern Shore" : "Maryland Eastern Shore",
                        "Massachusetts-Lowell" : "UMass Lowell",
                        "Miami (FL)" : "Miami FL",
                        "Miami (OH)" : "Miami OH",
                        "Missouri-Kansas City" : "UMKC",
                        "Omaha" : "Nebraska Omaha",
                        "Nevada-Las Vegas" : "UNLV",
                        "North Carolina-Asheville" : "UNC Asheville",
                        "North Carolina-Greensboro" : "UNC Greensboro",
                        "North Carolina-Wilmington" : "UNC Wilmington",
                        "NC State" : "N.C. State",
                        "Pennsylvania" : "Penn",
                        "Prairie View" : "Prairie View A&M",
                        "Saint Francis (PA)" : "St. Francis PA",
                        "Saint Mary's (CA)" : "Saint Mary's",
                        "South Carolina Upstate" : "South Carolina St.",
                        "Southern California" : "USC",
                        "Southern Methodist" : "SMU",
                        "Southern Mississippi" : "Southern Miss",
                        "SIU-Edwardsville" : "SIU Edwardsville",
                        "St. Francis (NY)" : "St. Francis NY",
                        "St. John's (NY)" : "St. John's",
                        "Tennessee-Martin" : "Tennessee Martin",
                        "Texas A&M-Corpus Christi" : "Texas A&M Corpus Chris",
                        "Texas-Arlington" : "UT Arlington",
                        "Texas Christian" : "TCU",
                        "Texas-El Paso" : "UTEP",
                        "Texas-Rio Grande Valley" : "UT Rio Grande Valley",
                        "Texas-San Antonio" : "UTSA",
                        "Virginia Commonwealth" : "VCU",
                        "UConn" : "Connecticut",
                        "UMass-Lowell" : "UMass Lowell",
                        "UT-Martin" : "Tennessee Martin",
                        "UNC" : "North Carolina",
                        "Pitt" : "Pittsburgh"
                     }

# %%
def predict_scores_error(year,month,day):
    path = os.getcwd()
    predict_scores = path+"\\predict_scores\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict_scores.csv"
    name = path+"\\predict_error\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict_error.csv"
    scores = path+"\\scores\\"+str(year)+"_"+str(month)+"_"+str(day)+"_scores.csv"
    
    df = pd.read_csv(predict_scores)
    
    
    df2 = pd.read_csv(scores)
    df2['score'] = df2['home_score'] - df2['away_score']
    
    
    df['score'] = 100
    for index, row in df.iterrows():
        away = row['away']
        for index2, row2 in df2.iterrows():
            away2 = row2['away_team']
            try:
                if away2 in map_names_not_same.keys():
                    away2 = map_names_not_same[home_team]
                else:
                    name_list = away2.split()
                    if name_list[-1] == "State":
                        name_list[-1] = "St."
                        new_name = " ".join(str(x) for x in name_list)
                        away2 = new_name
                if away == away2:
                    df.loc[index,'score'] = row2['score']
            except:
                pass
    df = df[df['score']!=100]            
    return df

# %%
from datetime import timedelta
def get_yesterday():
    today = datetime.today()
    yesterday = today - timedelta(days = 1)
    year = yesterday.year
    month = yesterday.month
    day = yesterday.day
    return year,month,day
year,month,day = get_yesterday()
year = 2020
day = 12
month = 12

# %%
df = predict_scores_error(year,month,day)

# %%
name = path+"\\predict_error\\"+str(year)+"_"+str(month)+"_"+str(day)+"_predict_error.csv"
df.to_csv(name, index = False)

# %%
ill_mizz = np.array([110.9,89.9,72.1,.036,108,91.1,70.7,.062])

# %%
ill_mizz
# Out:
# array([1.109e+02, 8.990e+01, 7.210e+01, 3.600e-02, 1.080e+02, 9.110e+01,
#        7.070e+01, 6.200e-02])

# %%
lasso.predict([ill_mizz])
# Out:
# array([-3.86648709])

# %%
lasso.predict([ill_mizz])
# Out:
# array([3.81125796])
